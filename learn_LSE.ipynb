# %%
import numpy as np
import matplotlib.pyplot as plt
import LSE_net
import lse_functions as lse_f
import torch
import importlib
import pickle
import datetime

# %%
a, b = [0, 100]
num_intervals = np.random.choice(range(2,100))
num_active_intervals = np.random.choice(range(1,num_intervals))
distr = lse_f.PiecewiseUniformDistribution(
    a=a, b=b,
    num_intervals=num_intervals,
    num_active_intervals=num_active_intervals,
    seed=None)
samples = np.sort(distr.sample(100))

# Plot histogram and PDF
plt.hist(samples, bins=100, density=True, alpha=0.5, label='Sampled')
xs = np.linspace(a, b, 1000)
ys = [distr.pdf(x) for x in xs]
plt.plot(xs, ys, label='PDF', color='red')
plt.legend()
plt.title("Piecewise Uniform Distribution")
plt.show()

# %% [markdown]
# ### Create dataset

# %%
# beta limits
b_min = 1e-4
b_max = 1e6
b_grow = 1.1
b_array = lse_f.createBetaArray(b_min, b_max, b_grow)
print(f'len b_array:\t{b_array.shape}')

# torch input and output arrays
n_curves = 50
num_D_range = [10,10]
D_range = [0.0, 100.0] # minimum value of D_array is picked at random from this range
IO_scale = 1

In, Out, len_D_ARR = lse_f.data_multi_paths(n_curves, b_array, D_range, num_D_range, n_shortest=10, plothist=False)
print(f'In:\t{In.size()}\nOut:\t{Out.size()}\nlen_D_ARR\tsize:{len(len_D_ARR)}\tmin:{np.min(len_D_ARR)}\tmax:{np.max(len_D_ARR)}\tmean:{np.mean(len_D_ARR)}')
# Out:
# len b_array:	(243,)
# In:	torch.Size([12150, 12])
# Out:	torch.Size([12150, 1])
# len_D_ARR	size:12150	min:10	max:10	mean:10.0

# %% [markdown]
# ### Visualize Data

# %%
lse_f.visualizeData(In, Out, 5000)

# %% [markdown]
# ### Create neural net for training

# %%
# create DNN
n_inputs = In.size()[1]
n_outputs = Out.size()[1]
layers = [20, 20, 10]
lse_net = LSE_net.dnn(n_inputs, n_outputs, layers)
print(f'DNN model:\n{lse_net}')

# create training, and testing dataset
n_samples = In.size()[0]
frac_train = 0.9
n_train = int(frac_train * n_samples)
indices = torch.arange(n_samples)
train_indices = indices[:n_train]
test_indices = indices[n_train:]
In_train = In[train_indices]
Out_train = Out[train_indices]
In_test = In[test_indices]
Out_test = Out[test_indices]
# Out:
# DNN model:
# dnn(
#   (layers): ModuleList(
#     (0): Linear(in_features=12, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=20, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=20, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )

# %%
In[:]
# Out:
# tensor([[62.1555, 33.3594, 34.1531,  ..., 86.2664, 95.8405, -4.0000],
#         [62.1555, 33.3594, 34.1531,  ..., 86.2664, 95.8405, -3.9586],
#         [62.1555, 33.3594, 34.1531,  ..., 86.2664, 95.8405, -3.9172],
#         ...,
#         [58.7111, 18.2953, 45.0807,  ..., 75.0735, 77.2035,  5.9342],
#         [58.7111, 18.2953, 45.0807,  ..., 75.0735, 77.2035,  5.9756],
#         [58.7111, 18.2953, 45.0807,  ..., 75.0735, 77.2035,  6.0170]])

# %%
lse_net(In[1:2]).detach().numpy()
# Out:
# array([[5.2535896]], dtype=float32)

# %%
lse_f.visualizeData(In_train, Out_train, n_end=5000)
lse_f.visualizeData(In_test, Out_test, n_end=5000)

# %% [markdown]
# ### train the network

# %%
# dnn configuration
optimizer_name = 'adam'
lr_scheduler = 'ReduceLROnPlateau'
lr0 = 0.0001
epochs = 500
batch_size = 70
loss_coeffs = [1.0, 0.0]
loss_fn, optimizer, scheduler = LSE_net.config_nn(lse_net, optimizer_name, lr_scheduler, lr0)
loss = loss_fn(lse_net(In_train[0:1]), Out_train[0:1]).detach().item()
training_loss, learning_rate, stopping_epoch = LSE_net.train_nn1(
    lse_net, In_train, Out_train, loss_fn,
    optimizer, scheduler, loss_coeffs=loss_coeffs,
    epochs=epochs, batch_size=batch_size, shuffledata=True, allowPrint=True)
# Out:
# ---------------------------------
# training data size = 10935
# training batch size = 70
# n_epochs = 500
# n_batches = 157
# loss weights = [1.0, 0.0]
# ---------------------------------
#
# batch_split
# 0 69
# 70 139
# 140 209
# 210 279
# 280 349
# 350 419
# 420 489
# 490 559
# 560 629
# 630 699
# 700 769
# 770 839
# 840 909
# 910 979
# 980 1049
# 1050 1119
# 1120 1189
# 1190 1259
# 1260 1329
# 1330 1399
# 1400 1469
# 1470 1539
# 1540 1609
# 1610 1679
# 1680 1749
# 1750 1819
# 1820 1889
# 1890 1959
# 1960 2029
# 2030 2099
# 2100 2169
# 2170 2239
# 2240 2309
# 2310 2379
# 2380 2449
# 2450 2519
# 2520 2589
# 2590 2659
# 2660 2729
# 2730 2799
# 2800 2869
# 2870 2939
# 2940 3009
# 3010 3079
# 3080 3149
# 3150 3219
# 3220 3289
# 3290 3359
# 3360 3429
# 3430 3499
# 3500 3569
# 3570 3639
# 3640 3709
# 3710 3779
# 3780 3849
# 3850 3919
# 3920 3989
# 3990 4059
# 4060 4129
# 4130 4199
# 4200 4269
# 4270 4339
# 4340 4409
# 4410 4479
# 4480 4549
# 4550 4619
# 4620 4689
# 4690 4759
# 4760 4829
# 4830 4899
# 4900 4969
# 4970 5039
# 5040 5109
# 5110 5179
# 5180 5249
# 5250 5319
# 5320 5389
# 5390 5459
# 5460 5529
# 5530 5599
# 5600 5669
# 5670 5739
# 5740 5809
# 5810 5879
# 5880 5949
# 5950 6019
# 6020 6089
# 6090 6159
# 6160 6229
# 6230 6299
# 6300 6369
# 6370 6439
# 6440 6509
# 6510 6579
# 6580 6649
# 6650 6719
# 6720 6789
# 6790 6859
# 6860 6929
# 6930 6999
# 7000 7069
# 7070 7139
# 7140 7209
# 7210 7279
# 7280 7349
# 7350 7419
# 7420 7489
# 7490 7559
# 7560 7629
# 7630 7699
# 7700 7769
# 7770 7839
# 7840 7909
# 7910 7979
# 7980 8049
# 8050 8119
# 8120 8189
# 8190 8259
# 8260 8329
# 8330 8399
# 8400 8469
# 8470 8539
# 8540 8609
# 8610 8679
# 8680 8749
# 8750 8819
# 8820 8889
# 8890 8959
# 8960 9029
# 9030 9099
# epoch: 481/500, 	 loss: 38.469 	 rel:3.634e-01, 	 time: 0.20
# epoch: 482/500, 	 loss: 39.420 	 rel:3.723e-01, 	 time: 0.21
# epoch: 483/500, 	 loss: 38.349 	 rel:3.622e-01, 	 time: 0.21
# epoch: 484/500, 	 loss: 39.849 	 rel:3.764e-01, 	 time: 0.20
# epoch: 485/500, 	 loss: 39.777 	 rel:3.757e-01, 	 time: 0.21
# epoch: 486/500, 	 loss: 37.290 	 rel:3.522e-01, 	 time: 0.20
# epoch: 487/500, 	 loss: 38.561 	 rel:3.642e-01, 	 time: 0.21
# epoch: 488/500, 	 loss: 39.067 	 rel:3.690e-01, 	 time: 0.20
# epoch: 489/500, 	 loss: 38.407 	 rel:3.628e-01, 	 time: 0.25
# epoch: 490/500, 	 loss: 37.670 	 rel:3.558e-01, 	 time: 0.21
# epoch: 491/500, 	 loss: 37.848 	 rel:3.575e-01, 	 time: 0.21
# epoch: 492/500, 	 loss: 38.240 	 rel:3.612e-01, 	 time: 0.21
# epoch: 493/500, 	 loss: 36.912 	 rel:3.487e-01, 	 time: 0.20
# epoch: 494/500, 	 loss: 38.013 	 rel:3.591e-01, 	 time: 0.20
# epoch: 495/500, 	 loss: 37.176 	 rel:3.511e-01, 	 time: 0.20
# epoch: 496/500, 	 loss: 37.603 	 rel:3.552e-01, 	 time: 0.20
# epoch: 497/500, 	 loss: 35.521 	 rel:3.355e-01, 	 time: 0.21
# epoch: 498/500, 	 loss: 37.983 	 rel:3.588e-01, 	 time: 0.20
# epoch: 499/500, 	 loss: 38.745 	 rel:3.660e-01, 	 time: 0.20
# epoch: 500/500, 	 loss: 38.569 	 rel:3.643e-01, 	 time: 0.20
# Maximum Iterations Reached
# ---------------------------------

# %% [markdown]
# ### Store the trained network data

# %%
trained_lse_info = {
    'model_state_dict': lse_net.state_dict(), 
    'n_inputs':n_inputs,
    'n_outputs':n_outputs,
    'layers':layers,
    'b_arr':b_array, 
    'len_Darray_range':len_Darray_range, 
    'D_min_range':D_min_range,
    'D_max_range':D_max_scale,
    'io_scale':IO_scale,
    'n_samples':n_samples,
    'frac_train':frac_train,
    'optimizer_name':optimizer,
    'optimize_state_dict':optimizer.state_dict(),
    'lr_scheduler':lr_scheduler,
    'lr0':lr0,
    'loss_fn':loss_fn,
    'epochs':epochs,
    'batch_size':batch_size,
    'training_loss':training_loss,
    'learning_rate':learning_rate,
}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 7
#       1 trained_lse_info = {
#       2     'model_state_dict': lse_net.state_dict(),
#       3     'n_inputs':n_inputs,
#       4     'n_outputs':n_outputs,
#       5     'layers':layers,
#       6     'b_arr':b_array,
# ----> 7     'len_Darray_range':len_Darray_range,
#       8     'D_min_range':D_min_range,
#       9     'D_max_range':D_max_scale,
#      10     'io_scale':IO_scale,
#      11     'n_samples':n_samples,
#      12     'frac_train':frac_train,
#      13     'optimizer_name':optimizer,
#      14     'optimize_state_dict':optimizer.state_dict(),
#      15     'lr_scheduler':lr_scheduler,
#      16     'lr0':lr0,
#      17     'loss_fn':loss_fn,
#      18     'epochs':epochs,
#      19     'batch_size':batch_size,
#      20     'training_loss':training_loss,
#      21     'learning_rate':learning_rate,
#      22 }
#
# NameError: name 'len_Darray_range' is not defined

# %% [markdown]
# ### Save the trained model

# %%
# str(datetime.datetime.today()).split()
current_time = datetime.datetime.now()
yyyy = str(current_time.year)
mm = str(current_time.month)
dd = str(current_time.day)
hh = str(current_time.hour)
mt = str(current_time.minute)
sec = str(current_time.second)
current_datetime = yyyy + '_' + mm + '_' + dd + '__' + hh + '_' + mt + '_' + sec 
print(f'trained_network_data_name: {current_datetime}')
# Out:
# trained_network_data_name: 2025_5_19__15_47_58

# %%
filename = 'logSumExp_models/lse_' + current_datetime + '.pth'

torch.save(trained_lse_info, filename)

# %% [markdown]
# ### plot training loss and learning rate

# %%
plt.figure(figsize=(10,2))
plt.subplot(1,2,1)
plt.plot(training_loss)
plt.title('training_loss')
plt.grid()
plt.subplot(1,2,2)
plt.plot(learning_rate)
plt.title('learning_rate')
plt.grid()

plt.show()

# %% [markdown]
# ### Evaluate the network on a validation dataset

# %%
# np.random.seed(10)
b_min_v = b_array[0]*1
b_max_v = b_array[-1]*1
b_grow_v = 1.5
b_array_v = lse_f.createBetaArray(b_min_v, b_max_v, b_grow_v)
# print(b_array_v)
n_curves_v = 2
D_range_v = [0.0, 100.0]
n_D_range_v = [100,100]
n_shortest_v = 10
In_val, Out_val, len_D_ARR_v = lse_f.data_multi_paths(n_curves=n_curves_v, 
                    b_array=b_array_v, D_range=D_range_v,
                    num_D_range=len_Darray_range_v,
                    n_shortest = n_shortest_v,
                    io_scale=IO_scale)
pred_val = lse_net(In_val).detach()

st = 0
Out_val_np = (Out_val.numpy().flatten()/IO_scale)[st:] - 0*(1 / np.tile(b_array_v, n_curves_v) * np.log(len_D_ARR_v))[st:] + 0*(In_val[:,1].numpy().flatten()/IO_scale)[st:]
pred_val_np = (pred_val.numpy().flatten()/IO_scale)[st:] - 0*(1 / np.tile(b_array_v, n_curves_v) * np.log(len_D_ARR_v))[st:] + 0*(In_val[:,1].numpy().flatten()/IO_scale)[st:]

plt.figure(figsize=(12,4))
plt.subplot(2,1,1)
plt.plot(Out_val_np, label='target', color='violet', linestyle='dashed', linewidth=3)
plt.plot(pred_val_np, label='prediction', color='black')
plt.grid()
plt.xticks()
plt.legend()

plt.subplot(2,1,2)
error_val = np.abs(pred_val_np - Out_val_np)/np.mean(Out_val_np)
plt.plot(error_val, label='error', color='red')
plt.legend()
plt.grid()

plt.figure(figsize=(12,2))
plt.hist(In_val[:,1].numpy().flatten(), bins=10, histtype='barstacked', rwidth=0.8, label='d_min')
plt.hist(In_val[:,0].numpy().flatten(), bins=10, histtype='barstacked', rwidth=0.8, label='F_min')
plt.legend()

plt.show()

# %%
Out_val_np.shape
# Out:
# (23160,)

# %%
b_array_v.shape
# Out:
# (2316,)

# %%
np.tile(b_array_v, n_curves_v).shape
# Out:
# (1120,)
