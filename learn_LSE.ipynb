# %%
import numpy as np
import matplotlib.pyplot as plt
import LSE_net
import torch
import importlib
import pickle
import datetime

# %%
def myLog(x, base):
    return np.log(x)/np.log(base)

def createBetaArray(min, max, grow):
    beta = min
    beta_array = [beta]
    while beta <= max:
        beta = beta*grow
        beta_array.append(beta)
    beta_array = np.array(beta_array)
    return beta_array

def logSumExp(D_array, beta):
    D_min = np.min(D_array)
    D_off = D_array - D_min
    F = -1/beta * np.log(np.sum(np.exp(-beta*D_off))) + 1/beta * np.log(len(D_array)) + D_min
    # F = -np.log(np.sum(np.exp(-beta*D_off))) + np.log(len(D_array)) + D_min * beta
    return F

def gibbs(D_array, beta):
    D_min = np.min(D_array)
    D_off = D_array - D_min
    exp_bD = np.exp(-beta * D_off)
    sum_exp_bD = np.sum(exp_bD)
    P = exp_bD/sum_exp_bD
    return P

def area_approx_F(D_min, D_max_range, N_D, beta):
    min_beta_D_arr = beta * D_min
    x_max = beta * D_max_range - min_beta_D_arr
    F_est = -1/beta * np.log(N_D/x_max * (1 - np.exp(-x_max))) + D_min + 1/beta * np.log(N_D)
    # F_est = -1/beta * np.log(1/x_max * (1 - np.exp(-x_max))) + D_min
    return F_est

# %% [markdown]
# ### A Usecase of area_approx_F function

# %%
# D_min = 0.5
# D_max_range = 1.0
# N_D = 341
# beta1 = 1e-3
# beta2 = 1e-4

# Fest1 = area_approx_F(D_min, D_max_range, N_D, beta=beta1)
# Fest2 = area_approx_F(D_min, D_max_range, N_D, beta=beta2)
# print(f'Fest1:{Fest1}\tFest2:{Fest2}')

# %%
# beta = 0.001
# # np.random.seed(10)
# D_max = 1
# D_array = np.sort(np.random.uniform(0.2, D_max, 500))
# D_min = np.min(D_array)
# P = gibbs(D_array, beta)
# F = logSumExp(D_array, beta)
# # slopeP = (P[1:] - P[0:-1])/(D_array[1:]-D_array[0:-1])

# N_discrete = 1000
# D_discrete = np.linspace(D_min, D_max, N_discrete)
# P1 = beta * np.exp(-beta * (D_discrete))/(np.exp(-beta * D_min) - np.exp(-beta * D_max)) * (D_max - D_min)/N_discrete
# P1 = P1/np.sum(P1)

# frac = 0.01
# # D_array1 = np.random.choice(a=D_discrete, p=P1, size=int(len(D_array)*frac)-1)
# # D_array1 = np.sort(
# #     np.concatenate((
# #         np.array([D_min]),
# #         D_array1, 
# #         np.random.uniform(np.max(D_array1), D_max, int(len(D_array)*(1-frac))))
# #     ))
# D_array1 = np.random.uniform(D_min, D_max, int(len(D_array)))

# P2 = gibbs(D_array1, beta)
# F2 = logSumExp(D_array1, beta)

# print(f"D_min:{D_min:.3e}\tD_min1:{np.min(D_array1):.3e}\tF:{F:.3f}\tF2:{F2:.3f}\tpercent_error:{abs(F-F2)/abs(F)*100:.3f}%")

# # P3 = beta * np.exp(-beta * (D_array1))/(np.exp(-beta * np.min(D_array1)) - np.exp(-beta * np.max(D_array1))) * (np.max(D_array1) - np.min(D_array1))/len(D_array1)

# plt.figure(figsize=(6,2))
# plt.plot(D_discrete, P1, marker='.', label='P1')
# plt.legend()
# plt.grid()

# plt.figure(figsize=(6,2))
# plt.plot(D_array, P, marker='.', label='P')
# plt.plot(D_array1, P2, marker='.', label='P2')
# # plt.plot(D_array1, P3, marker='.', label='P3')
# # plt.ylim(0.0,1.0)
# plt.legend()
# plt.grid()

# # plt.figure(figsize=(6,2))
# # plt.plot(beta * D_array[0:-1], slopeP, marker='.')
# # plt.ylim(0.0,1.0)
# # plt.grid()
# # plt.show()

# %%
# b_min = 0.0001
# b_max = 10
# b_grow = 1.1
# D_range0 = [10,200]
# D_range1 = [700,1000]
# D_array = np.sort(
#     np.concatenate(
#         (np.random.uniform(D_range0[0], D_range0[1], 500),
#         np.random.uniform(D_range1[0], D_range1[1], 500))
#         ))
# D_min = np.min(D_array)
# N_discrete = 20000

# F_org_arr = []
# F_est_arr = []
# b_arr = []
# beta = b_min

# while beta <= b_max:
#     F = logSumExp(D_array, beta)

#     # D_discrete = np.linspace(D_min, D_range[1], N_discrete)
#     # P1 = beta * np.exp(-beta * (D_discrete))/(np.exp(-beta * D_min) - np.exp(-beta * D_range[1])) * (D_range[1] - D_min)/N_discrete
#     # P1 = P1/np.sum(P1)

#     # D_array1 = np.sort(np.random.choice(a=D_discrete, p=P1, size=len(D_array)))
#     # D_array1 = np.concatenate((np.array([D_min]), np.sort(np.random.choice(a=D_discrete, p=P1, size=len(D_array)-1))))
#     # np.random.seed(10)
#     D_array1 = np.sort(
#     np.concatenate(
#         (np.array([D_min]),
#         np.random.uniform(D_min, D_range0[1], 500),
#         np.random.uniform(D_range1[0], D_range1[1], 499))
#         )
#     )
#     # D_array1 = np.concatenate((np.array([D_min]), np.sort(np.random.uniform(D_min, D_range[1], len(D_array)-1))))
#     P2 = gibbs(D_array1, beta)
#     F2 = logSumExp(D_array1, beta)

#     F_org_arr.append(F)
#     F_est_arr.append(F2)
#     b_arr.append(beta)

#     beta *= b_grow

# np_F_org_arr = np.array(F_org_arr)
# np_F_est_arr = np.array(F_est_arr)

# plt.figure(figsize=(6,2))
# plt.plot(myLog(b_arr,10), np.array(F_org_arr), label='original')
# plt.plot(myLog(b_arr,10), np.array(F_est_arr), label='estimate')
# plt.grid()
# plt.legend()

# plt.figure(figsize=(6,2))
# plt.plot(myLog(b_arr,10), np_F_org_arr-np_F_est_arr, label='error')
# plt.grid()
# plt.legend()

# plt.show()

# %%
# d1 = 10
# d2 = 30
# d3 = 40
# d4 = 50
# b0 = 1e-5
# l0 = 1/b0 * np.log(4)
# l1 = -1/b0 * np.log(np.exp(-b0*d1) + np.exp(-b0*d2) + np.exp(-b0*d3) + np.exp(-b0*d4)) + l0
# l2 = -1/b0 * np.log(4)
# l3 = l2 + d1 - 1/b0 * np.log((1 + np.exp(-b0*(d2-d1)) + np.exp(-b0*(d3-d1)) + np.exp(-b0*(d4-d1)))/4) + l0
# l4 = l2 + d1 - 1/b0 * np.log((1 + np.exp(-b0*d1) + np.exp(-b0*1.5*d1) + np.exp(-b0*4*d1))/4) + l0
# print(f'l0:{l0:.3f}\nl1:{l1:.3f}\nl2:{l2:.3f}\nl3:{l3:.3f}\nl4:{l4:.3f}\nl2-l1:{l2+l0-l1:.3f}\nl3-l1:{l3-l1:.3f}\nl4-l1:{l4-l1:.3f}')

# %% [markdown]
# ### Create dataset

# %%
# function to generate logsum dataset
def logsum_dataset(n_curves, b_min, b_max, b_grow, D_min_range, D_max_scale, len_Darray_range, approx_log_sum_flr, io_scale):
    b_array = createBetaArray(b_min, b_max, b_grow)
    n_beta_per_curve = len(b_array)
    n_data = n_curves * n_beta_per_curve
    In = torch.zeros((n_data, 3), dtype=torch.float32)
    Out = torch.zeros((n_data,1), dtype=torch.float32)
    len_D_ARR = []

    cnt = 0
    for c in range(n_curves):
        
        len_Darray = int(np.random.uniform(len_Darray_range[0], len_Darray_range[1]))
        D0 = np.random.uniform(D_min_range[0], D_min_range[1])
        D_array = np.random.uniform(D0, D_max_scale, len_Darray)
        D_min = np.min(D_array)
        if approx_log_sum_flr:
            F_min = area_approx_F(D_min, D_max_scale, len_Darray, b_min)
        else:
            F_min = logSumExp(D_array, b_min)
        F_min = io_scale * F_min
        F_max = io_scale * D_min

        for b in b_array:
            Fb = io_scale * logSumExp(D_array, b)
            # In[cnt,:] = torch.tensor([F_min, F_max, b])
            In[cnt,:] = torch.tensor([F_min, F_max, myLog(b,10)])
            Out[cnt,:] = torch.tensor([Fb])
            len_D_ARR.append(len_Darray)
            cnt += 1

    return In, Out, len_D_ARR

# %%
# beta limits
b_min = 1e-4
b_max = 1e6
b_grow = 1.1
b_array = createBetaArray(b_min, b_max, b_grow)
print(f'len b_array:\t{b_array.shape}')

# torch input and output arrays
n_curves = 60
len_Darray_range = [10,1000]
D_max_scale = 5.0 
D_min_range = [0.0, D_max_scale] # minimum value of D_array is picked at random from this range
IO_scale = 1

In, Out, len_D_ARR = logsum_dataset(n_curves, b_min, b_max, b_grow, D_min_range, D_max_scale, len_Darray_range, approx_log_sum_flr=False, io_scale=IO_scale)
print(f'In:\t{In.size()}\nOut:\t{Out.size()}\nlen_D_ARR\tsize:{len(len_D_ARR)}\tmin:{np.min(len_D_ARR)}\tmax:{np.max(len_D_ARR)}\tmean:{np.mean(len_D_ARR)}')
# Out:
# len b_array:	(243,)
# In:	torch.Size([14580, 3])
# Out:	torch.Size([14580, 1])
# len_D_ARR	size:14580	min:16	max:999	mean:474.56666666666666

# %% [markdown]
# ### Visualize Data

# %%
def visualizeData(In, Out, n_end):

    plt.figure(figsize=(12,8))

    plt.subplot(2,2,1)
    plt.plot(In[:n_end,0], label='F_min')
    plt.legend()
    plt.grid()

    plt.subplot(2,2,2)
    plt.plot(In[:n_end,1], label='F_max')
    plt.legend()
    plt.grid()

    plt.subplot(2,2,3)
    plt.plot(In[:n_end,2], label='log beta')
    plt.legend()
    plt.grid()

    plt.subplot(2,2,4)
    plt.plot(In[:n_end,0], label='F_min', linestyle='dashed', linewidth=2)
    plt.plot(In[:n_end,1], label='F_max', linestyle='dashed', linewidth=2)
    plt.plot(Out[:n_end], label='F_beta')
    plt.legend()
    plt.grid()

    plt.figure(figsize=(12,2))
    plt.hist(In[:,1].numpy().flatten(), bins=10, density=True, histtype='barstacked', rwidth=0.8, label='d_min')
    plt.hist(In[:,0].numpy().flatten(), bins=10, density=True, histtype='barstacked', rwidth=0.8, label='F_min')
    plt.legend()

    plt.show()

visualizeData(In, Out, n_end=20000)

# %% [markdown]
# ### Create neural net for training

# %%
importlib.reload(LSE_net)

# create DNN
n_inputs = In.size()[1]
n_outputs = Out.size()[1]
layers = [20, 20, 10]
NN_logSum = LSE_net.dnn(n_inputs, n_outputs, layers)
print(f'DNN model:\n{NN_logSum}')

# create training, and testing dataset
n_samples = In.size()[0]
frac_train = 0.9
n_train = int(frac_train * n_samples)
indices = torch.arange(n_samples)
train_indices = indices[:n_train]
test_indices = indices[n_train:]
In_train = In[train_indices]
Out_train = Out[train_indices]
In_test = In[test_indices]
Out_test = Out[test_indices]
# Out:
# DNN model:
# dnn(
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=20, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=20, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )

# %%
In[1:2]
# Out:
# tensor([[ 3.7565,  2.5793, -3.9586]])

# %%
NN_logSum(In[1:2]).detach().numpy()
# Out:
# array([[1.6150032]], dtype=float32)

# %%
visualizeData(In_train, Out_train, n_end=5000)
visualizeData(In_test, Out_test, n_end=5000)

# %%
print(D_max_scale)
# Out:
# 5.0

# %% [markdown]
# ### train the network

# %%
# dnn configuration
optimizer_name = 'adam'
lr_scheduler = 'ReduceLROnPlateau'
lr0 = 0.0001
epochs = 200
batch_size = 70
loss_coeffs = [1.0, 0.0]
loss_fn, optimizer, scheduler = LSE_net.config_nn(NN_logSum, optimizer_name, lr_scheduler, lr0)
loss = loss_fn(NN_logSum(In_train[0:1]), Out_train[0]).detach().item()
training_loss, learning_rate, stopping_epoch = LSE_net.train_nn1(
    NN_logSum, In_train, Out_train, loss_fn,
    optimizer, scheduler, loss_coeffs=loss_coeffs,
    epochs=epochs, batch_size=batch_size, shuffledata=True, allowPrint=True)
# Out:
# /Users/dhananjaytiwari/Library/Python/3.9/lib/python/site-packages/torch/nn/modules/loss.py:610: UserWarning: Using a target size (torch.Size([1])) that is different to the input size (torch.Size([1, 1])). This will likely lead to incorrect results due to broadcasting. Please ensure they have the same size.
#   return F.mse_loss(input, target, reduction=self.reduction)
# ---------------------------------
# training data size = 13122
# training batch size = 70
# n_epochs = 200
# n_batches = 188
# loss weights = [1.0, 0.0]
# ---------------------------------
#
# batch_split
# 0 69
# 70 139
# 140 209
# 210 279
# 280 349
# 350 419
# 420 489
# 490 559
# 560 629
# 630 699
# 700 769
# 770 839
# 840 909
# 910 979
# 980 1049
# 1050 1119
# 1120 1189
# 1190 1259
# 1260 1329
# 1330 1399
# 1400 1469
# 1470 1539
# 1540 1609
# 1610 1679
# 1680 1749
# 1750 1819
# 1820 1889
# 1890 1959
# 1960 2029
# 2030 2099
# 2100 2169
# 2170 2239
# 2240 2309
# 2310 2379
# 2380 2449
# 2450 2519
# 2520 2589
# 2590 2659
# 2660 2729
# 2730 2799
# 2800 2869
# 2870 2939
# 2940 3009
# 3010 3079
# 3080 3149
# 3150 3219
# 3220 3289
# 3290 3359
# 3360 3429
# 3430 3499
# 3500 3569
# 3570 3639
# 3640 3709
# 3710 3779
# 3780 3849
# 3850 3919
# 3920 3989
# 3990 4059
# 4060 4129
# 4130 4199
# 4200 4269
# 4270 4339
# 4340 4409
# 4410 4479
# 4480 4549
# 4550 4619
# 4620 4689
# 4690 4759
# 4760 4829
# 4830 4899
# 4900 4969
# 4970 5039
# 5040 5109
# 5110 5179
# 5180 5249
# 5250 5319
# 5320 5389
# 5390 5459
# 5460 5529
# 5530 5599
# 5600 5669
# 5670 5739
# 5740 5809
# 5810 5879
# 5880 5949
# 5950 6019
# 6020 6089
# 6090 6159
# 6160 6229
# 6230 6299
# 6300 6369
# 6370 6439
# 6440 6509
# 6510 6579
# 6580 6649
# 6650 6719
# 6720 6789
# 6790 6859
# 6860 6929
# 6930 6999
# 7000 7069
# 7070 7139
# 7140 7209
# 7210 7279
# 7280 7349
# 7350 7419
# 7420 7489
# 7490 7559
# 7560 7629
# 7630 7699
# 7700 7769
# 7770 7839
# 7840 7909
# 7910 7979
# 7980 8049
# 8050 8119
# 8120 8189
# 8190 8259
# 8260 8329
# 8330 8399
# 8400 8469
# 8470 8539
# 8540 8609
# 8610 8679
# 8680 8749
# 8750 8819
# 8820 8889
# 8890 8959
# 8960 9029
# 9030 9099
# 9100 9169
# 9170 9239
# 9240 9309
# 9310 9379
# 9380 9449
# 9450 9519
# 9520 9589
# 9590 9659
# 9660 9729
# 9730 9799
# 9800 9869
# 9870 9939
# 9940 10009
# 10010 10079
# 10080 10149
# 10150 10219
# 10220 10289
# 10290 10359
# 10360 10429
# 10430 10499
# 10500 10569
# 10570 10639
# 10640 10709
# 10710 10779
# 10780 10849
# 10850 10919
# 10920 10989
# 10990 11059
# 11060 11129
# 11130 11199
# 11200 11269
# 11270 11339
# 11340 11409
# 11410 11479
# 11480 11549
# 11550 11619
# 11620 11689
# 11690 11759
# 11760 11829
# 11830 11899
# 11900 11969
# 11970 12039
# 12040 12109
# 12110 12179
# 12180 12249
# 12250 12319
# 12320 12389
# 12390 12459
# 12460 12529
# 12530 12599
# 12600 12669
# 12670 12739
# 12740 12809
# 12810 12879
# 12880 12949
# 12950 13019
# 13020 13089
# 13090 13121
#
#
#
# ---------------------------------
# epoch: 0/200, 	 loss: 986.954 	 rel:1.000e+03, 	 time: 0.29
# epoch: 1/200, 	 loss: 986.954 	 rel:1.000e+03, 	 time: 0.29
# epoch: 2/200, 	 loss: 184.047 	 rel:1.865e+02, 	 time: 0.20
# epoch: 3/200, 	 loss: 84.324 	 rel:8.544e+01, 	 time: 0.22
# epoch: 4/200, 	 loss: 55.293 	 rel:5.602e+01, 	 time: 0.20
# epoch: 5/200, 	 loss: 38.901 	 rel:3.942e+01, 	 time: 0.22
# epoch: 6/200, 	 loss: 27.886 	 rel:2.825e+01, 	 time: 0.21
# epoch: 7/200, 	 loss: 20.310 	 rel:2.058e+01, 	 time: 0.20
# epoch: 8/200, 	 loss: 14.561 	 rel:1.475e+01, 	 time: 0.20
# epoch: 9/200, 	 loss: 11.246 	 rel:1.139e+01, 	 time: 0.20
# epoch: 10/200, 	 loss: 8.770 	 rel:8.886e+00, 	 time: 0.20
# epoch: 11/200, 	 loss: 6.970 	 rel:7.062e+00, 	 time: 0.20
# epoch: 12/200, 	 loss: 5.633 	 rel:5.708e+00, 	 time: 0.20
# epoch: 13/200, 	 loss: 4.478 	 rel:4.537e+00, 	 time: 0.20
# epoch: 14/200, 	 loss: 3.659 	 rel:3.707e+00, 	 time: 0.21
# epoch: 15/200, 	 loss: 3.186 	 rel:3.228e+00, 	 time: 0.21
# epoch: 16/200, 	 loss: 2.813 	 rel:2.850e+00, 	 time: 0.20
# epoch: 17/200, 	 loss: 2.377 	 rel:2.409e+00, 	 time: 0.20
# epoch: 18/200, 	 loss: 2.166 	 rel:2.194e+00, 	 time: 0.20
# epoch: 19/200, 	 loss: 1.942 	 rel:1.967e+00, 	 time: 0.23
# epoch: 20/200, 	 loss: 1.650 	 rel:1.671e+00, 	 time: 0.20
# epoch: 21/200, 	 loss: 1.441 	 rel:1.460e+00, 	 time: 0.21
# epoch: 22/200, 	 loss: 1.242 	 rel:1.258e+00, 	 time: 0.33
# epoch: 23/200, 	 loss: 1.104 	 rel:1.118e+00, 	 time: 0.26
# epoch: 24/200, 	 loss: 0.931 	 rel:9.437e-01, 	 time: 0.27
# epoch: 25/200, 	 loss: 0.821 	 rel:8.321e-01, 	 time: 0.27
# epoch: 26/200, 	 loss: 0.697 	 rel:7.061e-01, 	 time: 0.27
# epoch: 27/200, 	 loss: 0.614 	 rel:6.223e-01, 	 time: 0.26
# epoch: 28/200, 	 loss: 0.562 	 rel:5.693e-01, 	 time: 0.27
# epoch: 29/200, 	 loss: 0.498 	 rel:5.048e-01, 	 time: 0.27
# epoch: 30/200, 	 loss: 0.453 	 rel:4.593e-01, 	 time: 0.27
# epoch: 31/200, 	 loss: 0.407 	 rel:4.128e-01, 	 time: 0.27
# epoch: 32/200, 	 loss: 0.382 	 rel:3.875e-01, 	 time: 0.27
# epoch: 33/200, 	 loss: 0.353 	 rel:3.573e-01, 	 time: 0.27
# epoch: 34/200, 	 loss: 0.326 	 rel:3.301e-01, 	 time: 0.27
# epoch: 35/200, 	 loss: 0.293 	 rel:2.965e-01, 	 time: 0.27
# epoch: 36/200, 	 loss: 0.272 	 rel:2.757e-01, 	 time: 0.27
# epoch: 37/200, 	 loss: 0.249 	 rel:2.526e-01, 	 time: 0.27
# epoch: 38/200, 	 loss: 0.230 	 rel:2.328e-01, 	 time: 0.27
# epoch: 39/200, 	 loss: 0.219 	 rel:2.220e-01, 	 time: 0.27
# epoch: 40/200, 	 loss: 0.194 	 rel:1.965e-01, 	 time: 0.27
# epoch: 41/200, 	 loss: 0.173 	 rel:1.753e-01, 	 time: 0.27
# epoch: 42/200, 	 loss: 0.162 	 rel:1.640e-01, 	 time: 0.27
# epoch: 43/200, 	 loss: 0.153 	 rel:1.547e-01, 	 time: 0.27
# epoch: 44/200, 	 loss: 0.138 	 rel:1.403e-01, 	 time: 0.27
# epoch: 45/200, 	 loss: 0.129 	 rel:1.311e-01, 	 time: 0.27
# epoch: 46/200, 	 loss: 0.122 	 rel:1.237e-01, 	 time: 0.27
# epoch: 47/200, 	 loss: 0.117 	 rel:1.183e-01, 	 time: 0.27
# epoch: 48/200, 	 loss: 0.114 	 rel:1.160e-01, 	 time: 0.27
# epoch: 49/200, 	 loss: 0.109 	 rel:1.101e-01, 	 time: 0.27
# epoch: 50/200, 	 loss: 0.103 	 rel:1.039e-01, 	 time: 0.27
# epoch: 51/200, 	 loss: 0.096 	 rel:9.759e-02, 	 time: 0.27
# epoch: 52/200, 	 loss: 0.092 	 rel:9.301e-02, 	 time: 0.26
# epoch: 53/200, 	 loss: 0.090 	 rel:9.093e-02, 	 time: 0.27
# epoch: 54/200, 	 loss: 0.083 	 rel:8.455e-02, 	 time: 0.28
# epoch: 55/200, 	 loss: 0.078 	 rel:7.917e-02, 	 time: 0.40
# epoch: 56/200, 	 loss: 0.077 	 rel:7.771e-02, 	 time: 0.28
# epoch: 57/200, 	 loss: 0.075 	 rel:7.559e-02, 	 time: 0.28
# epoch: 58/200, 	 loss: 0.073 	 rel:7.355e-02, 	 time: 0.28
# epoch: 59/200, 	 loss: 0.073 	 rel:7.361e-02, 	 time: 0.28
# epoch: 60/200, 	 loss: 0.067 	 rel:6.742e-02, 	 time: 0.27
# epoch: 61/200, 	 loss: 0.065 	 rel:6.576e-02, 	 time: 0.28
# epoch: 62/200, 	 loss: 0.064 	 rel:6.479e-02, 	 time: 0.27
# epoch: 63/200, 	 loss: 0.061 	 rel:6.209e-02, 	 time: 0.28
# epoch: 64/200, 	 loss: 0.058 	 rel:5.922e-02, 	 time: 0.28
# epoch: 65/200, 	 loss: 0.058 	 rel:5.856e-02, 	 time: 0.27
# epoch: 66/200, 	 loss: 0.057 	 rel:5.786e-02, 	 time: 0.27
# epoch: 67/200, 	 loss: 0.056 	 rel:5.702e-02, 	 time: 0.27
# epoch: 68/200, 	 loss: 0.052 	 rel:5.274e-02, 	 time: 0.34
# epoch: 69/200, 	 loss: 0.054 	 rel:5.437e-02, 	 time: 0.30
# epoch: 70/200, 	 loss: 0.052 	 rel:5.268e-02, 	 time: 0.31
# epoch: 71/200, 	 loss: 0.052 	 rel:5.267e-02, 	 time: 0.29
# epoch: 72/200, 	 loss: 0.049 	 rel:4.978e-02, 	 time: 0.30
# epoch: 73/200, 	 loss: 0.049 	 rel:4.994e-02, 	 time: 0.28
# epoch: 74/200, 	 loss: 0.048 	 rel:4.833e-02, 	 time: 0.27
# epoch: 75/200, 	 loss: 0.045 	 rel:4.530e-02, 	 time: 0.28
# epoch: 76/200, 	 loss: 0.046 	 rel:4.655e-02, 	 time: 0.27
# epoch: 77/200, 	 loss: 0.045 	 rel:4.524e-02, 	 time: 0.27
# epoch: 78/200, 	 loss: 0.044 	 rel:4.493e-02, 	 time: 0.27
# epoch: 79/200, 	 loss: 0.042 	 rel:4.275e-02, 	 time: 0.27
# epoch: 80/200, 	 loss: 0.042 	 rel:4.240e-02, 	 time: 0.27
# epoch: 81/200, 	 loss: 0.041 	 rel:4.140e-02, 	 time: 0.27
# epoch: 82/200, 	 loss: 0.039 	 rel:3.973e-02, 	 time: 0.27
# epoch: 83/200, 	 loss: 0.038 	 rel:3.852e-02, 	 time: 0.27
# epoch: 84/200, 	 loss: 0.039 	 rel:3.931e-02, 	 time: 0.27
# epoch: 85/200, 	 loss: 0.038 	 rel:3.849e-02, 	 time: 0.27
# epoch: 86/200, 	 loss: 0.037 	 rel:3.729e-02, 	 time: 0.27
# epoch: 87/200, 	 loss: 0.037 	 rel:3.728e-02, 	 time: 0.27
# epoch: 88/200, 	 loss: 0.036 	 rel:3.638e-02, 	 time: 0.29
# epoch: 89/200, 	 loss: 0.036 	 rel:3.636e-02, 	 time: 0.29
# epoch: 90/200, 	 loss: 0.034 	 rel:3.450e-02, 	 time: 0.30
# epoch: 91/200, 	 loss: 0.035 	 rel:3.517e-02, 	 time: 0.30
# epoch: 92/200, 	 loss: 0.034 	 rel:3.407e-02, 	 time: 0.29
# epoch: 93/200, 	 loss: 0.033 	 rel:3.331e-02, 	 time: 0.29
# epoch: 94/200, 	 loss: 0.032 	 rel:3.232e-02, 	 time: 0.53
# epoch: 95/200, 	 loss: 0.032 	 rel:3.286e-02, 	 time: 0.31
# epoch: 96/200, 	 loss: 0.031 	 rel:3.180e-02, 	 time: 0.28
# epoch: 97/200, 	 loss: 0.031 	 rel:3.148e-02, 	 time: 0.33
# epoch: 98/200, 	 loss: 0.031 	 rel:3.116e-02, 	 time: 0.30
# epoch: 99/200, 	 loss: 0.030 	 rel:3.030e-02, 	 time: 0.47
# epoch: 100/200, 	 loss: 0.030 	 rel:3.020e-02, 	 time: 0.31
# epoch: 101/200, 	 loss: 0.029 	 rel:2.897e-02, 	 time: 0.29
# epoch: 102/200, 	 loss: 0.029 	 rel:2.914e-02, 	 time: 0.27
# epoch: 103/200, 	 loss: 0.028 	 rel:2.839e-02, 	 time: 0.27
# epoch: 104/200, 	 loss: 0.028 	 rel:2.878e-02, 	 time: 0.27
# epoch: 105/200, 	 loss: 0.027 	 rel:2.770e-02, 	 time: 0.26
# epoch: 106/200, 	 loss: 0.027 	 rel:2.768e-02, 	 time: 0.26
# epoch: 107/200, 	 loss: 0.027 	 rel:2.696e-02, 	 time: 0.25
# epoch: 108/200, 	 loss: 0.028 	 rel:2.790e-02, 	 time: 0.25
# epoch: 109/200, 	 loss: 0.027 	 rel:2.776e-02, 	 time: 0.25
# epoch: 110/200, 	 loss: 0.026 	 rel:2.661e-02, 	 time: 0.26
# epoch: 111/200, 	 loss: 0.026 	 rel:2.674e-02, 	 time: 0.26
# epoch: 112/200, 	 loss: 0.026 	 rel:2.638e-02, 	 time: 0.26
# epoch: 113/200, 	 loss: 0.026 	 rel:2.630e-02, 	 time: 0.26
# epoch: 114/200, 	 loss: 0.025 	 rel:2.562e-02, 	 time: 0.25
# epoch: 115/200, 	 loss: 0.025 	 rel:2.492e-02, 	 time: 0.25
# epoch: 116/200, 	 loss: 0.025 	 rel:2.513e-02, 	 time: 0.25
# epoch: 117/200, 	 loss: 0.026 	 rel:2.598e-02, 	 time: 0.25
# epoch: 118/200, 	 loss: 0.025 	 rel:2.570e-02, 	 time: 0.25
# epoch: 119/200, 	 loss: 0.025 	 rel:2.520e-02, 	 time: 0.25
# epoch: 120/200, 	 loss: 0.025 	 rel:2.510e-02, 	 time: 0.25
# epoch: 121/200, 	 loss: 0.023 	 rel:2.369e-02, 	 time: 0.25
# epoch: 122/200, 	 loss: 0.024 	 rel:2.382e-02, 	 time: 0.25
# epoch: 123/200, 	 loss: 0.023 	 rel:2.362e-02, 	 time: 0.26
# epoch: 124/200, 	 loss: 0.024 	 rel:2.386e-02, 	 time: 0.26
# epoch: 125/200, 	 loss: 0.022 	 rel:2.274e-02, 	 time: 0.25
# epoch: 126/200, 	 loss: 0.023 	 rel:2.340e-02, 	 time: 0.25
# epoch: 127/200, 	 loss: 0.023 	 rel:2.326e-02, 	 time: 0.31
# epoch: 128/200, 	 loss: 0.023 	 rel:2.285e-02, 	 time: 0.28
# epoch: 129/200, 	 loss: 0.022 	 rel:2.258e-02, 	 time: 0.26
# epoch: 130/200, 	 loss: 0.022 	 rel:2.250e-02, 	 time: 0.25
# epoch: 131/200, 	 loss: 0.022 	 rel:2.272e-02, 	 time: 0.31
# epoch: 132/200, 	 loss: 0.022 	 rel:2.234e-02, 	 time: 0.43
# epoch: 133/200, 	 loss: 0.021 	 rel:2.144e-02, 	 time: 0.40
# epoch: 134/200, 	 loss: 0.021 	 rel:2.172e-02, 	 time: 0.50
# epoch: 135/200, 	 loss: 0.021 	 rel:2.167e-02, 	 time: 1.13
# epoch: 136/200, 	 loss: 0.021 	 rel:2.150e-02, 	 time: 0.69
# epoch: 137/200, 	 loss: 0.021 	 rel:2.142e-02, 	 time: 0.39
# epoch: 138/200, 	 loss: 0.021 	 rel:2.121e-02, 	 time: 0.32
# epoch: 139/200, 	 loss: 0.020 	 rel:2.071e-02, 	 time: 0.27
# epoch: 140/200, 	 loss: 0.020 	 rel:2.011e-02, 	 time: 0.26
# epoch: 141/200, 	 loss: 0.020 	 rel:2.046e-02, 	 time: 0.26
# epoch: 142/200, 	 loss: 0.021 	 rel:2.079e-02, 	 time: 0.26
# epoch: 143/200, 	 loss: 0.021 	 rel:2.092e-02, 	 time: 0.26
# epoch: 144/200, 	 loss: 0.020 	 rel:2.043e-02, 	 time: 0.29
# epoch: 145/200, 	 loss: 0.020 	 rel:2.024e-02, 	 time: 0.28
# epoch: 146/200, 	 loss: 0.020 	 rel:1.984e-02, 	 time: 0.30
# epoch: 147/200, 	 loss: 0.020 	 rel:2.019e-02, 	 time: 0.26
# epoch: 148/200, 	 loss: 0.020 	 rel:2.016e-02, 	 time: 0.25
# epoch: 149/200, 	 loss: 0.020 	 rel:1.999e-02, 	 time: 0.25
# epoch: 150/200, 	 loss: 0.019 	 rel:1.943e-02, 	 time: 0.26
# epoch: 151/200, 	 loss: 0.020 	 rel:1.988e-02, 	 time: 0.26
# epoch: 152/200, 	 loss: 0.019 	 rel:1.961e-02, 	 time: 0.26
# epoch: 153/200, 	 loss: 0.019 	 rel:1.923e-02, 	 time: 0.30
# epoch: 154/200, 	 loss: 0.019 	 rel:1.941e-02, 	 time: 0.27
# epoch: 155/200, 	 loss: 0.019 	 rel:1.905e-02, 	 time: 0.26
# epoch: 156/200, 	 loss: 0.018 	 rel:1.870e-02, 	 time: 0.26
# epoch: 157/200, 	 loss: 0.019 	 rel:1.877e-02, 	 time: 0.26
# epoch: 158/200, 	 loss: 0.019 	 rel:1.876e-02, 	 time: 0.26
# epoch: 159/200, 	 loss: 0.018 	 rel:1.866e-02, 	 time: 0.25
# epoch: 160/200, 	 loss: 0.019 	 rel:1.906e-02, 	 time: 0.26
# epoch: 161/200, 	 loss: 0.018 	 rel:1.874e-02, 	 time: 0.26
# epoch: 162/200, 	 loss: 0.018 	 rel:1.807e-02, 	 time: 0.25
# epoch: 163/200, 	 loss: 0.019 	 rel:1.944e-02, 	 time: 0.25
# epoch: 164/200, 	 loss: 0.018 	 rel:1.784e-02, 	 time: 0.25
# epoch: 165/200, 	 loss: 0.018 	 rel:1.809e-02, 	 time: 0.25
# epoch: 166/200, 	 loss: 0.018 	 rel:1.813e-02, 	 time: 0.25
# epoch: 167/200, 	 loss: 0.018 	 rel:1.797e-02, 	 time: 0.26
# epoch: 168/200, 	 loss: 0.017 	 rel:1.742e-02, 	 time: 0.26
# epoch: 169/200, 	 loss: 0.018 	 rel:1.833e-02, 	 time: 0.25
# epoch: 170/200, 	 loss: 0.017 	 rel:1.759e-02, 	 time: 0.25
# epoch: 171/200, 	 loss: 0.017 	 rel:1.758e-02, 	 time: 0.25
# epoch: 172/200, 	 loss: 0.017 	 rel:1.738e-02, 	 time: 0.31
# epoch: 173/200, 	 loss: 0.017 	 rel:1.734e-02, 	 time: 0.27
# epoch: 174/200, 	 loss: 0.017 	 rel:1.766e-02, 	 time: 0.27
# epoch: 175/200, 	 loss: 0.017 	 rel:1.721e-02, 	 time: 0.26
# epoch: 176/200, 	 loss: 0.017 	 rel:1.721e-02, 	 time: 0.26
# epoch: 177/200, 	 loss: 0.017 	 rel:1.736e-02, 	 time: 0.26
# epoch: 178/200, 	 loss: 0.016 	 rel:1.652e-02, 	 time: 0.37
# epoch: 179/200, 	 loss: 0.017 	 rel:1.704e-02, 	 time: 0.26
# epoch: 180/200, 	 loss: 0.017 	 rel:1.683e-02, 	 time: 0.26
# epoch: 181/200, 	 loss: 0.017 	 rel:1.672e-02, 	 time: 0.25
# epoch: 182/200, 	 loss: 0.017 	 rel:1.694e-02, 	 time: 0.25
# epoch: 183/200, 	 loss: 0.016 	 rel:1.635e-02, 	 time: 0.25
# epoch: 184/200, 	 loss: 0.017 	 rel:1.699e-02, 	 time: 0.25
# epoch: 185/200, 	 loss: 0.016 	 rel:1.664e-02, 	 time: 0.25
# epoch: 186/200, 	 loss: 0.016 	 rel:1.633e-02, 	 time: 0.35
# epoch: 187/200, 	 loss: 0.016 	 rel:1.645e-02, 	 time: 0.28
# epoch: 188/200, 	 loss: 0.016 	 rel:1.645e-02, 	 time: 0.32
# epoch: 189/200, 	 loss: 0.016 	 rel:1.600e-02, 	 time: 0.31
# epoch: 190/200, 	 loss: 0.016 	 rel:1.660e-02, 	 time: 0.30
# epoch: 191/200, 	 loss: 0.016 	 rel:1.616e-02, 	 time: 0.27
# epoch: 192/200, 	 loss: 0.016 	 rel:1.611e-02, 	 time: 0.27
# epoch: 193/200, 	 loss: 0.016 	 rel:1.616e-02, 	 time: 0.27
# epoch: 194/200, 	 loss: 0.015 	 rel:1.557e-02, 	 time: 0.26
# epoch: 195/200, 	 loss: 0.016 	 rel:1.612e-02, 	 time: 0.26
# epoch: 196/200, 	 loss: 0.016 	 rel:1.604e-02, 	 time: 0.25
# epoch: 197/200, 	 loss: 0.016 	 rel:1.573e-02, 	 time: 0.26
# epoch: 198/200, 	 loss: 0.016 	 rel:1.583e-02, 	 time: 0.26
# epoch: 199/200, 	 loss: 0.015 	 rel:1.529e-02, 	 time: 0.25
# epoch: 200/200, 	 loss: 0.015 	 rel:1.533e-02, 	 time: 0.25
# Maximum Iterations Reached
# ---------------------------------

# %% [markdown]
# ### Store the trained network data

# %%
trained_lse_info = {
    'model_state_dict': NN_logSum.state_dict(), 
    'n_inputs':n_inputs,
    'n_outputs':n_outputs,
    'layers':layers,
    'b_arr':b_array, 
    'len_Darray_range':len_Darray_range, 
    'D_min_range':D_min_range,
    'D_max_range':D_max_scale,
    'io_scale':IO_scale,
    'n_samples':n_samples,
    'frac_train':frac_train,
    'optimizer_name':optimizer,
    'optimize_state_dict':optimizer.state_dict(),
    'lr_scheduler':lr_scheduler,
    'lr0':lr0,
    'loss_fn':loss_fn,
    'epochs':epochs,
    'batch_size':batch_size,
    'training_loss':training_loss,
    'learning_rate':learning_rate,
}

# %% [markdown]
# ### Save the trained model

# %%
# str(datetime.datetime.today()).split()
current_time = datetime.datetime.now()
yyyy = str(current_time.year)
mm = str(current_time.month)
dd = str(current_time.day)
hh = str(current_time.hour)
mt = str(current_time.minute)
sec = str(current_time.second)
current_datetime = yyyy + '_' + mm + '_' + dd + '__' + hh + '_' + mt + '_' + sec 
print(f'trained_network_data_name: {current_datetime}')
# Out:
# trained_network_data_name: 2025_5_19__15_47_58

# %%
filename = 'logSumExp_models/lse_' + current_datetime + '.pth'

torch.save(trained_lse_info, filename)

# %% [markdown]
# ### plot training loss and learning rate

# %%
plt.figure(figsize=(10,2))
plt.subplot(1,2,1)
plt.plot(training_loss)
plt.title('training_loss')
plt.grid()
plt.subplot(1,2,2)
plt.plot(learning_rate)
plt.title('learning_rate')
plt.grid()

plt.show()

# %% [markdown]
# ### Evaluate the network on a validation dataset

# %%
# np.random.seed(10)
b_min_v = b_array[0]*1
b_max_v = b_array[-1]*1
b_grow_v = 1.05
b_array_v = createBetaArray(b_min_v, b_max_v, b_grow_v)
# print(b_array_v)
n_curves_v = 10
D_max_scale_v = 5.0
D_min_range_v = [0.0, D_max_scale_v]
len_Darray_range_v = [100,1000]
In_val, Out_val, len_D_ARR_v = logsum_dataset(n_curves=n_curves_v, 
                    b_min=b_min_v, b_max=b_max_v, b_grow=b_grow_v, D_min_range=D_min_range_v, 
                    D_max_scale=D_max_scale_v, 
                    len_Darray_range=len_Darray_range_v, 
                    approx_log_sum_flr=True, io_scale=IO_scale)
pred_val = NN_logSum(In_val).detach()

st = 0
Out_val_np = (Out_val.numpy().flatten()/IO_scale)[st:] - 0*(1 / np.tile(b_array_v, n_curves_v) * np.log(len_D_ARR_v))[st:] + 0*(In_val[:,1].numpy().flatten()/IO_scale)[st:]
pred_val_np = (pred_val.numpy().flatten()/IO_scale)[st:] - 0*(1 / np.tile(b_array_v, n_curves_v) * np.log(len_D_ARR_v))[st:] + 0*(In_val[:,1].numpy().flatten()/IO_scale)[st:]

plt.figure(figsize=(12,4))
plt.subplot(2,1,1)
plt.plot(Out_val_np, label='target', color='violet', linestyle='dashed', linewidth=3)
plt.plot(pred_val_np, label='prediction', color='black')
plt.grid()
plt.xticks()
plt.legend()

plt.subplot(2,1,2)
error_val = np.abs(pred_val_np - Out_val_np)/np.mean(Out_val_np)
plt.plot(error_val, label='error', color='red')
plt.legend()
plt.grid()

plt.figure(figsize=(12,2))
plt.hist(In_val[:,1].numpy().flatten(), bins=10, histtype='barstacked', rwidth=0.8, label='d_min')
plt.hist(In_val[:,0].numpy().flatten(), bins=10, histtype='barstacked', rwidth=0.8, label='F_min')
plt.legend()

plt.show()

# %%
Out_val_np.shape
# Out:
# (23160,)

# %%
b_array_v.shape
# Out:
# (2316,)

# %%
np.tile(b_array_v, n_curves_v).shape
# Out:
# (1120,)
