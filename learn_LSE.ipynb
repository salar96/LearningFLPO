# %%
import numpy as np
import matplotlib.pyplot as plt
import LSE_net
import torch
import importlib
import pickle
import datetime

# %%
def myLog(x, base):
    return np.log(x)/np.log(base)

def createBetaArray(min, max, grow):
    beta = min
    beta_array = [beta]
    while beta <= max:
        beta = beta*grow
        beta_array.append(beta)
    beta_array = np.array(beta_array)
    return beta_array

def logSumExp(D_array, beta):
    D_min = np.min(D_array)
    D_off = D_array - D_min
    F = -1/beta * np.log(np.sum(np.exp(-beta*D_off))/len(D_array))
    # F = -np.log(np.sum(np.exp(-beta*D_off))) + np.log(len(D_array)) + D_min * beta
    return F

# %%
np.random.seed(10)
D_array = np.random.uniform(10,100,20)
print(D_array.min())
beta0 = 1
logSumExp(D_array, beta0)
# Out:
# 10.355343969512301
# 2.7961450054117143

# %%
d1 = 10
d2 = 30
d3 = 40
d4 = 50
b0 = 1e-5
l0 = 1/b0 * np.log(4)
l1 = -1/b0 * np.log(np.exp(-b0*d1) + np.exp(-b0*d2) + np.exp(-b0*d3) + np.exp(-b0*d4)) + l0
l2 = -1/b0 * np.log(4)
l3 = l2 + d1 - 1/b0 * np.log((1 + np.exp(-b0*(d2-d1)) + np.exp(-b0*(d3-d1)) + np.exp(-b0*(d4-d1)))/4) + l0
l4 = l2 + d1 - 1/b0 * np.log((1 + np.exp(-b0*d1) + np.exp(-b0*1.5*d1) + np.exp(-b0*4*d1))/4) + l0
print(f'l0:{l0:.3f}\nl1:{l1:.3f}\nl2:{l2:.3f}\nl3:{l3:.3f}\nl4:{l4:.3f}\nl2-l1:{l2+l0-l1:.3f}\nl3-l1:{l3-l1:.3f}\nl4-l1:{l4-l1:.3f}')
# Out:
# l0:138629.436
# l1:32.499
# l2:-138629.436
# l3:32.499
# l4:26.249
# l2-l1:-32.499
# l3-l1:0.000
# l4-l1:-6.250

# %% [markdown]
# ### Create dataset

# %%
# function to generate logsum dataset
def logsum_dataset(n_curves, b_min, b_max, b_grow, D_min_range, D_max_range, len_Darray, approx_log_sum_flr, io_scale):
    b_array = createBetaArray(b_min, b_max, b_grow)
    n_beta_per_curve = len(b_array)
    n_data = n_curves * n_beta_per_curve
    In = torch.zeros((n_data, 3), dtype=torch.float32)
    Out = torch.zeros((n_data,1), dtype=torch.float32)

    cnt = 0
    for c in range(n_curves):
        
        D_min = np.random.uniform(D_min_range[0], D_min_range[1])
        D_max = D_min + np.random.uniform(D_max_range[0], D_max_range[1])
        D_array = np.random.uniform(D_min, D_max, len_Darray)
        if approx_log_sum_flr:
            D_array_dum = np.arange(1,len_Darray+1)*2 + D_min
            F_min = logSumExp(D_array_dum, b_min)
        else:
            F_min = logSumExp(D_array, b_min)
        F_min = io_scale * F_min
        F_max = io_scale * np.min(D_array)

        for b in b_array:
            Fb = io_scale * logSumExp(D_array, b)
            In[cnt,:] = torch.tensor([F_min, F_max, b])
            Out[cnt,:] = torch.tensor([Fb])
            cnt += 1

    return In, Out

# %%
# beta limits
b_min = 1e-4
b_max = 1e5
b_grow = 1.1
b_array = createBetaArray(b_min, b_max, b_grow)
print(f'len b_array: {b_array.shape}')

# torch input and output arrays
n_curves = 200
len_Darray = 200
D_min_range = [0.001, 1] # minimum value of D_array is picked at random from this range
D_max_range = [1, 10] # maximum value of D_array is picked at random from the range dmin + D_max_range
IO_scale = 0.5

In, Out = logsum_dataset(n_curves, b_min, b_max, b_grow, D_min_range, D_max_range, len_Darray, approx_log_sum_flr=False, io_scale=IO_scale)
print(f'In: {In.size()}\tOut: {Out.size()}')
# Out:
# len b_array: (219,)
# In: torch.Size([43800, 3])	Out: torch.Size([43800, 1])

# %% [markdown]
# ### Visualize Data

# %%
def visualizeData(In, Out, n_end):

    plt.figure(figsize=(12,8))

    plt.subplot(2,2,1)
    plt.plot(In[:n_end,0], label='F_min')
    plt.legend()
    plt.grid()

    plt.subplot(2,2,2)
    plt.plot(In[:n_end,1], label='F_max')
    plt.legend()
    plt.grid()

    plt.subplot(2,2,3)
    plt.plot(In[:n_end,2], label='beta')
    plt.legend()
    plt.grid()

    plt.subplot(2,2,4)
    plt.plot(In[:n_end,0], label='F_min', linestyle='dashed', linewidth=2)
    plt.plot(In[:n_end,1], label='F_max', linestyle='dashed', linewidth=2)
    plt.plot(Out[:n_end], label='F_beta')
    plt.legend()
    plt.grid()

    plt.show()

visualizeData(In, Out, n_end=1000)

# %% [markdown]
# ### Create neural net for training

# %%
importlib.reload(LSE_net)

# create DNN
n_inputs = In.size()[1]
n_outputs = Out.size()[1]
layers = [20, 20, 10]
NN_logSum = LSE_net.dnn(n_inputs, n_outputs, layers)
print(f'DNN model:\n{NN_logSum}')

# create training, and testing dataset
n_samples = In.size()[0]
frac_train = 0.7
n_train = int(frac_train * n_samples)
indices = torch.arange(n_samples)
train_indices = indices[:n_train]
test_indices = indices[n_train:]
In_train = In[train_indices]
Out_train = Out[train_indices]
In_test = In[test_indices]
Out_test = Out[test_indices]
# Out:
# DNN model:
# dnn(
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=20, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=20, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )

# %%
In[0]
# Out:
# tensor([2.3302e+00, 4.1128e-01, 1.0000e-04])

# %%
NN_logSum(In).detach().numpy()
# Out:
# array([[-5.2956396e-01],
#        [-5.2956128e-01],
#        [-5.2955729e-01],
#        ...,
#        [-1.3218198e+05],
#        [-1.4540059e+05],
#        [-1.5994103e+05]], dtype=float32)

# %%
visualizeData(In_train, Out_train, n_end=200)
visualizeData(In_test, Out_test, n_end=200)

# %% [markdown]
# ### train the network

# %%
# dnn configuration
optimizer_name = 'adam'
lr_scheduler = 'ReduceLROnPlateau'
lr0 = 0.0005
epochs = 200
batch_size = 70
loss_coeffs = [1.0, 0.0]
loss_fn, optimizer, scheduler = LSE_net.config_nn(NN_logSum, optimizer_name, lr_scheduler, lr0)
loss = loss_fn(NN_logSum(In_train[0]), Out_train[0]).detach().item()
training_loss, learning_rate, stopping_epoch = LSE_net.train_nn1(
    NN_logSum, In_train, Out_train, loss_fn,
    optimizer, scheduler, loss_coeffs=loss_coeffs,
    epochs=epochs, batch_size=batch_size, allowPrint=True)
# Out:
# ---------------------------------
# training data size = 30659
# training batch size = 70
# n_epochs = 200
# n_batches = 438
# loss weights = [1.0, 0.0]
# ---------------------------------
#
# batch_split
# 0 69
# 70 139
# 140 209
# 210 279
# 280 349
# 350 419
# 420 489
# 490 559
# 560 629
# 630 699
# 700 769
# 770 839
# 840 909
# 910 979
# 980 1049
# 1050 1119
# 1120 1189
# 1190 1259
# 1260 1329
# 1330 1399
# 1400 1469
# 1470 1539
# 1540 1609
# 1610 1679
# 1680 1749
# 1750 1819
# 1820 1889
# 1890 1959
# 1960 2029
# 2030 2099
# 2100 2169
# 2170 2239
# 2240 2309
# 2310 2379
# 2380 2449
# 2450 2519
# 2520 2589
# 2590 2659
# 2660 2729
# 2730 2799
# 2800 2869
# 2870 2939
# 2940 3009
# 3010 3079
# 3080 3149
# 3150 3219
# 3220 3289
# 3290 3359
# 3360 3429
# 3430 3499
# 3500 3569
# 3570 3639
# 3640 3709
# 3710 3779
# 3780 3849
# 3850 3919
# 3920 3989
# 3990 4059
# 4060 4129
# 4130 4199
# 4200 4269
# 4270 4339
# 4340 4409
# 4410 4479
# 4480 4549
# 4550 4619
# 4620 4689
# 4690 4759
# 4760 4829
# 4830 4899
# 4900 4969
# 4970 5039
# 5040 5109
# 5110 5179
# 5180 5249
# 5250 5319
# 5320 5389
# 5390 5459
# 5460 5529
# 5530 5599
# 5600 5669
# 5670 5739
# 5740 5809
# 5810 5879
# 5880 5949
# 5950 6019
# 6020 6089
# 6090 6159
# 6160 6229
# 6230 6299
# 6300 6369
# 6370 6439
# 6440 6509
# 6510 6579
# 6580 6649
# 6650 6719
# 6720 6789
# 6790 6859
# 6860 6929
# 6930 6999
# 7000 7069
# 7070 7139
# 7140 7209
# 7210 7279
# 7280 7349
# 7350 7419
# 7420 7489
# 7490 7559
# 7560 7629
# 7630 7699
# 7700 7769
# 7770 7839
# 7840 7909
# 7910 7979
# 7980 8049
# 8050 8119
# 8120 8189
# 8190 8259
# 8260 8329
# 8330 8399
# 8400 8469
# 8470 8539
# 8540 8609
# 8610 8679
# 8680 8749
# 8750 8819
# 8820 8889
# 8890 8959
# 8960 9029
# 9030 9099
# 9100 9169
# 9170 9239
# 9240 9309
# 9310 9379
# 9380 9449
# 9450 9519
# 9520 9589
# 9590 9659
# 9660 9729
# 9730 9799
# 9800 9869
# 9870 9939
# 9940 10009
# 10010 10079
# 10080 10149
# 10150 10219
# 10220 10289
# 10290 10359
# 10360 10429
# 10430 10499
# 10500 10569
# 10570 10639
# 10640 10709
# 10710 10779
# 10780 10849
# 10850 10919
# 10920 10989
# 10990 11059
# 11060 11129
# 11130 11199
# 11200 11269
# 11270 11339
# 11340 11409
# 11410 11479
# 11480 11549
# 11550 11619
# 11620 11689
# 11690 11759
# 11760 11829
# 11830 11899
# 11900 11969
# 11970 12039
# 12040 12109
# 12110 12179
# 12180 12249
# 12250 12319
# 12320 12389
# 12390 12459
# 12460 12529
# 12530 12599
# 12600 12669
# 12670 12739
# 12740 12809
# 12810 12879
# 12880 12949
# 12950 13019
# 13020 13089
# 13090 13159
# 13160 13229
# 13230 13299
# 13300 13369
# 13370 13439
# 13440 13509
# 13510 13579
# 13580 13649
# 13650 13719
# 13720 13789
# 13790 13859
# 13860 13929
# 13930 13999
# 14000 14069
# 14070 14139
# 14140 14209
# 14210 14279
# 14280 14349
# 14350 14419
# 14420 14489
# 14490 14559
# 14560 14629
# 14630 14699
# 14700 14769
# 14770 14839
# 14840 14909
# 14910 14979
# 14980 15049
# 15050 15119
# 15120 15189
# 15190 15259
# 15260 15329
# 15330 15399
# 15400 15469
# 15470 15539
# 15540 15609
# 15610 15679
# 15680 15749
# 15750 15819
# 15820 15889
# 15890 15959
# 15960 16029
# 16030 16099
# 16100 16169
# 16170 16239
# 16240 16309
# 16310 16379
# 16380 16449
# 16450 16519
# 16520 16589
# 16590 16659
# 16660 16729
# 16730 16799
# 16800 16869
# 16870 16939
# 16940 17009
# 17010 17079
# 17080 17149
# 17150 17219
# 17220 17289
# 17290 17359
# 17360 17429
# 17430 17499
# 17500 17569
# 17570 17639
# 17640 17709
# 17710 17779
# 17780 17849
# 17850 17919
# 17920 17989
# 17990 18059
# 18060 18129
# 18130 18199
# 18200 18269
# 18270 18339
# 18340 18409
# 18410 18479
# 18480 18549
# 18550 18619
# 18620 18689
# 18690 18759
# 18760 18829
# 18830 18899
# 18900 18969
# 18970 19039
# 19040 19109
# 19110 19179
# 19180 19249
# 19250 19319
# 19320 19389
# 19390 19459
# 19460 19529
# 19530 19599
# 19600 19669
# 19670 19739
# 19740 19809
# 19810 19879
# 19880 19949
# 19950 20019
# 20020 20089
# 20090 20159
# 20160 20229
# 20230 20299
# 20300 20369
# 20370 20439
# 20440 20509
# 20510 20579
# 20580 20649
# 20650 20719
# 20720 20789
# 20790 20859
# 20860 20929
# 20930 20999
# 21000 21069
# 21070 21139
# 21140 21209
# 21210 21279
# 21280 21349
# 21350 21419
# 21420 21489
# 21490 21559
# 21560 21629
# 21630 21699
# 21700 21769
# 21770 21839
# 21840 21909
# 21910 21979
# 21980 22049
# 22050 22119
# 22120 22189
# 22190 22259
# 22260 22329
# 22330 22399
# 22400 22469
# 22470 22539
# 22540 22609
# 22610 22679
# 22680 22749
# 22750 22819
# 22820 22889
# 22890 22959
# 22960 23029
# 23030 23099
# 23100 23169
# 23170 23239
# 23240 23309
# 23310 23379
# 23380 23449
# 23450 23519
# 23520 23589
# 23590 23659
# 23660 23729
# 23730 23799
# 23800 23869
# 23870 23939
# 23940 24009
# 24010 24079
# 24080 24149
# 24150 24219
# 24220 24289
# 24290 24359
# 24360 24429
# 24430 24499
# 24500 24569
# 24570 24639
# 24640 24709
# 24710 24779
# 24780 24849
# 24850 24919
# 24920 24989
# 24990 25059
# 25060 25129
# 25130 25199
# 25200 25269
# 25270 25339
# 25340 25409
# 25410 25479
# 25480 25549
# 25550 25619
# 25620 25689
# 25690 25759
# 25760 25829
# 25830 25899
# 25900 25969
# 25970 26039
# 26040 26109
# 26110 26179
# 26180 26249
# 26250 26319
# 26320 26389
# 26390 26459
# 26460 26529
# 26530 26599
# 26600 26669
# 26670 26739
# 26740 26809
# 26810 26879
# 26880 26949
# 26950 27019
# 27020 27089
# 27090 27159
# 27160 27229
# 27230 27299
# 27300 27369
# 27370 27439
# 27440 27509
# 27510 27579
# 27580 27649
# 27650 27719
# 27720 27789
# 27790 27859
# 27860 27929
# 27930 27999
# 28000 28069
# 28070 28139
# 28140 28209
# 28210 28279
# 28280 28349
# 28350 28419
# 28420 28489
# 28490 28559
# 28560 28629
# 28630 28699
# 28700 28769
# 28770 28839
# 28840 28909
# 28910 28979
# 28980 29049
# 29050 29119
# 29120 29189
# 29190 29259
# 29260 29329
# 29330 29399
# 29400 29469
# 29470 29539
# 29540 29609
# 29610 29679
# 29680 29749
# 29750 29819
# 29820 29889
# 29890 29959
# 29960 30029
# 30030 30099
# 30100 30169
# 30170 30239
# 30240 30309
# 30310 30379
# 30380 30449
# 30450 30519
# 30520 30589
# 30590 30658
#
#
#
# ---------------------------------
# epoch: 0/200, 	 loss: 22820664.189 	 rel:1.000e+03, 	 time: 0.85
# epoch: 1/200, 	 loss: 22820664.189 	 rel:1.000e+03, 	 time: 0.85
# epoch: 2/200, 	 loss: 4.316 	 rel:1.891e-04, 	 time: 0.75
# epoch: 3/200, 	 loss: 3.348 	 rel:1.467e-04, 	 time: 0.75
# epoch: 4/200, 	 loss: 2.674 	 rel:1.172e-04, 	 time: 0.75
# epoch: 5/200, 	 loss: 2.453 	 rel:1.075e-04, 	 time: 0.75
# epoch: 6/200, 	 loss: 2.330 	 rel:1.021e-04, 	 time: 0.76
# epoch: 7/200, 	 loss: 2.145 	 rel:9.398e-05, 	 time: 0.75
# epoch: 8/200, 	 loss: 38.650 	 rel:1.694e-03, 	 time: 0.75
# epoch: 9/200, 	 loss: 1.554 	 rel:6.812e-05, 	 time: 0.74
# epoch: 10/200, 	 loss: 1.327 	 rel:5.816e-05, 	 time: 0.77
# epoch: 11/200, 	 loss: 1.225 	 rel:5.368e-05, 	 time: 0.80
# epoch: 12/200, 	 loss: 0.624 	 rel:2.736e-05, 	 time: 1.02
# epoch: 13/200, 	 loss: 1.132 	 rel:4.960e-05, 	 time: 1.30
# epoch: 14/200, 	 loss: 0.157 	 rel:6.899e-06, 	 time: 1.17
# epoch: 15/200, 	 loss: 0.642 	 rel:2.812e-05, 	 time: 1.16
# epoch: 16/200, 	 loss: 2.145 	 rel:9.399e-05, 	 time: 1.29
# epoch: 17/200, 	 loss: 0.191 	 rel:8.372e-06, 	 time: 1.21
# epoch: 18/200, 	 loss: 0.464 	 rel:2.031e-05, 	 time: 1.11
# epoch: 19/200, 	 loss: 5.943 	 rel:2.604e-04, 	 time: 1.21
# epoch: 20/200, 	 loss: 1.348 	 rel:5.906e-05, 	 time: 1.15
# epoch: 21/200, 	 loss: 0.239 	 rel:1.046e-05, 	 time: 1.40
# epoch: 22/200, 	 loss: 3.189 	 rel:1.397e-04, 	 time: 1.23
# epoch: 23/200, 	 loss: 3.362 	 rel:1.473e-04, 	 time: 1.68
# epoch: 24/200, 	 loss: 974.455 	 rel:4.270e-02, 	 time: 1.30
# epoch: 25/200, 	 loss: 0.165 	 rel:7.219e-06, 	 time: 1.17
# epoch: 26/200, 	 loss: 325.360 	 rel:1.426e-02, 	 time: 1.42
# epoch: 27/200, 	 loss: 201.143 	 rel:8.814e-03, 	 time: 1.30
# epoch: 28/200, 	 loss: 59.325 	 rel:2.600e-03, 	 time: 1.14
# epoch: 29/200, 	 loss: 3940.821 	 rel:1.727e-01, 	 time: 1.13
# epoch: 30/200, 	 loss: 3.365 	 rel:1.475e-04, 	 time: 1.14
# epoch: 31/200, 	 loss: 27.889 	 rel:1.222e-03, 	 time: 1.14
# epoch: 32/200, 	 loss: 0.399 	 rel:1.749e-05, 	 time: 1.21
# epoch: 33/200, 	 loss: 238.172 	 rel:1.044e-02, 	 time: 1.16
# epoch: 34/200, 	 loss: 91.170 	 rel:3.995e-03, 	 time: 1.17
# epoch: 35/200, 	 loss: 190.279 	 rel:8.338e-03, 	 time: 1.06
# epoch: 36/200, 	 loss: 19838.997 	 rel:8.693e-01, 	 time: 1.13
# epoch: 37/200, 	 loss: 0.163 	 rel:7.156e-06, 	 time: 1.10
# epoch: 38/200, 	 loss: 0.063 	 rel:2.770e-06, 	 time: 1.09
# epoch: 39/200, 	 loss: 0.064 	 rel:2.817e-06, 	 time: 1.12
# epoch: 40/200, 	 loss: 0.060 	 rel:2.642e-06, 	 time: 1.06
# epoch: 41/200, 	 loss: 0.117 	 rel:5.111e-06, 	 time: 1.06
# epoch: 42/200, 	 loss: 0.206 	 rel:9.012e-06, 	 time: 1.13
# epoch: 43/200, 	 loss: 2.667 	 rel:1.169e-04, 	 time: 1.06
# epoch: 44/200, 	 loss: 3.065 	 rel:1.343e-04, 	 time: 1.06
# epoch: 45/200, 	 loss: 2748.768 	 rel:1.205e-01, 	 time: 1.12
# epoch: 46/200, 	 loss: 0.201 	 rel:8.815e-06, 	 time: 1.05
# epoch: 47/200, 	 loss: 0.163 	 rel:7.129e-06, 	 time: 1.06
# epoch: 48/200, 	 loss: 5.678 	 rel:2.488e-04, 	 time: 1.13
# epoch: 49/200, 	 loss: 1894.293 	 rel:8.301e-02, 	 time: 1.07
# epoch: 50/200, 	 loss: 0.207 	 rel:9.058e-06, 	 time: 1.06
# epoch: 51/200, 	 loss: 0.381 	 rel:1.671e-05, 	 time: 1.15
# epoch: 52/200, 	 loss: 324.300 	 rel:1.421e-02, 	 time: 1.07
# epoch: 53/200, 	 loss: 74.953 	 rel:3.284e-03, 	 time: 1.05
# epoch: 54/200, 	 loss: 989.023 	 rel:4.334e-02, 	 time: 1.13
# epoch: 55/200, 	 loss: 56539.036 	 rel:2.478e+00, 	 time: 1.07
# epoch: 56/200, 	 loss: 0.091 	 rel:3.982e-06, 	 time: 1.10
# epoch: 57/200, 	 loss: 0.088 	 rel:3.856e-06, 	 time: 1.31
# epoch: 58/200, 	 loss: 0.086 	 rel:3.751e-06, 	 time: 1.18
# epoch: 59/200, 	 loss: 0.084 	 rel:3.669e-06, 	 time: 1.71
# epoch: 60/200, 	 loss: 0.084 	 rel:3.674e-06, 	 time: 1.17
# epoch: 61/200, 	 loss: 0.087 	 rel:3.794e-06, 	 time: 2.83
# epoch: 62/200, 	 loss: 0.084 	 rel:3.693e-06, 	 time: 1.57
# epoch: 63/200, 	 loss: 0.082 	 rel:3.588e-06, 	 time: 1.85
# epoch: 64/200, 	 loss: 0.082 	 rel:3.582e-06, 	 time: 3.28
# epoch: 65/200, 	 loss: 24.434 	 rel:1.071e-03, 	 time: 3.69
# epoch: 66/200, 	 loss: 549.525 	 rel:2.408e-02, 	 time: 3.46
# epoch: 67/200, 	 loss: 26702.864 	 rel:1.170e+00, 	 time: 1.86
# epoch: 68/200, 	 loss: 0.078 	 rel:3.397e-06, 	 time: 1.35
# epoch: 69/200, 	 loss: 0.075 	 rel:3.293e-06, 	 time: 1.92
# epoch: 70/200, 	 loss: 0.074 	 rel:3.261e-06, 	 time: 1.66
# epoch: 71/200, 	 loss: 0.075 	 rel:3.291e-06, 	 time: 1.52
# epoch: 72/200, 	 loss: 0.067 	 rel:2.934e-06, 	 time: 1.86
# epoch: 73/200, 	 loss: 0.713 	 rel:3.124e-05, 	 time: 1.14
# epoch: 74/200, 	 loss: 0.082 	 rel:3.585e-06, 	 time: 1.11
# epoch: 75/200, 	 loss: 0.090 	 rel:3.937e-06, 	 time: 1.64
# epoch: 76/200, 	 loss: 25.800 	 rel:1.131e-03, 	 time: 1.50
# epoch: 77/200, 	 loss: 2273.186 	 rel:9.961e-02, 	 time: 1.48
# epoch: 78/200, 	 loss: 0.074 	 rel:3.246e-06, 	 time: 1.46
# epoch: 79/200, 	 loss: 0.081 	 rel:3.530e-06, 	 time: 1.74
# epoch: 80/200, 	 loss: 3.939 	 rel:1.726e-04, 	 time: 1.20
# epoch: 81/200, 	 loss: 144.593 	 rel:6.336e-03, 	 time: 1.19
# epoch: 82/200, 	 loss: 3540.842 	 rel:1.552e-01, 	 time: 1.39
# epoch: 83/200, 	 loss: 0.060 	 rel:2.617e-06, 	 time: 1.28
# epoch: 84/200, 	 loss: 0.060 	 rel:2.647e-06, 	 time: 1.16
# epoch: 85/200, 	 loss: 0.071 	 rel:3.129e-06, 	 time: 1.25
# epoch: 86/200, 	 loss: 0.540 	 rel:2.366e-05, 	 time: 1.16
# epoch: 87/200, 	 loss: 331.152 	 rel:1.451e-02, 	 time: 1.21
# epoch: 88/200, 	 loss: 527.571 	 rel:2.312e-02, 	 time: 1.34
# epoch: 89/200, 	 loss: 0.062 	 rel:2.719e-06, 	 time: 1.52
# epoch: 90/200, 	 loss: 653.709 	 rel:2.865e-02, 	 time: 1.68
# epoch: 91/200, 	 loss: 41733.316 	 rel:1.829e+00, 	 time: 1.55
# epoch: 92/200, 	 loss: 0.053 	 rel:2.325e-06, 	 time: 1.45
# epoch: 93/200, 	 loss: 0.050 	 rel:2.209e-06, 	 time: 1.79
# epoch: 94/200, 	 loss: 0.050 	 rel:2.176e-06, 	 time: 1.58
# epoch: 95/200, 	 loss: 0.049 	 rel:2.157e-06, 	 time: 1.39
# epoch: 96/200, 	 loss: 0.050 	 rel:2.204e-06, 	 time: 1.52
# epoch: 97/200, 	 loss: 0.052 	 rel:2.283e-06, 	 time: 1.52
# epoch: 98/200, 	 loss: 0.054 	 rel:2.376e-06, 	 time: 1.68
# epoch: 99/200, 	 loss: 0.050 	 rel:2.185e-06, 	 time: 1.68
# epoch: 100/200, 	 loss: 0.391 	 rel:1.715e-05, 	 time: 1.73
# epoch: 101/200, 	 loss: 184.616 	 rel:8.090e-03, 	 time: 2.18
# epoch: 102/200, 	 loss: 19.434 	 rel:8.516e-04, 	 time: 1.59
# epoch: 103/200, 	 loss: 11357.961 	 rel:4.977e-01, 	 time: 1.44
# epoch: 104/200, 	 loss: 0.038 	 rel:1.676e-06, 	 time: 1.67
# epoch: 105/200, 	 loss: 0.039 	 rel:1.704e-06, 	 time: 1.44
# epoch: 106/200, 	 loss: 0.040 	 rel:1.766e-06, 	 time: 1.15
# epoch: 107/200, 	 loss: 0.043 	 rel:1.879e-06, 	 time: 1.22
# epoch: 108/200, 	 loss: 0.039 	 rel:1.702e-06, 	 time: 1.08
# epoch: 109/200, 	 loss: 0.069 	 rel:3.032e-06, 	 time: 1.14
# epoch: 110/200, 	 loss: 2.395 	 rel:1.049e-04, 	 time: 1.08
# epoch: 111/200, 	 loss: 154.083 	 rel:6.752e-03, 	 time: 1.07
# epoch: 112/200, 	 loss: 11851.355 	 rel:5.193e-01, 	 time: 1.15
# epoch: 113/200, 	 loss: 0.040 	 rel:1.772e-06, 	 time: 1.15
# epoch: 114/200, 	 loss: 0.040 	 rel:1.736e-06, 	 time: 1.08
# epoch: 115/200, 	 loss: 0.041 	 rel:1.800e-06, 	 time: 1.14
# epoch: 116/200, 	 loss: 0.043 	 rel:1.865e-06, 	 time: 1.09
# epoch: 117/200, 	 loss: 0.044 	 rel:1.926e-06, 	 time: 1.10
# epoch: 118/200, 	 loss: 2.521 	 rel:1.105e-04, 	 time: 1.13
# epoch: 119/200, 	 loss: 1.098 	 rel:4.811e-05, 	 time: 1.05
# epoch: 120/200, 	 loss: 182.232 	 rel:7.985e-03, 	 time: 1.08
# epoch: 121/200, 	 loss: 2846.136 	 rel:1.247e-01, 	 time: 1.24
# epoch: 122/200, 	 loss: 0.037 	 rel:1.636e-06, 	 time: 1.15
# epoch: 123/200, 	 loss: 0.040 	 rel:1.740e-06, 	 time: 1.29
# epoch: 124/200, 	 loss: 0.043 	 rel:1.874e-06, 	 time: 1.14
# epoch: 125/200, 	 loss: 0.411 	 rel:1.803e-05, 	 time: 1.12
# epoch: 126/200, 	 loss: 146.905 	 rel:6.437e-03, 	 time: 1.11
# epoch: 127/200, 	 loss: 2512.733 	 rel:1.101e-01, 	 time: 1.18
# epoch: 128/200, 	 loss: 0.037 	 rel:1.604e-06, 	 time: 1.11
# epoch: 129/200, 	 loss: 0.037 	 rel:1.624e-06, 	 time: 1.16
# epoch: 130/200, 	 loss: 0.066 	 rel:2.912e-06, 	 time: 1.20
# epoch: 131/200, 	 loss: 0.786 	 rel:3.445e-05, 	 time: 1.11
# epoch: 132/200, 	 loss: 113.736 	 rel:4.984e-03, 	 time: 1.11
# epoch: 133/200, 	 loss: 1627.247 	 rel:7.131e-02, 	 time: 1.18
# epoch: 134/200, 	 loss: 0.034 	 rel:1.483e-06, 	 time: 1.11
# epoch: 135/200, 	 loss: 0.060 	 rel:2.628e-06, 	 time: 1.20
# epoch: 136/200, 	 loss: 0.330 	 rel:1.445e-05, 	 time: 1.50
# epoch: 137/200, 	 loss: 502.643 	 rel:2.203e-02, 	 time: 1.13
# epoch: 138/200, 	 loss: 28582.193 	 rel:1.252e+00, 	 time: 1.27
# epoch: 139/200, 	 loss: 0.032 	 rel:1.385e-06, 	 time: 1.47
# epoch: 140/200, 	 loss: 0.031 	 rel:1.344e-06, 	 time: 1.13
# epoch: 141/200, 	 loss: 0.030 	 rel:1.326e-06, 	 time: 1.26
# epoch: 142/200, 	 loss: 0.030 	 rel:1.317e-06, 	 time: 1.30
# epoch: 143/200, 	 loss: 0.031 	 rel:1.354e-06, 	 time: 1.32
# epoch: 144/200, 	 loss: 0.032 	 rel:1.406e-06, 	 time: 1.31
# epoch: 145/200, 	 loss: 0.034 	 rel:1.508e-06, 	 time: 1.19
# epoch: 146/200, 	 loss: 0.034 	 rel:1.478e-06, 	 time: 1.26
# epoch: 147/200, 	 loss: 0.031 	 rel:1.352e-06, 	 time: 1.22
# epoch: 148/200, 	 loss: 23.530 	 rel:1.031e-03, 	 time: 1.38
# epoch: 149/200, 	 loss: 10688.827 	 rel:4.684e-01, 	 time: 1.26
# epoch: 150/200, 	 loss: 0.023 	 rel:1.011e-06, 	 time: 1.35
# epoch: 151/200, 	 loss: 0.023 	 rel:9.918e-07, 	 time: 1.08
# epoch: 152/200, 	 loss: 0.023 	 rel:1.000e-06, 	 time: 1.14
# epoch: 153/200, 	 loss: 0.023 	 rel:9.876e-07, 	 time: 1.07
# epoch: 154/200, 	 loss: 0.131 	 rel:5.736e-06, 	 time: 1.09
# epoch: 155/200, 	 loss: 0.031 	 rel:1.361e-06, 	 time: 1.14
# epoch: 156/200, 	 loss: 0.124 	 rel:5.418e-06, 	 time: 1.07
# epoch: 157/200, 	 loss: 192.121 	 rel:8.419e-03, 	 time: 1.06
# epoch: 158/200, 	 loss: 6284.837 	 rel:2.754e-01, 	 time: 1.12
# epoch: 159/200, 	 loss: 0.027 	 rel:1.199e-06, 	 time: 1.08
# epoch: 160/200, 	 loss: 0.028 	 rel:1.220e-06, 	 time: 1.06
# epoch: 161/200, 	 loss: 0.029 	 rel:1.288e-06, 	 time: 1.13
# epoch: 162/200, 	 loss: 0.032 	 rel:1.399e-06, 	 time: 1.07
# epoch: 163/200, 	 loss: 0.031 	 rel:1.368e-06, 	 time: 1.07
# epoch: 164/200, 	 loss: 0.068 	 rel:2.996e-06, 	 time: 1.12
# epoch: 165/200, 	 loss: 113.190 	 rel:4.960e-03, 	 time: 1.06
# epoch: 166/200, 	 loss: 15893.814 	 rel:6.965e-01, 	 time: 1.06
# epoch: 167/200, 	 loss: 0.027 	 rel:1.170e-06, 	 time: 1.12
# epoch: 168/200, 	 loss: 0.026 	 rel:1.129e-06, 	 time: 1.07
# epoch: 169/200, 	 loss: 0.025 	 rel:1.090e-06, 	 time: 1.08
# epoch: 170/200, 	 loss: 0.025 	 rel:1.107e-06, 	 time: 1.12
# epoch: 171/200, 	 loss: 0.025 	 rel:1.115e-06, 	 time: 1.08
# epoch: 172/200, 	 loss: 0.026 	 rel:1.159e-06, 	 time: 1.10
# epoch: 173/200, 	 loss: 2.190 	 rel:9.596e-05, 	 time: 1.14
# epoch: 174/200, 	 loss: 0.485 	 rel:2.124e-05, 	 time: 1.08
# epoch: 175/200, 	 loss: 20.724 	 rel:9.081e-04, 	 time: 1.06
# epoch: 176/200, 	 loss: 1988.723 	 rel:8.715e-02, 	 time: 1.12
# epoch: 177/200, 	 loss: 0.026 	 rel:1.139e-06, 	 time: 1.10
# epoch: 178/200, 	 loss: 0.026 	 rel:1.121e-06, 	 time: 1.08
# epoch: 179/200, 	 loss: 0.100 	 rel:4.395e-06, 	 time: 1.15
# epoch: 180/200, 	 loss: 0.806 	 rel:3.531e-05, 	 time: 1.09
# epoch: 181/200, 	 loss: 199.732 	 rel:8.752e-03, 	 time: 1.10
# epoch: 182/200, 	 loss: 982.567 	 rel:4.306e-02, 	 time: 1.17
# epoch: 183/200, 	 loss: 0.024 	 rel:1.056e-06, 	 time: 1.10
# epoch: 184/200, 	 loss: 0.040 	 rel:1.767e-06, 	 time: 1.08
# epoch: 185/200, 	 loss: 49.504 	 rel:2.169e-03, 	 time: 1.15
# epoch: 186/200, 	 loss: 465.116 	 rel:2.038e-02, 	 time: 1.08
# epoch: 187/200, 	 loss: 26207.093 	 rel:1.148e+00, 	 time: 1.09
# epoch: 188/200, 	 loss: 0.018 	 rel:7.729e-07, 	 time: 1.14
# epoch: 189/200, 	 loss: 0.017 	 rel:7.508e-07, 	 time: 1.07
# epoch: 190/200, 	 loss: 0.017 	 rel:7.264e-07, 	 time: 1.06
# epoch: 191/200, 	 loss: 0.016 	 rel:7.133e-07, 	 time: 1.13
# epoch: 192/200, 	 loss: 0.016 	 rel:7.172e-07, 	 time: 1.06
# epoch: 193/200, 	 loss: 0.017 	 rel:7.239e-07, 	 time: 1.08
# epoch: 194/200, 	 loss: 0.018 	 rel:7.679e-07, 	 time: 1.15
# epoch: 195/200, 	 loss: 0.019 	 rel:8.211e-07, 	 time: 1.07
# epoch: 196/200, 	 loss: 0.748 	 rel:3.278e-05, 	 time: 1.06
# epoch: 197/200, 	 loss: 0.115 	 rel:5.031e-06, 	 time: 1.12
# epoch: 198/200, 	 loss: 183.034 	 rel:8.021e-03, 	 time: 1.07
# epoch: 199/200, 	 loss: 214.455 	 rel:9.397e-03, 	 time: 1.07
# epoch: 200/200, 	 loss: 22.384 	 rel:9.809e-04, 	 time: 1.12
# Maximum Iterations Reached
# ---------------------------------

# %%
# trained_lse_info = {
#     'model_state_dict': NN_logSum.state_dict(), 
#     'n_inputs':n_inputs,
#     'n_outputs':n_outputs,
#     'layers':layers,
#     'b_arr':b_array, 
#     'len_Darray':len_Darray, 
#     'D_min_range':D_min_range,
#     'D_max_range':D_max_range,
#     'io_scale':IO_scale,
#     'n_samples':n_samples,
#     'frac_train':frac_train,
#     'optimizer_name':optimizer,
#     'optimize_state_dict':optimizer.state_dict(),
#     'lr_scheduler':lr_scheduler,
#     'lr0':lr0,
#     'loss_fn':loss_fn,
#     'epochs':epochs,
#     'batch_size':batch_size,
#     'training_loss':training_loss,
#     'learning_rate':learning_rate,
# }

# %% [markdown]
# ### Save the trained model

# %%
# # str(datetime.datetime.today()).split()
# current_time = datetime.datetime.now()
# yyyy = str(current_time.year)
# mm = str(current_time.month)
# dd = str(current_time.day)
# hh = str(current_time.hour)
# mt = str(current_time.minute)
# sec = str(current_time.second)
# current_datetime = yyyy + '_' + mm + '_' + dd + '__' + hh + '_' + mt + '_' + sec 
# print(current_datetime)
# Out:
# 2025_4_17__15_56_48

# %%
# filename = 'logSumExp_models/lse_' + current_datetime + '.pth'

# torch.save(trained_lse_info, filename)

# %% [markdown]
# ### plot training loss and learning rate

# %%
plt.figure(figsize=(10,2))
plt.subplot(1,2,1)
plt.plot(training_loss)
plt.title('training_loss')
plt.grid()
plt.subplot(1,2,2)
plt.plot(learning_rate)
plt.title('learning_rate')
plt.grid()

plt.show()

# %% [markdown]
# ### Evaluate the network on a validation dataset

# %%
b_min_v = b_array[0]
b_max_v = b_array[-1]
b_grow_v = 1.1
b_array_v = createBetaArray(b_min_v, b_max_v, b_grow_v)
n_curves_v = 5
D_min_range_v = [0.0001,1]
D_max_range_v = [1,2]
len_Darray_v = len_Darray
In_val, Out_val = logsum_dataset(n_curves=n_curves_v, 
                    b_min=b_min_v, b_max=b_max_v, b_grow=b_grow_v, D_min_range=D_min_range_v, 
                    D_max_range=D_max_range_v, len_Darray=len_Darray_v, 
                    approx_log_sum_flr=True, io_scale=IO_scale)
pred_val = NN_logSum(In_val).detach()

st = 0
Out_val_np = (Out_val.numpy().flatten()/IO_scale)[st:] - (1 / np.tile(b_array_v, n_curves_v) * np.log(len_Darray_v))[st:] + (In_val[:,1].numpy().flatten()/IO_scale)[st:]
pred_val_np = (pred_val.numpy().flatten()/IO_scale)[st:] - (1 / np.tile(b_array_v, n_curves_v) * np.log(len_Darray_v))[st:] + (In_val[:,1].numpy().flatten()/IO_scale)[st:]

plt.figure(figsize=(12,4))
plt.subplot(2,1,1)
plt.plot(Out_val_np, label='target', color='violet', linestyle='dashed', linewidth=3)
plt.plot(pred_val_np, label='prediction', color='black')
plt.grid()
plt.xticks()
plt.legend()

plt.subplot(2,1,2)
error_val = np.abs(pred_val_np - Out_val_np)
# plt.subplot(1,2,2)
plt.plot(error_val, label='error', color='red')
plt.legend()
plt.grid()

plt.show()

# %%
Out_val_np.shape
# Out:
# (1120,)

# %%
b_array_v.shape
# Out:
# (280,)

# %%
np.tile(b_array_v, n_curves_v).shape
# Out:
# (1120,)
