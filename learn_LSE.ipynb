# %%
import numpy as np
import matplotlib.pyplot as plt
import LSE_net
import torch
import importlib
import pickle
import datetime

# %%
def myLog(x, base):
    return np.log(x)/np.log(base)

def createBetaArray(min, max, grow):
    beta = min
    beta_array = [beta]
    while beta <= max:
        beta = beta*grow
        beta_array.append(beta)
    beta_array = np.array(beta_array)
    return beta_array

def logSumExp(D_array, beta):
    D_min = np.min(D_array)
    D_off = D_array - D_min
    F = -1/beta * np.log(np.sum(np.exp(-beta*D_off))) + 1/beta * np.log(len(D_array)) + 0*D_min
    # F = -np.log(np.sum(np.exp(-beta*D_off))) + np.log(len(D_array)) + D_min * beta
    return F

def gibbs(D_array, beta):
    D_min = np.min(D_array)
    D_off = D_array - D_min
    exp_bD = np.exp(-beta * D_off)
    sum_exp_bD = np.sum(exp_bD)
    P = exp_bD/sum_exp_bD
    return P

# %%
beta = 0.001
# np.random.seed(10)
D_max = 1
D_array = np.sort(np.random.uniform(0.2, D_max, 500))
D_min = np.min(D_array)
P = gibbs(D_array, beta)
F = logSumExp(D_array, beta)
# slopeP = (P[1:] - P[0:-1])/(D_array[1:]-D_array[0:-1])

N_discrete = 1000
D_discrete = np.linspace(D_min, D_max, N_discrete)
P1 = beta * np.exp(-beta * (D_discrete))/(np.exp(-beta * D_min) - np.exp(-beta * D_max)) * (D_max - D_min)/N_discrete
P1 = P1/np.sum(P1)

frac = 0.01
# D_array1 = np.random.choice(a=D_discrete, p=P1, size=int(len(D_array)*frac)-1)
# D_array1 = np.sort(
#     np.concatenate((
#         np.array([D_min]),
#         D_array1, 
#         np.random.uniform(np.max(D_array1), D_max, int(len(D_array)*(1-frac))))
#     ))
D_array1 = np.random.uniform(D_min, D_max, int(len(D_array)))

P2 = gibbs(D_array1, beta)
F2 = logSumExp(D_array1, beta)

print(f"D_min:{D_min:.3e}\tD_min1:{np.min(D_array1):.3e}\tF:{F:.3f}\tF2:{F2:.3f}\tpercent_error:{abs(F-F2)/abs(F)*100:.3f}%")

# P3 = beta * np.exp(-beta * (D_array1))/(np.exp(-beta * np.min(D_array1)) - np.exp(-beta * np.max(D_array1))) * (np.max(D_array1) - np.min(D_array1))/len(D_array1)

plt.figure(figsize=(6,2))
plt.plot(D_discrete, P1, marker='.', label='P1')
plt.legend()
plt.grid()

plt.figure(figsize=(6,2))
plt.plot(D_array, P, marker='.', label='P')
plt.plot(D_array1, P2, marker='.', label='P2')
# plt.plot(D_array1, P3, marker='.', label='P3')
# plt.ylim(0.0,1.0)
plt.legend()
plt.grid()

# plt.figure(figsize=(6,2))
# plt.plot(beta * D_array[0:-1], slopeP, marker='.')
# plt.ylim(0.0,1.0)
# plt.grid()
# plt.show()
# Out:
# D_min:2.000e-01	D_min1:2.000e-01	F:0.401	F2:0.401	percent_error:0.040%

# %%
# b_min = 0.0001
# b_max = 10
# b_grow = 1.1
# D_range0 = [10,200]
# D_range1 = [700,1000]
# D_array = np.sort(
#     np.concatenate(
#         (np.random.uniform(D_range0[0], D_range0[1], 500),
#         np.random.uniform(D_range1[0], D_range1[1], 500))
#         ))
# D_min = np.min(D_array)
# N_discrete = 20000

# F_org_arr = []
# F_est_arr = []
# b_arr = []
# beta = b_min

# while beta <= b_max:
#     F = logSumExp(D_array, beta)

#     # D_discrete = np.linspace(D_min, D_range[1], N_discrete)
#     # P1 = beta * np.exp(-beta * (D_discrete))/(np.exp(-beta * D_min) - np.exp(-beta * D_range[1])) * (D_range[1] - D_min)/N_discrete
#     # P1 = P1/np.sum(P1)

#     # D_array1 = np.sort(np.random.choice(a=D_discrete, p=P1, size=len(D_array)))
#     # D_array1 = np.concatenate((np.array([D_min]), np.sort(np.random.choice(a=D_discrete, p=P1, size=len(D_array)-1))))
#     # np.random.seed(10)
#     D_array1 = np.sort(
#     np.concatenate(
#         (np.array([D_min]),
#         np.random.uniform(D_min, D_range0[1], 500),
#         np.random.uniform(D_range1[0], D_range1[1], 499))
#         )
#     )
#     # D_array1 = np.concatenate((np.array([D_min]), np.sort(np.random.uniform(D_min, D_range[1], len(D_array)-1))))
#     P2 = gibbs(D_array1, beta)
#     F2 = logSumExp(D_array1, beta)

#     F_org_arr.append(F)
#     F_est_arr.append(F2)
#     b_arr.append(beta)

#     beta *= b_grow

# np_F_org_arr = np.array(F_org_arr)
# np_F_est_arr = np.array(F_est_arr)

# plt.figure(figsize=(6,2))
# plt.plot(myLog(b_arr,10), np.array(F_org_arr), label='original')
# plt.plot(myLog(b_arr,10), np.array(F_est_arr), label='estimate')
# plt.grid()
# plt.legend()

# plt.figure(figsize=(6,2))
# plt.plot(myLog(b_arr,10), np_F_org_arr-np_F_est_arr, label='error')
# plt.grid()
# plt.legend()

# plt.show()

# %%
# d1 = 10
# d2 = 30
# d3 = 40
# d4 = 50
# b0 = 1e-5
# l0 = 1/b0 * np.log(4)
# l1 = -1/b0 * np.log(np.exp(-b0*d1) + np.exp(-b0*d2) + np.exp(-b0*d3) + np.exp(-b0*d4)) + l0
# l2 = -1/b0 * np.log(4)
# l3 = l2 + d1 - 1/b0 * np.log((1 + np.exp(-b0*(d2-d1)) + np.exp(-b0*(d3-d1)) + np.exp(-b0*(d4-d1)))/4) + l0
# l4 = l2 + d1 - 1/b0 * np.log((1 + np.exp(-b0*d1) + np.exp(-b0*1.5*d1) + np.exp(-b0*4*d1))/4) + l0
# print(f'l0:{l0:.3f}\nl1:{l1:.3f}\nl2:{l2:.3f}\nl3:{l3:.3f}\nl4:{l4:.3f}\nl2-l1:{l2+l0-l1:.3f}\nl3-l1:{l3-l1:.3f}\nl4-l1:{l4-l1:.3f}')

# %% [markdown]
# ### Create dataset

# %%
# function to generate logsum dataset
def logsum_dataset(n_curves, b_min, b_max, b_grow, D_min_range, D_max_range, D_max_scale, len_Darray_range, approx_log_sum_flr, io_scale):
    b_array = createBetaArray(b_min, b_max, b_grow)
    n_beta_per_curve = len(b_array)
    n_data = n_curves * n_beta_per_curve
    In = torch.zeros((n_data, 3), dtype=torch.float32)
    Out = torch.zeros((n_data,1), dtype=torch.float32)
    len_D_ARR = []

    cnt = 0
    for c in range(n_curves):
        
        len_Darray = int(np.random.uniform(len_Darray_range[0], len_Darray_range[1]))
        D0 = np.random.uniform(D_min_range[0], D_min_range[1])
        # D1 = D0 + np.random.uniform(D_max_range[0], D_max_range[1])
        D_array = np.random.uniform(D0, D_max_scale, len_Darray)
        D_min = np.min(D_array)
        if approx_log_sum_flr:
            # N_discrete = 2000
            # D_discrete = np.linspace(D_min, D_max_scale, N_discrete)
            # P1 = b_min * np.exp(-b_min * (D_discrete))/(np.exp(-b_min * D_min) - np.exp(-b_min * D_max_scale)) * (D_max_scale - D_min)/N_discrete
            # P1 = P1/np.sum(P1)
            # D_array_dum = np.sort(np.random.choice(a=D_discrete, p=P1, size=len(D_array)))
            D_array_dum = np.sort(np.random.uniform(D_min, D_max_scale, len(D_array)))
            F_min = logSumExp(D_array_dum, b_min)
            F_min1 = logSumExp(D_array, b_min)
            # print(f"F_min approx: {F_min:.3e}")
            # print(f"F_min true: {F_min1:.3e}")
            # print(f"D_array approx:{D_array_dum}")
            # print(f"D_array true:{np.sort(D_array)}")
        else:
            F_min = logSumExp(D_array, b_min)
            # print(f"F_min true: {F_min:.3e}")
        F_min = io_scale * F_min
        F_max = io_scale * D_min

        for b in b_array:
            Fb = io_scale * logSumExp(D_array, b)
            In[cnt,:] = torch.tensor([F_min, F_max, myLog(b,10)])
            Out[cnt,:] = torch.tensor([Fb])
            len_D_ARR.append(len_Darray)
            cnt += 1

    return In, Out, len_D_ARR

# %%
# beta limits
b_min = 1e-4
b_max = 1e5
b_grow = 1.05
b_array = createBetaArray(b_min, b_max, b_grow)
print(f'len b_array:\t{b_array.shape}')

# torch input and output arrays
n_curves = 100
len_Darray_range = [100,1000]
D_min_range = [0.0, 0.4] # minimum value of D_array is picked at random from this range
D_max_range = [1.0, 1.0] # maximum value of D_array is picked at random from the range dmin + D_max_range
D_max_scale = np.max(np.array(D_min_range) + np.array(D_max_range))
IO_scale = 1

In, Out, len_D_ARR = logsum_dataset(n_curves, b_min, b_max, b_grow, D_min_range, D_max_range, D_max_scale, len_Darray_range, approx_log_sum_flr=False, io_scale=IO_scale)
print(f'In:\t{In.size()}\nOut:\t{Out.size()}\nlen_D_ARR\tsize:{len(len_D_ARR)}\tmin:{np.min(len_D_ARR)}\tmax:{np.max(len_D_ARR)}\tmean:{np.mean(len_D_ARR)}')
# Out:
# len b_array:	(426,)
# In:	torch.Size([42600, 3])
# Out:	torch.Size([42600, 1])
# len_D_ARR	size:42600	min:101	max:990	mean:512.78

# %% [markdown]
# ### Visualize Data

# %%
def visualizeData(In, Out, n_end):

    plt.figure(figsize=(12,8))

    plt.subplot(2,2,1)
    plt.plot(In[:n_end,0], label='F_min')
    plt.legend()
    plt.grid()

    plt.subplot(2,2,2)
    plt.plot(In[:n_end,1], label='F_max')
    plt.legend()
    plt.grid()

    plt.subplot(2,2,3)
    plt.plot(In[:n_end,2], label='beta')
    plt.legend()
    plt.grid()

    plt.subplot(2,2,4)
    plt.plot(In[:n_end,0], label='F_min', linestyle='dashed', linewidth=2)
    plt.plot(In[:n_end,1], label='F_max', linestyle='dashed', linewidth=2)
    plt.plot(Out[:n_end], label='F_beta')
    plt.legend()
    plt.grid()

    plt.show()

visualizeData(In, Out, n_end=2000)

# %% [markdown]
# ### Create neural net for training

# %%
importlib.reload(LSE_net)

# create DNN
n_inputs = In.size()[1]
n_outputs = Out.size()[1]
layers = [10, 10]
NN_logSum = LSE_net.dnn(n_inputs, n_outputs, layers)
print(f'DNN model:\n{NN_logSum}')

# create training, and testing dataset
n_samples = In.size()[0]
frac_train = 0.7
n_train = int(frac_train * n_samples)
indices = torch.arange(n_samples)
train_indices = indices[:n_train]
test_indices = indices[n_train:]
In_train = In[train_indices]
Out_train = Out[train_indices]
In_test = In[test_indices]
Out_test = Out[test_indices]
# Out:
# DNN model:
# dnn(
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=10, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=10, out_features=10, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=10, out_features=1, bias=True)
#   )
# )

# %%
In[1]
# Out:
# tensor([6.1587e-01, 1.7515e-01, 1.0500e-04])

# %%
NN_logSum(In[1]).detach().numpy()
# Out:
# array([-2.1481194], dtype=float32)

# %%
visualizeData(In_train, Out_train, n_end=2000)
visualizeData(In_test, Out_test, n_end=2000)

# %% [markdown]
# ### train the network

# %%
# dnn configuration
optimizer_name = 'adam'
lr_scheduler = 'ReduceLROnPlateau'
lr0 = 0.0001
epochs = 100
batch_size = 70
loss_coeffs = [1.0, 0.0]
loss_fn, optimizer, scheduler = LSE_net.config_nn(NN_logSum, optimizer_name, lr_scheduler, lr0)
loss = loss_fn(NN_logSum(In_train[0]), Out_train[0]).detach().item()
training_loss, learning_rate, stopping_epoch = LSE_net.train_nn1(
    NN_logSum, In_train, Out_train, loss_fn,
    optimizer, scheduler, loss_coeffs=loss_coeffs,
    epochs=epochs, batch_size=batch_size, shuffledata=True, allowPrint=True)
# Out:
# ---------------------------------
# training data size = 29819
# training batch size = 70
# n_epochs = 100
# n_batches = 426
# loss weights = [1.0, 0.0]
# ---------------------------------
#
# batch_split
# 0 69
# 70 139
# 140 209
# 210 279
# 280 349
# 350 419
# 420 489
# 490 559
# 560 629
# 630 699
# 700 769
# 770 839
# 840 909
# 910 979
# 980 1049
# 1050 1119
# 1120 1189
# 1190 1259
# 1260 1329
# 1330 1399
# 1400 1469
# 1470 1539
# 1540 1609
# 1610 1679
# 1680 1749
# 1750 1819
# 1820 1889
# 1890 1959
# 1960 2029
# 2030 2099
# 2100 2169
# 2170 2239
# 2240 2309
# 2310 2379
# 2380 2449
# 2450 2519
# 2520 2589
# 2590 2659
# 2660 2729
# 2730 2799
# 2800 2869
# 2870 2939
# 2940 3009
# 3010 3079
# 3080 3149
# 3150 3219
# 3220 3289
# 3290 3359
# 3360 3429
# 3430 3499
# 3500 3569
# 3570 3639
# 3640 3709
# 3710 3779
# 3780 3849
# 3850 3919
# 3920 3989
# 3990 4059
# 4060 4129
# 4130 4199
# 4200 4269
# 4270 4339
# 4340 4409
# 4410 4479
# 4480 4549
# 4550 4619
# 4620 4689
# 4690 4759
# 4760 4829
# 4830 4899
# 4900 4969
# 4970 5039
# 5040 5109
# 5110 5179
# 5180 5249
# 5250 5319
# 5320 5389
# 5390 5459
# 5460 5529
# 5530 5599
# 5600 5669
# 5670 5739
# 5740 5809
# 5810 5879
# 5880 5949
# 5950 6019
# 6020 6089
# 6090 6159
# 6160 6229
# 6230 6299
# 6300 6369
# 6370 6439
# 6440 6509
# 6510 6579
# 6580 6649
# 6650 6719
# 6720 6789
# 6790 6859
# 6860 6929
# 6930 6999
# 7000 7069
# 7070 7139
# 7140 7209
# 7210 7279
# 7280 7349
# 7350 7419
# 7420 7489
# 7490 7559
# 7560 7629
# 7630 7699
# 7700 7769
# 7770 7839
# 7840 7909
# 7910 7979
# 7980 8049
# 8050 8119
# 8120 8189
# 8190 8259
# 8260 8329
# 8330 8399
# 8400 8469
# 8470 8539
# 8540 8609
# 8610 8679
# 8680 8749
# 8750 8819
# 8820 8889
# 8890 8959
# 8960 9029
# 9030 9099
# 9100 9169
# 9170 9239
# 9240 9309
# 9310 9379
# 9380 9449
# 9450 9519
# 9520 9589
# 9590 9659
# 9660 9729
# 9730 9799
# 9800 9869
# 9870 9939
# 9940 10009
# 10010 10079
# 10080 10149
# 10150 10219
# 10220 10289
# 10290 10359
# 10360 10429
# 10430 10499
# 10500 10569
# 10570 10639
# 10640 10709
# 10710 10779
# 10780 10849
# 10850 10919
# 10920 10989
# 10990 11059
# 11060 11129
# 11130 11199
# 11200 11269
# 11270 11339
# 11340 11409
# 11410 11479
# 11480 11549
# 11550 11619
# 11620 11689
# 11690 11759
# 11760 11829
# 11830 11899
# 11900 11969
# 11970 12039
# 12040 12109
# 12110 12179
# 12180 12249
# 12250 12319
# 12320 12389
# 12390 12459
# 12460 12529
# 12530 12599
# 12600 12669
# 12670 12739
# 12740 12809
# 12810 12879
# 12880 12949
# 12950 13019
# 13020 13089
# 13090 13159
# 13160 13229
# 13230 13299
# 13300 13369
# 13370 13439
# 13440 13509
# 13510 13579
# 13580 13649
# 13650 13719
# 13720 13789
# 13790 13859
# 13860 13929
# 13930 13999
# 14000 14069
# 14070 14139
# 14140 14209
# 14210 14279
# 14280 14349
# 14350 14419
# 14420 14489
# 14490 14559
# 14560 14629
# 14630 14699
# 14700 14769
# 14770 14839
# 14840 14909
# 14910 14979
# 14980 15049
# 15050 15119
# 15120 15189
# 15190 15259
# 15260 15329
# 15330 15399
# 15400 15469
# 15470 15539
# 15540 15609
# 15610 15679
# 15680 15749
# 15750 15819
# 15820 15889
# 15890 15959
# 15960 16029
# 16030 16099
# 16100 16169
# 16170 16239
# 16240 16309
# 16310 16379
# 16380 16449
# 16450 16519
# 16520 16589
# 16590 16659
# 16660 16729
# 16730 16799
# 16800 16869
# 16870 16939
# 16940 17009
# 17010 17079
# 17080 17149
# 17150 17219
# 17220 17289
# 17290 17359
# 17360 17429
# 17430 17499
# 17500 17569
# 17570 17639
# 17640 17709
# 17710 17779
# 17780 17849
# 17850 17919
# 17920 17989
# 17990 18059
# 18060 18129
# 18130 18199
# 18200 18269
# 18270 18339
# 18340 18409
# 18410 18479
# 18480 18549
# 18550 18619
# 18620 18689
# 18690 18759
# 18760 18829
# 18830 18899
# 18900 18969
# 18970 19039
# 19040 19109
# 19110 19179
# 19180 19249
# 19250 19319
# 19320 19389
# 19390 19459
# 19460 19529
# 19530 19599
# 19600 19669
# 19670 19739
# 19740 19809
# 19810 19879
# 19880 19949
# 19950 20019
# 20020 20089
# 20090 20159
# 20160 20229
# 20230 20299
# 20300 20369
# 20370 20439
# 20440 20509
# 20510 20579
# 20580 20649
# 20650 20719
# 20720 20789
# 20790 20859
# 20860 20929
# 20930 20999
# 21000 21069
# 21070 21139
# 21140 21209
# 21210 21279
# 21280 21349
# 21350 21419
# 21420 21489
# 21490 21559
# 21560 21629
# 21630 21699
# 21700 21769
# 21770 21839
# 21840 21909
# 21910 21979
# 21980 22049
# 22050 22119
# 22120 22189
# 22190 22259
# 22260 22329
# 22330 22399
# 22400 22469
# 22470 22539
# 22540 22609
# 22610 22679
# 22680 22749
# 22750 22819
# 22820 22889
# 22890 22959
# 22960 23029
# 23030 23099
# 23100 23169
# 23170 23239
# 23240 23309
# 23310 23379
# 23380 23449
# 23450 23519
# 23520 23589
# 23590 23659
# 23660 23729
# 23730 23799
# 23800 23869
# 23870 23939
# 23940 24009
# 24010 24079
# 24080 24149
# 24150 24219
# 24220 24289
# 24290 24359
# 24360 24429
# 24430 24499
# 24500 24569
# 24570 24639
# 24640 24709
# 24710 24779
# 24780 24849
# 24850 24919
# 24920 24989
# 24990 25059
# 25060 25129
# 25130 25199
# 25200 25269
# 25270 25339
# 25340 25409
# 25410 25479
# 25480 25549
# 25550 25619
# 25620 25689
# 25690 25759
# 25760 25829
# 25830 25899
# 25900 25969
# 25970 26039
# 26040 26109
# 26110 26179
# 26180 26249
# 26250 26319
# 26320 26389
# 26390 26459
# 26460 26529
# 26530 26599
# 26600 26669
# 26670 26739
# 26740 26809
# 26810 26879
# 26880 26949
# 26950 27019
# 27020 27089
# 27090 27159
# 27160 27229
# 27230 27299
# 27300 27369
# 27370 27439
# 27440 27509
# 27510 27579
# 27580 27649
# 27650 27719
# 27720 27789
# 27790 27859
# 27860 27929
# 27930 27999
# 28000 28069
# 28070 28139
# 28140 28209
# 28210 28279
# 28280 28349
# 28350 28419
# 28420 28489
# 28490 28559
# 28560 28629
# 28630 28699
# 28700 28769
# 28770 28839
# 28840 28909
# 28910 28979
# 28980 29049
# 29050 29119
# 29120 29189
# 29190 29259
# 29260 29329
# 29330 29399
# 29400 29469
# 29470 29539
# 29540 29609
# 29610 29679
# 29680 29749
# 29750 29818
#
#
#
# ---------------------------------
# epoch: 0/100, 	 loss: 136153.978 	 rel:1.000e+03, 	 time: 0.44
# epoch: 1/100, 	 loss: 136153.978 	 rel:1.000e+03, 	 time: 0.44
# epoch: 2/100, 	 loss: 118066.075 	 rel:8.672e+02, 	 time: 0.44
# epoch: 3/100, 	 loss: 117701.388 	 rel:8.645e+02, 	 time: 0.41
# epoch: 4/100, 	 loss: 301660.793 	 rel:2.216e+03, 	 time: 0.41
# epoch: 5/100, 	 loss: 140333.220 	 rel:1.031e+03, 	 time: 0.41
# epoch: 6/100, 	 loss: 192422.944 	 rel:1.413e+03, 	 time: 0.43
# epoch: 7/100, 	 loss: 38402.224 	 rel:2.820e+02, 	 time: 0.41
# epoch: 8/100, 	 loss: 56476.707 	 rel:4.148e+02, 	 time: 0.41
# epoch: 9/100, 	 loss: 38484.197 	 rel:2.827e+02, 	 time: 0.41
# epoch: 10/100, 	 loss: 124853.029 	 rel:9.170e+02, 	 time: 0.41
# epoch: 11/100, 	 loss: 147065.281 	 rel:1.080e+03, 	 time: 0.41
# epoch: 12/100, 	 loss: 67306.861 	 rel:4.943e+02, 	 time: 0.41
# epoch: 13/100, 	 loss: 66081.830 	 rel:4.853e+02, 	 time: 0.41
# epoch: 14/100, 	 loss: 31031.725 	 rel:2.279e+02, 	 time: 0.41
# epoch: 15/100, 	 loss: 22131.753 	 rel:1.625e+02, 	 time: 0.41
# epoch: 16/100, 	 loss: 33036.292 	 rel:2.426e+02, 	 time: 0.41
# epoch: 17/100, 	 loss: 15707.542 	 rel:1.154e+02, 	 time: 0.41
# epoch: 18/100, 	 loss: 15718.697 	 rel:1.154e+02, 	 time: 0.41
# epoch: 19/100, 	 loss: 10090.577 	 rel:7.411e+01, 	 time: 0.41
# epoch: 20/100, 	 loss: 8303.253 	 rel:6.098e+01, 	 time: 0.45
# epoch: 21/100, 	 loss: 4476.291 	 rel:3.288e+01, 	 time: 0.41
# epoch: 22/100, 	 loss: 2506.802 	 rel:1.841e+01, 	 time: 0.41
# epoch: 23/100, 	 loss: 1298.823 	 rel:9.539e+00, 	 time: 0.41
# epoch: 24/100, 	 loss: 2034.745 	 rel:1.494e+01, 	 time: 0.41
# epoch: 25/100, 	 loss: 386.422 	 rel:2.838e+00, 	 time: 0.41
# epoch: 26/100, 	 loss: 415.831 	 rel:3.054e+00, 	 time: 0.41
# epoch: 27/100, 	 loss: 71.002 	 rel:5.215e-01, 	 time: 0.41
# epoch: 28/100, 	 loss: 87.802 	 rel:6.449e-01, 	 time: 0.41
# epoch: 29/100, 	 loss: 2.630 	 rel:1.932e-02, 	 time: 0.47
# epoch: 30/100, 	 loss: 0.215 	 rel:1.582e-03, 	 time: 0.55
# epoch: 31/100, 	 loss: 0.047 	 rel:3.440e-04, 	 time: 0.56
# epoch: 32/100, 	 loss: 0.010 	 rel:7.229e-05, 	 time: 0.56
# epoch: 33/100, 	 loss: 0.009 	 rel:6.290e-05, 	 time: 0.56
# epoch: 34/100, 	 loss: 0.013 	 rel:9.749e-05, 	 time: 0.56
# epoch: 35/100, 	 loss: 0.091 	 rel:6.676e-04, 	 time: 0.56
# epoch: 36/100, 	 loss: 0.034 	 rel:2.532e-04, 	 time: 0.55
# epoch: 37/100, 	 loss: 0.148 	 rel:1.089e-03, 	 time: 0.56
# epoch: 38/100, 	 loss: 0.015 	 rel:1.124e-04, 	 time: 0.56
# epoch: 39/100, 	 loss: 0.039 	 rel:2.861e-04, 	 time: 0.56
# epoch: 40/100, 	 loss: 4.033 	 rel:2.962e-02, 	 time: 0.56
# epoch: 41/100, 	 loss: 0.028 	 rel:2.079e-04, 	 time: 0.56
# epoch: 42/100, 	 loss: 0.053 	 rel:3.874e-04, 	 time: 0.59
# epoch: 43/100, 	 loss: 0.018 	 rel:1.352e-04, 	 time: 0.56
# epoch: 44/100, 	 loss: 0.135 	 rel:9.941e-04, 	 time: 0.56
# epoch: 45/100, 	 loss: 0.084 	 rel:6.134e-04, 	 time: 0.56
# epoch: 46/100, 	 loss: 0.014 	 rel:9.974e-05, 	 time: 0.58
# epoch: 47/100, 	 loss: 0.070 	 rel:5.178e-04, 	 time: 0.57
# epoch: 48/100, 	 loss: 0.602 	 rel:4.423e-03, 	 time: 0.56
# epoch: 49/100, 	 loss: 1.111 	 rel:8.160e-03, 	 time: 0.56
# epoch: 50/100, 	 loss: 0.173 	 rel:1.269e-03, 	 time: 0.63
# epoch: 51/100, 	 loss: 20.000 	 rel:1.469e-01, 	 time: 0.56
# epoch: 52/100, 	 loss: 0.066 	 rel:4.884e-04, 	 time: 0.57
# epoch: 53/100, 	 loss: 0.002 	 rel:1.327e-05, 	 time: 0.56
# epoch: 54/100, 	 loss: 0.002 	 rel:1.624e-05, 	 time: 0.58
# epoch: 55/100, 	 loss: 0.001 	 rel:6.252e-06, 	 time: 0.58
# epoch: 56/100, 	 loss: 0.007 	 rel:5.084e-05, 	 time: 0.58
# epoch: 57/100, 	 loss: 0.011 	 rel:8.241e-05, 	 time: 0.56
# epoch: 58/100, 	 loss: 0.005 	 rel:3.842e-05, 	 time: 0.56
# epoch: 59/100, 	 loss: 0.006 	 rel:4.740e-05, 	 time: 0.55
# epoch: 60/100, 	 loss: 0.003 	 rel:2.126e-05, 	 time: 0.56
# epoch: 61/100, 	 loss: 0.108 	 rel:7.941e-04, 	 time: 0.56
# epoch: 62/100, 	 loss: 0.452 	 rel:3.323e-03, 	 time: 0.55
# epoch: 63/100, 	 loss: 4.211 	 rel:3.093e-02, 	 time: 0.55
# epoch: 64/100, 	 loss: 0.002 	 rel:1.822e-05, 	 time: 0.55
# epoch: 65/100, 	 loss: 0.099 	 rel:7.236e-04, 	 time: 0.57
# epoch: 66/100, 	 loss: 0.017 	 rel:1.281e-04, 	 time: 0.56
# epoch: 67/100, 	 loss: 0.095 	 rel:6.995e-04, 	 time: 0.55
# epoch: 68/100, 	 loss: 1.485 	 rel:1.091e-02, 	 time: 0.55
# epoch: 69/100, 	 loss: 0.031 	 rel:2.276e-04, 	 time: 0.58
# epoch: 70/100, 	 loss: 1.154 	 rel:8.479e-03, 	 time: 0.56
# epoch: 71/100, 	 loss: 0.001 	 rel:6.399e-06, 	 time: 0.56
# epoch: 72/100, 	 loss: 0.004 	 rel:2.932e-05, 	 time: 0.55
# epoch: 73/100, 	 loss: 46.914 	 rel:3.446e-01, 	 time: 0.56
# epoch: 74/100, 	 loss: 0.028 	 rel:2.086e-04, 	 time: 0.56
# epoch: 75/100, 	 loss: 0.004 	 rel:2.701e-05, 	 time: 0.55
# epoch: 76/100, 	 loss: 0.001 	 rel:5.454e-06, 	 time: 0.56
# epoch: 77/100, 	 loss: 0.001 	 rel:4.711e-06, 	 time: 0.56
# epoch: 78/100, 	 loss: 0.000 	 rel:3.272e-06, 	 time: 0.56
# epoch: 79/100, 	 loss: 0.001 	 rel:4.528e-06, 	 time: 0.63
# epoch: 80/100, 	 loss: 0.005 	 rel:3.731e-05, 	 time: 0.56
# epoch: 81/100, 	 loss: 0.002 	 rel:1.741e-05, 	 time: 0.56
# epoch: 82/100, 	 loss: 0.025 	 rel:1.835e-04, 	 time: 0.55
# epoch: 83/100, 	 loss: 0.006 	 rel:4.238e-05, 	 time: 0.56
# epoch: 84/100, 	 loss: 0.399 	 rel:2.934e-03, 	 time: 0.55
# epoch: 85/100, 	 loss: 5.727 	 rel:4.206e-02, 	 time: 0.56
# epoch: 86/100, 	 loss: 0.001 	 rel:7.343e-06, 	 time: 0.55
# epoch: 87/100, 	 loss: 0.018 	 rel:1.288e-04, 	 time: 0.55
# epoch: 88/100, 	 loss: 3.303 	 rel:2.426e-02, 	 time: 0.56
# epoch: 89/100, 	 loss: 0.000 	 rel:1.376e-06, 	 time: 0.55
# epoch: 90/100, 	 loss: 0.000 	 rel:1.249e-06, 	 time: 0.55
# epoch: 91/100, 	 loss: 0.001 	 rel:3.822e-06, 	 time: 0.55
# epoch: 92/100, 	 loss: 0.000 	 rel:1.429e-06, 	 time: 0.55
# epoch: 93/100, 	 loss: 0.003 	 rel:2.263e-05, 	 time: 0.56
# epoch: 94/100, 	 loss: 8.104 	 rel:5.952e-02, 	 time: 0.55
# epoch: 95/100, 	 loss: 7.675 	 rel:5.637e-02, 	 time: 0.55
# epoch: 96/100, 	 loss: 0.000 	 rel:1.421e-06, 	 time: 0.56
# epoch: 97/100, 	 loss: 0.000 	 rel:1.124e-06, 	 time: 0.56
# epoch: 98/100, 	 loss: 0.000 	 rel:1.163e-06, 	 time: 0.55
# epoch: 99/100, 	 loss: 0.000 	 rel:1.184e-06, 	 time: 0.57
# epoch: 100/100, 	 loss: 0.000 	 rel:1.181e-06, 	 time: 0.57
# Maximum Iterations Reached
# ---------------------------------

# %%
trained_lse_info = {
    'model_state_dict': NN_logSum.state_dict(), 
    'n_inputs':n_inputs,
    'n_outputs':n_outputs,
    'layers':layers,
    'b_arr':b_array, 
    'len_Darray_range':len_Darray_range, 
    'D_min_range':D_min_range,
    'D_max_range':D_max_range,
    'io_scale':IO_scale,
    'n_samples':n_samples,
    'frac_train':frac_train,
    'optimizer_name':optimizer,
    'optimize_state_dict':optimizer.state_dict(),
    'lr_scheduler':lr_scheduler,
    'lr0':lr0,
    'loss_fn':loss_fn,
    'epochs':epochs,
    'batch_size':batch_size,
    'training_loss':training_loss,
    'learning_rate':learning_rate,
}

# %% [markdown]
# ### Save the trained model

# %%
# str(datetime.datetime.today()).split()
current_time = datetime.datetime.now()
yyyy = str(current_time.year)
mm = str(current_time.month)
dd = str(current_time.day)
hh = str(current_time.hour)
mt = str(current_time.minute)
sec = str(current_time.second)
current_datetime = yyyy + '_' + mm + '_' + dd + '__' + hh + '_' + mt + '_' + sec 
print(current_datetime)
# Out:
# 2025_4_25__15_5_32

# %%
filename = 'logSumExp_models/lse_' + current_datetime + '.pth'

torch.save(trained_lse_info, filename)

# %% [markdown]
# ### plot training loss and learning rate

# %%
plt.figure(figsize=(10,2))
plt.subplot(1,2,1)
plt.plot(training_loss)
plt.title('training_loss')
plt.grid()
plt.subplot(1,2,2)
plt.plot(learning_rate)
plt.title('learning_rate')
plt.grid()

plt.show()

# %% [markdown]
# ### Evaluate the network on a validation dataset

# %%
b_min_v = b_array[0]
b_max_v = b_array[-1]
b_grow_v = 1.01
b_array_v = createBetaArray(b_min_v, b_max_v, b_grow_v)
n_curves_v = 1
D_min_range_v = [0.0,0.2]
D_max_range_v = [1.0,1.0]
D_max_scale_v = np.max(np.array(D_min_range_v) + np.array(D_max_range_v))
len_Darray_range_v = len_Darray_range
In_val, Out_val, len_D_ARR_v = logsum_dataset(n_curves=n_curves_v, 
                    b_min=b_min_v, b_max=b_max_v, b_grow=b_grow_v, D_min_range=D_min_range_v, 
                    D_max_range=D_max_range_v, D_max_scale=D_max_scale_v, 
                    len_Darray_range=len_Darray_range_v, 
                    approx_log_sum_flr=True, io_scale=IO_scale)
pred_val = NN_logSum(In_val).detach()

st = 0
Out_val_np = (Out_val.numpy().flatten()/IO_scale)[st:] - 0*(1 / np.tile(b_array_v, n_curves_v) * np.log(len_D_ARR_v))[st:] + (In_val[:,1].numpy().flatten()/IO_scale)[st:]
pred_val_np = (pred_val.numpy().flatten()/IO_scale)[st:] - 0*(1 / np.tile(b_array_v, n_curves_v) * np.log(len_D_ARR_v))[st:] + (In_val[:,1].numpy().flatten()/IO_scale)[st:]

plt.figure(figsize=(12,4))
plt.subplot(2,1,1)
plt.plot(Out_val_np, label='target', color='violet', linestyle='dashed', linewidth=3)
plt.plot(pred_val_np, label='prediction', color='black')
plt.grid()
plt.xticks()
plt.legend()

plt.subplot(2,1,2)
error_val = np.abs(pred_val_np - Out_val_np)
# plt.subplot(1,2,2)
plt.plot(error_val, label='error', color='red')
plt.legend()
plt.grid()

plt.show()

# %%
Out_val_np.shape
# Out:
# (1120,)

# %%
b_array_v.shape
# Out:
# (280,)

# %%
np.tile(b_array_v, n_curves_v).shape
# Out:
# (1120,)
