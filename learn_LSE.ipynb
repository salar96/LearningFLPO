# %%
import numpy as np
import matplotlib.pyplot as plt
import LSE_net
import torch
import importlib
import pickle
import datetime

# %%
def myLog(x, base):
    return np.log(x)/np.log(base)

def createBetaArray(min, max, grow):
    beta = min
    beta_array = [beta]
    while beta <= max:
        beta = beta*grow
        beta_array.append(beta)
    beta_array = np.array(beta_array)
    return beta_array

def logSumExp(D_array, beta):
    D_min = np.min(D_array)
    D_off = D_array - D_min
    F = -1/beta * np.log(np.sum(np.exp(-beta*D_off))) + 1/beta * np.log(len(D_array))
    # F = -np.log(np.sum(np.exp(-beta*D_off))) + np.log(len(D_array)) + D_min * beta
    return F

# %%
np.random.seed(10)
D_array = np.random.uniform(10,100,20)
print(D_array.min())
beta0 = 1
logSumExp(D_array, beta0)
# Out:
# 10.355343969512301
# 2.7961450054117143

# %%
d1 = 10
d2 = 30
d3 = 40
d4 = 50
b0 = 1e-5
l0 = 1/b0 * np.log(4)
l1 = -1/b0 * np.log(np.exp(-b0*d1) + np.exp(-b0*d2) + np.exp(-b0*d3) + np.exp(-b0*d4)) + l0
l2 = -1/b0 * np.log(4)
l3 = l2 + d1 - 1/b0 * np.log((1 + np.exp(-b0*(d2-d1)) + np.exp(-b0*(d3-d1)) + np.exp(-b0*(d4-d1)))/4) + l0
l4 = l2 + d1 - 1/b0 * np.log((1 + np.exp(-b0*d1) + np.exp(-b0*1.5*d1) + np.exp(-b0*4*d1))/4) + l0
print(f'l0:{l0:.3f}\nl1:{l1:.3f}\nl2:{l2:.3f}\nl3:{l3:.3f}\nl4:{l4:.3f}\nl2-l1:{l2+l0-l1:.3f}\nl3-l1:{l3-l1:.3f}\nl4-l1:{l4-l1:.3f}')
# Out:
# l0:138629.436
# l1:32.499
# l2:-138629.436
# l3:32.499
# l4:26.249
# l2-l1:-32.499
# l3-l1:0.000
# l4-l1:-6.250

# %% [markdown]
# ### Create dataset

# %%
# function to generate logsum dataset
def logsum_dataset(n_curves, b_min, b_max, b_grow, D_min_range, D_max_range, len_Darray, approx_log_sum_flr, io_scale):
    b_array = createBetaArray(b_min, b_max, b_grow)
    n_beta_per_curve = len(b_array)
    n_data = n_curves * n_beta_per_curve
    In = torch.zeros((n_data, 3), dtype=torch.float32)
    Out = torch.zeros((n_data,1), dtype=torch.float32)

    cnt = 0
    for c in range(n_curves):
        
        D_min = np.random.uniform(D_min_range[0], D_min_range[1])
        D_max = D_min + np.random.uniform(D_max_range[0], D_max_range[1])
        D_array = np.random.uniform(D_min, D_max, len_Darray)
        if approx_log_sum_flr:
            D_array_dum = np.arange(1,len_Darray+1)*2 + D_min
            F_min = logSumExp(D_array_dum, b_min)
        else:
            F_min = logSumExp(D_array, b_min)
        F_min = io_scale * F_min
        F_max = io_scale * np.min(D_array)

        for b in b_array:
            Fb = io_scale * logSumExp(D_array, b)
            In[cnt,:] = torch.tensor([F_min, F_max, b])
            Out[cnt,:] = torch.tensor([Fb])
            cnt += 1

    return In, Out

# %%
# beta limits
b_min = 1e-5
b_max = 1e6
b_grow = 1.05
b_array = createBetaArray(b_min, b_max, b_grow)
print(f'len b_array: {b_array.shape}')

# torch input and output arrays
n_curves = 50
len_Darray = 200
D_min_range = [0.01, 10] # minimum value of D_array is picked at random from this range
D_max_range = [10, 100] # maximum value of D_array is picked at random from the range dmin + D_max_range
IO_scale = 1

In, Out = logsum_dataset(n_curves, b_min, b_max, b_grow, D_min_range, D_max_range, len_Darray, approx_log_sum_flr=False, io_scale=IO_scale)
print(f'In: {In.size()}\tOut: {Out.size()}')
# Out:
# len b_array: (521,)
# In: torch.Size([26050, 3])	Out: torch.Size([26050, 1])

# %% [markdown]
# ### Visualize Data

# %%
def visualizeData(In, Out, n_end):

    plt.figure(figsize=(12,8))

    plt.subplot(2,2,1)
    plt.plot(In[:n_end,0], label='F_min')
    plt.legend()
    plt.grid()

    plt.subplot(2,2,2)
    plt.plot(In[:n_end,1], label='F_max')
    plt.legend()
    plt.grid()

    plt.subplot(2,2,3)
    plt.plot(In[:n_end,2], label='beta')
    plt.legend()
    plt.grid()

    plt.subplot(2,2,4)
    plt.plot(In[:n_end,0], label='F_min', linestyle='dashed', linewidth=2)
    plt.plot(In[:n_end,1], label='F_max', linestyle='dashed', linewidth=2)
    plt.plot(Out[:n_end], label='F_beta')
    plt.legend()
    plt.grid()

    plt.show()

visualizeData(In, Out, n_end=1000)

# %% [markdown]
# ### Create neural net for training

# %%
importlib.reload(LSE_net)

# create DNN
n_inputs = In.size()[1]
n_outputs = Out.size()[1]
layers = [20, 20, 10]
NN_logSum = LSE_net.dnn(n_inputs, n_outputs, layers)
print(f'DNN model:\n{NN_logSum}')

# create training, and testing dataset
n_samples = In.size()[0]
frac_train = 1.0
n_train = int(frac_train * n_samples)
indices = torch.arange(n_samples)
train_indices = indices[:n_train]
test_indices = indices[n_train:]
In_train = In[train_indices]
Out_train = Out[train_indices]
In_test = In[test_indices]
Out_test = Out[test_indices]
# Out:
# DNN model:
# dnn(
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=20, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=20, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )

# %%
In[0]
# Out:
# tensor([2.3582e+01, 4.5478e+00, 1.0000e-05])

# %%
NN_logSum(In).detach().numpy()
# Out:
# array([[7.8715503e-01],
#        [7.8715509e-01],
#        [7.8715509e-01],
#        ...,
#        [8.9130752e+03],
#        [9.3587236e+03],
#        [9.8266494e+03]], dtype=float32)

# %%
visualizeData(In_train, Out_train, n_end=2000)
visualizeData(In_test, Out_test, n_end=2000)

# %% [markdown]
# ### train the network

# %%
# dnn configuration
optimizer_name = 'adam'
lr_scheduler = 'ReduceLROnPlateau'
lr0 = 0.0005
epochs = 200
batch_size = 70
loss_coeffs = [1.0, 0.0]
loss_fn, optimizer, scheduler = LSE_net.config_nn(NN_logSum, optimizer_name, lr_scheduler, lr0)
loss = loss_fn(NN_logSum(In_train[0]), Out_train[0]).detach().item()
training_loss, learning_rate, stopping_epoch = LSE_net.train_nn1(
    NN_logSum, In_train, Out_train, loss_fn,
    optimizer, scheduler, loss_coeffs=loss_coeffs,
    epochs=epochs, batch_size=batch_size, allowPrint=True)
# Out:
# ---------------------------------
# training data size = 26050
# training batch size = 70
# n_epochs = 200
# n_batches = 373
# loss weights = [1.0, 0.0]
# ---------------------------------
#
# batch_split
# 0 69
# 70 139
# 140 209
# 210 279
# 280 349
# 350 419
# 420 489
# 490 559
# 560 629
# 630 699
# 700 769
# 770 839
# 840 909
# 910 979
# 980 1049
# 1050 1119
# 1120 1189
# 1190 1259
# 1260 1329
# 1330 1399
# 1400 1469
# 1470 1539
# 1540 1609
# 1610 1679
# 1680 1749
# 1750 1819
# 1820 1889
# 1890 1959
# 1960 2029
# 2030 2099
# 2100 2169
# 2170 2239
# 2240 2309
# 2310 2379
# 2380 2449
# 2450 2519
# 2520 2589
# 2590 2659
# 2660 2729
# 2730 2799
# 2800 2869
# 2870 2939
# 2940 3009
# 3010 3079
# 3080 3149
# 3150 3219
# 3220 3289
# 3290 3359
# 3360 3429
# 3430 3499
# 3500 3569
# 3570 3639
# 3640 3709
# 3710 3779
# 3780 3849
# 3850 3919
# 3920 3989
# 3990 4059
# 4060 4129
# 4130 4199
# 4200 4269
# 4270 4339
# 4340 4409
# 4410 4479
# 4480 4549
# 4550 4619
# 4620 4689
# 4690 4759
# 4760 4829
# 4830 4899
# 4900 4969
# 4970 5039
# 5040 5109
# 5110 5179
# 5180 5249
# 5250 5319
# 5320 5389
# 5390 5459
# 5460 5529
# 5530 5599
# 5600 5669
# 5670 5739
# 5740 5809
# 5810 5879
# 5880 5949
# 5950 6019
# 6020 6089
# 6090 6159
# 6160 6229
# 6230 6299
# 6300 6369
# 6370 6439
# 6440 6509
# 6510 6579
# 6580 6649
# 6650 6719
# 6720 6789
# 6790 6859
# 6860 6929
# 6930 6999
# 7000 7069
# 7070 7139
# 7140 7209
# 7210 7279
# 7280 7349
# 7350 7419
# 7420 7489
# 7490 7559
# 7560 7629
# 7630 7699
# 7700 7769
# 7770 7839
# 7840 7909
# 7910 7979
# 7980 8049
# 8050 8119
# 8120 8189
# 8190 8259
# 8260 8329
# 8330 8399
# 8400 8469
# 8470 8539
# 8540 8609
# 8610 8679
# 8680 8749
# 8750 8819
# 8820 8889
# 8890 8959
# 8960 9029
# 9030 9099
# 9100 9169
# 9170 9239
# 9240 9309
# 9310 9379
# 9380 9449
# 9450 9519
# 9520 9589
# 9590 9659
# 9660 9729
# 9730 9799
# 9800 9869
# 9870 9939
# 9940 10009
# 10010 10079
# 10080 10149
# 10150 10219
# 10220 10289
# 10290 10359
# 10360 10429
# 10430 10499
# 10500 10569
# 10570 10639
# 10640 10709
# 10710 10779
# 10780 10849
# 10850 10919
# 10920 10989
# 10990 11059
# 11060 11129
# 11130 11199
# 11200 11269
# 11270 11339
# 11340 11409
# 11410 11479
# 11480 11549
# 11550 11619
# 11620 11689
# 11690 11759
# 11760 11829
# 11830 11899
# 11900 11969
# 11970 12039
# 12040 12109
# 12110 12179
# 12180 12249
# 12250 12319
# 12320 12389
# 12390 12459
# 12460 12529
# 12530 12599
# 12600 12669
# 12670 12739
# 12740 12809
# 12810 12879
# 12880 12949
# 12950 13019
# 13020 13089
# 13090 13159
# 13160 13229
# 13230 13299
# 13300 13369
# 13370 13439
# 13440 13509
# 13510 13579
# 13580 13649
# 13650 13719
# 13720 13789
# 13790 13859
# 13860 13929
# 13930 13999
# 14000 14069
# 14070 14139
# 14140 14209
# 14210 14279
# 14280 14349
# 14350 14419
# 14420 14489
# 14490 14559
# 14560 14629
# 14630 14699
# 14700 14769
# 14770 14839
# 14840 14909
# 14910 14979
# 14980 15049
# 15050 15119
# 15120 15189
# 15190 15259
# 15260 15329
# 15330 15399
# 15400 15469
# 15470 15539
# 15540 15609
# 15610 15679
# 15680 15749
# 15750 15819
# 15820 15889
# 15890 15959
# 15960 16029
# 16030 16099
# 16100 16169
# 16170 16239
# 16240 16309
# 16310 16379
# 16380 16449
# 16450 16519
# 16520 16589
# 16590 16659
# 16660 16729
# 16730 16799
# 16800 16869
# 16870 16939
# 16940 17009
# 17010 17079
# 17080 17149
# 17150 17219
# 17220 17289
# 17290 17359
# 17360 17429
# 17430 17499
# 17500 17569
# 17570 17639
# 17640 17709
# 17710 17779
# 17780 17849
# 17850 17919
# 17920 17989
# 17990 18059
# 18060 18129
# 18130 18199
# 18200 18269
# 18270 18339
# 18340 18409
# 18410 18479
# 18480 18549
# 18550 18619
# 18620 18689
# 18690 18759
# 18760 18829
# 18830 18899
# 18900 18969
# 18970 19039
# 19040 19109
# 19110 19179
# 19180 19249
# 19250 19319
# 19320 19389
# 19390 19459
# 19460 19529
# 19530 19599
# 19600 19669
# 19670 19739
# 19740 19809
# 19810 19879
# 19880 19949
# 19950 20019
# 20020 20089
# 20090 20159
# 20160 20229
# 20230 20299
# 20300 20369
# 20370 20439
# 20440 20509
# 20510 20579
# 20580 20649
# 20650 20719
# 20720 20789
# 20790 20859
# 20860 20929
# 20930 20999
# 21000 21069
# 21070 21139
# 21140 21209
# 21210 21279
# 21280 21349
# 21350 21419
# 21420 21489
# 21490 21559
# 21560 21629
# 21630 21699
# 21700 21769
# 21770 21839
# 21840 21909
# 21910 21979
# 21980 22049
# 22050 22119
# 22120 22189
# 22190 22259
# 22260 22329
# 22330 22399
# 22400 22469
# 22470 22539
# 22540 22609
# 22610 22679
# 22680 22749
# 22750 22819
# 22820 22889
# 22890 22959
# 22960 23029
# 23030 23099
# 23100 23169
# 23170 23239
# 23240 23309
# 23310 23379
# 23380 23449
# 23450 23519
# 23520 23589
# 23590 23659
# 23660 23729
# 23730 23799
# 23800 23869
# 23870 23939
# 23940 24009
# 24010 24079
# 24080 24149
# 24150 24219
# 24220 24289
# 24290 24359
# 24360 24429
# 24430 24499
# 24500 24569
# 24570 24639
# 24640 24709
# 24710 24779
# 24780 24849
# 24850 24919
# 24920 24989
# 24990 25059
# 25060 25129
# 25130 25199
# 25200 25269
# 25270 25339
# 25340 25409
# 25410 25479
# 25480 25549
# 25550 25619
# 25620 25689
# 25690 25759
# 25760 25829
# 25830 25899
# 25900 25969
# 25970 26039
# 26040 26049
#
#
#
# ---------------------------------
# epoch: 0/200, 	 loss: 24299490.410 	 rel:1000.0, 	 time: 0.74
# epoch: 1/200, 	 loss: 24299490.410 	 rel:1000.0, 	 time: 0.74
# epoch: 2/200, 	 loss: 28088.945 	 rel:1.2, 	 time: 0.62
# epoch: 3/200, 	 loss: 24182.257 	 rel:1.0, 	 time: 0.61
# epoch: 4/200, 	 loss: 21179.911 	 rel:0.9, 	 time: 0.60
# epoch: 5/200, 	 loss: 17988.520 	 rel:0.7, 	 time: 0.59
# epoch: 6/200, 	 loss: 14089.878 	 rel:0.6, 	 time: 0.60
# epoch: 7/200, 	 loss: 10557.083 	 rel:0.4, 	 time: 0.60
# epoch: 8/200, 	 loss: 7939.164 	 rel:0.3, 	 time: 0.60
# epoch: 9/200, 	 loss: 6080.646 	 rel:0.3, 	 time: 0.60
# epoch: 10/200, 	 loss: 4756.308 	 rel:0.2, 	 time: 0.60
# epoch: 11/200, 	 loss: 3771.798 	 rel:0.2, 	 time: 0.61
# epoch: 12/200, 	 loss: 3043.583 	 rel:0.1, 	 time: 0.75
# epoch: 13/200, 	 loss: 2480.015 	 rel:0.1, 	 time: 0.84
# epoch: 14/200, 	 loss: 2039.848 	 rel:0.1, 	 time: 0.84
# epoch: 15/200, 	 loss: 1683.249 	 rel:0.1, 	 time: 0.82
# epoch: 16/200, 	 loss: 1427.786 	 rel:0.1, 	 time: 0.82
# epoch: 17/200, 	 loss: 1148.379 	 rel:0.0, 	 time: 0.84
# epoch: 18/200, 	 loss: 948.917 	 rel:0.0, 	 time: 0.84
# epoch: 19/200, 	 loss: 827.504 	 rel:0.0, 	 time: 0.83
# epoch: 20/200, 	 loss: 650.174 	 rel:0.0, 	 time: 0.82
# epoch: 21/200, 	 loss: 6472.709 	 rel:0.3, 	 time: 0.83
# epoch: 22/200, 	 loss: 490.157 	 rel:0.0, 	 time: 0.82
# epoch: 23/200, 	 loss: 7742.775 	 rel:0.3, 	 time: 0.82
# epoch: 24/200, 	 loss: 401.543 	 rel:0.0, 	 time: 0.83
# epoch: 25/200, 	 loss: 9927.574 	 rel:0.4, 	 time: 0.89
# epoch: 26/200, 	 loss: 318.616 	 rel:0.0, 	 time: 0.84
# epoch: 27/200, 	 loss: 2894.702 	 rel:0.1, 	 time: 0.82
# epoch: 28/200, 	 loss: 4826.060 	 rel:0.2, 	 time: 0.83
# epoch: 29/200, 	 loss: 1962.121 	 rel:0.1, 	 time: 0.83
# epoch: 30/200, 	 loss: 3282.291 	 rel:0.1, 	 time: 0.83
# epoch: 31/200, 	 loss: 3231.809 	 rel:0.1, 	 time: 0.82
# epoch: 32/200, 	 loss: 3281.814 	 rel:0.1, 	 time: 0.83
# epoch: 33/200, 	 loss: 2348.120 	 rel:0.1, 	 time: 0.86
# epoch: 34/200, 	 loss: 1129.641 	 rel:0.0, 	 time: 0.83
# epoch: 35/200, 	 loss: 1248.625 	 rel:0.1, 	 time: 0.82
# epoch: 36/200, 	 loss: 1516.882 	 rel:0.1, 	 time: 0.82
# epoch: 37/200, 	 loss: 7419.468 	 rel:0.3, 	 time: 0.83
# epoch: 38/200, 	 loss: 205.778 	 rel:0.0, 	 time: 0.83
# epoch: 39/200, 	 loss: 820.055 	 rel:0.0, 	 time: 0.83
# epoch: 40/200, 	 loss: 6498.905 	 rel:0.3, 	 time: 0.83
# epoch: 41/200, 	 loss: 154.586 	 rel:0.0, 	 time: 0.82
# epoch: 42/200, 	 loss: 1215.237 	 rel:0.1, 	 time: 0.83
# epoch: 43/200, 	 loss: 2482.576 	 rel:0.1, 	 time: 0.86
# epoch: 44/200, 	 loss: 1696.054 	 rel:0.1, 	 time: 0.84
# epoch: 45/200, 	 loss: 1316.796 	 rel:0.1, 	 time: 0.83
# epoch: 46/200, 	 loss: 2328.557 	 rel:0.1, 	 time: 0.83
# epoch: 47/200, 	 loss: 1900.504 	 rel:0.1, 	 time: 0.82
# epoch: 48/200, 	 loss: 1401.227 	 rel:0.1, 	 time: 0.83
# epoch: 49/200, 	 loss: 2252.837 	 rel:0.1, 	 time: 0.82
# epoch: 50/200, 	 loss: 856.863 	 rel:0.0, 	 time: 0.82
# epoch: 51/200, 	 loss: 1546.010 	 rel:0.1, 	 time: 0.83
# epoch: 52/200, 	 loss: 1430.383 	 rel:0.1, 	 time: 0.82
# epoch: 53/200, 	 loss: 1125.880 	 rel:0.0, 	 time: 0.83
# epoch: 54/200, 	 loss: 1304.551 	 rel:0.1, 	 time: 0.82
# epoch: 55/200, 	 loss: 994.567 	 rel:0.0, 	 time: 0.82
# epoch: 56/200, 	 loss: 1139.945 	 rel:0.0, 	 time: 0.90
# epoch: 57/200, 	 loss: 585.373 	 rel:0.0, 	 time: 0.83
# epoch: 58/200, 	 loss: 1238.841 	 rel:0.1, 	 time: 0.83
# epoch: 59/200, 	 loss: 548.813 	 rel:0.0, 	 time: 0.83
# epoch: 60/200, 	 loss: 1370.547 	 rel:0.1, 	 time: 0.83
# epoch: 61/200, 	 loss: 108.841 	 rel:0.0, 	 time: 0.83
# epoch: 62/200, 	 loss: 975.652 	 rel:0.0, 	 time: 0.83
# epoch: 63/200, 	 loss: 187.549 	 rel:0.0, 	 time: 0.82
# epoch: 64/200, 	 loss: 3045.412 	 rel:0.1, 	 time: 0.83
# epoch: 65/200, 	 loss: 86.458 	 rel:0.0, 	 time: 0.82
# epoch: 66/200, 	 loss: 73.957 	 rel:0.0, 	 time: 0.83
# epoch: 67/200, 	 loss: 132.084 	 rel:0.0, 	 time: 0.83
# epoch: 68/200, 	 loss: 3412.151 	 rel:0.1, 	 time: 0.83
# epoch: 69/200, 	 loss: 71.981 	 rel:0.0, 	 time: 0.83
# epoch: 70/200, 	 loss: 79.453 	 rel:0.0, 	 time: 0.83
# epoch: 71/200, 	 loss: 68.917 	 rel:0.0, 	 time: 0.85
# epoch: 72/200, 	 loss: 180.967 	 rel:0.0, 	 time: 0.83
# epoch: 73/200, 	 loss: 1533.773 	 rel:0.1, 	 time: 0.83
# epoch: 74/200, 	 loss: 87.080 	 rel:0.0, 	 time: 0.83
# epoch: 75/200, 	 loss: 95.181 	 rel:0.0, 	 time: 0.82
# epoch: 76/200, 	 loss: 872.881 	 rel:0.0, 	 time: 0.83
# epoch: 77/200, 	 loss: 90.883 	 rel:0.0, 	 time: 0.82
# epoch: 78/200, 	 loss: 74.914 	 rel:0.0, 	 time: 0.83
# epoch: 79/200, 	 loss: 612.383 	 rel:0.0, 	 time: 0.82
# epoch: 80/200, 	 loss: 61.237 	 rel:0.0, 	 time: 0.83
# epoch: 81/200, 	 loss: 65.183 	 rel:0.0, 	 time: 0.83
# epoch: 82/200, 	 loss: 2208.316 	 rel:0.1, 	 time: 0.86
# epoch: 83/200, 	 loss: 57.158 	 rel:0.0, 	 time: 0.82
# epoch: 84/200, 	 loss: 57.605 	 rel:0.0, 	 time: 0.88
# epoch: 85/200, 	 loss: 56.919 	 rel:0.0, 	 time: 0.95
# epoch: 86/200, 	 loss: 56.147 	 rel:0.0, 	 time: 0.82
# epoch: 87/200, 	 loss: 56.027 	 rel:0.0, 	 time: 0.83
# epoch: 88/200, 	 loss: 55.542 	 rel:0.0, 	 time: 0.83
# epoch: 89/200, 	 loss: 158.694 	 rel:0.0, 	 time: 0.82
# epoch: 90/200, 	 loss: 54.245 	 rel:0.0, 	 time: 0.83
# epoch: 91/200, 	 loss: 76.483 	 rel:0.0, 	 time: 0.83
# epoch: 92/200, 	 loss: 3699.167 	 rel:0.2, 	 time: 0.83
# epoch: 93/200, 	 loss: 53.566 	 rel:0.0, 	 time: 0.83
# epoch: 94/200, 	 loss: 57.999 	 rel:0.0, 	 time: 0.83
# epoch: 95/200, 	 loss: 121.784 	 rel:0.0, 	 time: 0.85
# epoch: 96/200, 	 loss: 271.035 	 rel:0.0, 	 time: 0.84
# epoch: 97/200, 	 loss: 83.271 	 rel:0.0, 	 time: 0.82
# epoch: 98/200, 	 loss: 802.143 	 rel:0.0, 	 time: 0.83
# epoch: 99/200, 	 loss: 51.913 	 rel:0.0, 	 time: 0.83
# epoch: 100/200, 	 loss: 58.538 	 rel:0.0, 	 time: 0.83
# epoch: 101/200, 	 loss: 55.405 	 rel:0.0, 	 time: 0.82
# epoch: 102/200, 	 loss: 523.128 	 rel:0.0, 	 time: 0.83
# epoch: 103/200, 	 loss: 50.066 	 rel:0.0, 	 time: 0.83
# epoch: 104/200, 	 loss: 59.169 	 rel:0.0, 	 time: 0.83
# epoch: 105/200, 	 loss: 75.678 	 rel:0.0, 	 time: 0.83
# epoch: 106/200, 	 loss: 86.965 	 rel:0.0, 	 time: 0.83
# epoch: 107/200, 	 loss: 2511.742 	 rel:0.1, 	 time: 0.83
# epoch: 108/200, 	 loss: 48.143 	 rel:0.0, 	 time: 0.83
# epoch: 109/200, 	 loss: 41.271 	 rel:0.0, 	 time: 0.84
# epoch: 110/200, 	 loss: 38.181 	 rel:0.0, 	 time: 0.83
# epoch: 111/200, 	 loss: 36.772 	 rel:0.0, 	 time: 0.83
# epoch: 112/200, 	 loss: 36.244 	 rel:0.0, 	 time: 0.82
# epoch: 113/200, 	 loss: 35.822 	 rel:0.0, 	 time: 0.83
# epoch: 114/200, 	 loss: 35.486 	 rel:0.0, 	 time: 0.91
# epoch: 115/200, 	 loss: 35.092 	 rel:0.0, 	 time: 0.84
# epoch: 116/200, 	 loss: 34.905 	 rel:0.0, 	 time: 0.84
# epoch: 117/200, 	 loss: 34.885 	 rel:0.0, 	 time: 0.83
# epoch: 118/200, 	 loss: 34.306 	 rel:0.0, 	 time: 0.83
# epoch: 119/200, 	 loss: 34.330 	 rel:0.0, 	 time: 0.89
# epoch: 120/200, 	 loss: 34.048 	 rel:0.0, 	 time: 1.03
# epoch: 121/200, 	 loss: 33.315 	 rel:0.0, 	 time: 1.52
# epoch: 122/200, 	 loss: 33.425 	 rel:0.0, 	 time: 2.04
# epoch: 123/200, 	 loss: 32.572 	 rel:0.0, 	 time: 1.11
# epoch: 124/200, 	 loss: 32.322 	 rel:0.0, 	 time: 2.15
# epoch: 125/200, 	 loss: 35.788 	 rel:0.0, 	 time: 1.34
# epoch: 126/200, 	 loss: 31.001 	 rel:0.0, 	 time: 1.11
# epoch: 127/200, 	 loss: 31.097 	 rel:0.0, 	 time: 0.95
# epoch: 128/200, 	 loss: 34.792 	 rel:0.0, 	 time: 0.91
# epoch: 129/200, 	 loss: 30.441 	 rel:0.0, 	 time: 1.09
# epoch: 130/200, 	 loss: 30.434 	 rel:0.0, 	 time: 1.00
# epoch: 131/200, 	 loss: 34.447 	 rel:0.0, 	 time: 1.03
# epoch: 132/200, 	 loss: 29.871 	 rel:0.0, 	 time: 0.93
# epoch: 133/200, 	 loss: 30.063 	 rel:0.0, 	 time: 1.17
# epoch: 134/200, 	 loss: 31.108 	 rel:0.0, 	 time: 1.11
# epoch: 135/200, 	 loss: 30.608 	 rel:0.0, 	 time: 1.02
# epoch: 136/200, 	 loss: 29.787 	 rel:0.0, 	 time: 1.03
# epoch: 137/200, 	 loss: 30.570 	 rel:0.0, 	 time: 1.16
# epoch: 138/200, 	 loss: 30.202 	 rel:0.0, 	 time: 1.19
# epoch: 139/200, 	 loss: 29.040 	 rel:0.0, 	 time: 1.19
# epoch: 140/200, 	 loss: 30.640 	 rel:0.0, 	 time: 0.98
# epoch: 141/200, 	 loss: 403.960 	 rel:0.0, 	 time: 0.86
# epoch: 142/200, 	 loss: 1641.406 	 rel:0.1, 	 time: 0.85
# epoch: 143/200, 	 loss: 31.430 	 rel:0.0, 	 time: 0.85
# epoch: 144/200, 	 loss: 29.172 	 rel:0.0, 	 time: 0.87
# epoch: 145/200, 	 loss: 32.604 	 rel:0.0, 	 time: 0.86
# epoch: 146/200, 	 loss: 28.510 	 rel:0.0, 	 time: 0.84
# epoch: 147/200, 	 loss: 28.742 	 rel:0.0, 	 time: 0.89
# epoch: 148/200, 	 loss: 39.481 	 rel:0.0, 	 time: 0.97
# epoch: 149/200, 	 loss: 29.882 	 rel:0.0, 	 time: 1.46
# epoch: 150/200, 	 loss: 28.711 	 rel:0.0, 	 time: 0.89
# epoch: 151/200, 	 loss: 27.874 	 rel:0.0, 	 time: 0.83
# epoch: 152/200, 	 loss: 28.195 	 rel:0.0, 	 time: 0.82
# epoch: 153/200, 	 loss: 28.948 	 rel:0.0, 	 time: 0.84
# epoch: 154/200, 	 loss: 28.080 	 rel:0.0, 	 time: 0.83
# epoch: 155/200, 	 loss: 28.869 	 rel:0.0, 	 time: 0.84
# epoch: 156/200, 	 loss: 27.641 	 rel:0.0, 	 time: 0.83
# epoch: 157/200, 	 loss: 28.850 	 rel:0.0, 	 time: 0.82
# epoch: 158/200, 	 loss: 27.978 	 rel:0.0, 	 time: 0.82
# epoch: 159/200, 	 loss: 28.029 	 rel:0.0, 	 time: 1.10
# epoch: 160/200, 	 loss: 27.699 	 rel:0.0, 	 time: 0.92
# epoch: 161/200, 	 loss: 27.437 	 rel:0.0, 	 time: 0.86
# epoch: 162/200, 	 loss: 28.507 	 rel:0.0, 	 time: 0.84
# epoch: 163/200, 	 loss: 27.139 	 rel:0.0, 	 time: 0.84
# epoch: 164/200, 	 loss: 28.369 	 rel:0.0, 	 time: 0.83
# epoch: 165/200, 	 loss: 27.359 	 rel:0.0, 	 time: 0.82
# epoch: 166/200, 	 loss: 27.595 	 rel:0.0, 	 time: 0.87
# epoch: 167/200, 	 loss: 27.459 	 rel:0.0, 	 time: 0.88
# epoch: 168/200, 	 loss: 28.007 	 rel:0.0, 	 time: 0.86
# epoch: 169/200, 	 loss: 26.918 	 rel:0.0, 	 time: 0.83
# epoch: 170/200, 	 loss: 27.913 	 rel:0.0, 	 time: 0.83
# epoch: 171/200, 	 loss: 26.953 	 rel:0.0, 	 time: 0.85
# epoch: 172/200, 	 loss: 27.361 	 rel:0.0, 	 time: 0.83
# epoch: 173/200, 	 loss: 27.280 	 rel:0.0, 	 time: 1.09
# epoch: 174/200, 	 loss: 27.172 	 rel:0.0, 	 time: 1.18
# epoch: 175/200, 	 loss: 27.657 	 rel:0.0, 	 time: 0.93
# epoch: 176/200, 	 loss: 26.718 	 rel:0.0, 	 time: 0.84
# epoch: 177/200, 	 loss: 27.319 	 rel:0.0, 	 time: 0.84
# epoch: 178/200, 	 loss: 26.502 	 rel:0.0, 	 time: 1.01
# epoch: 179/200, 	 loss: 27.456 	 rel:0.0, 	 time: 1.07
# epoch: 180/200, 	 loss: 26.339 	 rel:0.0, 	 time: 1.23
# epoch: 181/200, 	 loss: 27.187 	 rel:0.0, 	 time: 1.05
# epoch: 182/200, 	 loss: 26.176 	 rel:0.0, 	 time: 0.94
# epoch: 183/200, 	 loss: 27.007 	 rel:0.0, 	 time: 0.98
# epoch: 184/200, 	 loss: 26.419 	 rel:0.0, 	 time: 0.87
# epoch: 185/200, 	 loss: 26.806 	 rel:0.0, 	 time: 0.87
# epoch: 186/200, 	 loss: 25.963 	 rel:0.0, 	 time: 0.87
# epoch: 187/200, 	 loss: 26.945 	 rel:0.0, 	 time: 0.86
# epoch: 188/200, 	 loss: 25.904 	 rel:0.0, 	 time: 0.86
# epoch: 189/200, 	 loss: 27.039 	 rel:0.0, 	 time: 0.85
# epoch: 190/200, 	 loss: 25.902 	 rel:0.0, 	 time: 0.85
# epoch: 191/200, 	 loss: 26.746 	 rel:0.0, 	 time: 0.85
# epoch: 192/200, 	 loss: 26.352 	 rel:0.0, 	 time: 0.86
# epoch: 193/200, 	 loss: 26.317 	 rel:0.0, 	 time: 0.86
# epoch: 194/200, 	 loss: 25.979 	 rel:0.0, 	 time: 0.86
# epoch: 195/200, 	 loss: 26.739 	 rel:0.0, 	 time: 0.86
# epoch: 196/200, 	 loss: 25.984 	 rel:0.0, 	 time: 0.94
# epoch: 197/200, 	 loss: 25.723 	 rel:0.0, 	 time: 0.89
# epoch: 198/200, 	 loss: 31.735 	 rel:0.0, 	 time: 0.88
# epoch: 199/200, 	 loss: 25.871 	 rel:0.0, 	 time: 0.86
# epoch: 200/200, 	 loss: 25.470 	 rel:0.0, 	 time: 0.84
# Maximum Iterations Reached
# ---------------------------------

# %%
# trained_dnn_info = {
#     'model_state_dict': NN_logSum.state_dict(), 
#     'n_inputs':n_inputs,
#     'n_outputs':n_outputs,
#     'layers':layers,
#     'b_arr':b_array, 
#     'len_Darray':len_Darray, 
#     'D_min_range':D_min_range,
#     'D_max_range':D_max_range,
#     'io_scale':IO_scale,
#     'n_samples':n_samples,
#     'frac_train':frac_train,
#     'optimizer_name':optimizer,
#     'optimize_state_dict':optimizer.state_dict(),
#     'lr_scheduler':lr_scheduler,
#     'lr0':lr0,
#     'loss_fn':loss_fn,
#     'epochs':epochs,
#     'batch_size':batch_size,
#     'training_loss':training_loss,
#     'learning_rate':learning_rate,
# }

# %% [markdown]
# ### Save the trained model

# %%
# # str(datetime.datetime.today()).split()
# current_time = datetime.datetime.now()
# yyyy = str(current_time.year)[2:]
# mm = str(current_time.month)
# dd = str(current_time.day)
# hh = str(current_time.hour)
# mt = str(current_time.minute)
# sec = str(current_time.second)
# current_datetime = yyyy + mm + dd + '_' + hh + mt + sec 
# print(current_datetime)
# Out:
# 25415_153930

# %%
# filename = 'logSumExp_models/dnn_' + current_datetime + '.pth'

# torch.save(trained_dnn_info, filename)

# %% [markdown]
# ### plot training loss and learning rate

# %%
plt.figure(figsize=(10,2))
plt.subplot(1,2,1)
plt.plot(training_loss)
plt.title('training_loss')
plt.grid()
plt.subplot(1,2,2)
plt.plot(learning_rate)
plt.title('learning_rate')
plt.grid()

plt.show()

# %% [markdown]
# ### Evaluate the network on a validation dataset

# %%
b_min_v = b_array[0]
b_max_v = b_array[-1]
b_grow_v = 1.1
b_array_v = createBetaArray(b_min_v, b_max_v, b_grow_v)
n_curves_v = 5
D_min_range_v = [10,100]
D_max_range_v = [100,1000]
len_Darray_v = len_Darray
In_val, Out_val = logsum_dataset(n_curves=n_curves_v, 
                    b_min=b_min_v, b_max=b_max_v, b_grow=b_grow_v, D_min_range=D_min_range_v, 
                    D_max_range=D_max_range_v, len_Darray=len_Darray_v, 
                    approx_log_sum_flr=False, io_scale=IO_scale)
pred_val = NN_logSum(In_val).detach()

st = 0
Out_val_np = (Out_val.numpy().flatten()/IO_scale)[st:] - (1 / np.tile(b_array_v, n_curves_v) * np.log(len_Darray_v))[st:] + (In_val[:,1].numpy().flatten()/IO_scale)[st:]
pred_val_np = (pred_val.numpy().flatten()/IO_scale)[st:] - (1 / np.tile(b_array_v, n_curves_v) * np.log(len_Darray_v))[st:] + (In_val[:,1].numpy().flatten()/IO_scale)[st:]

plt.figure(figsize=(12,4))
plt.subplot(2,1,1)
plt.plot(Out_val_np, label='target', color='violet', linestyle='dashed', linewidth=3)
plt.plot(pred_val_np, label='prediction', color='black')
plt.grid()
plt.xticks()
plt.legend()

plt.subplot(2,1,2)
error_val = np.abs(pred_val_np - Out_val_np)
# plt.subplot(1,2,2)
plt.plot(error_val, label='error', color='red')
plt.legend()
plt.grid()

plt.show()

# %%
Out_val_np.shape
# Out:
# (1120,)

# %%
b_array_v.shape
# Out:
# (280,)

# %%
np.tile(b_array_v, n_curves_v).shape
# Out:
# (1120,)
