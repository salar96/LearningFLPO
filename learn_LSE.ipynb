# %%
import numpy as np
import matplotlib.pyplot as plt
import LSE_net
import torch
import importlib
import pickle
import datetime

# %%
def myLog(x, base):
    return np.log(x)/np.log(base)

def createBetaArray(min, max, grow):
    beta = min
    beta_array = [beta]
    while beta <= max:
        beta = beta*grow
        beta_array.append(beta)
    beta_array = np.array(beta_array)
    return beta_array

def logSumExp(D_array, beta):
    D_min = np.min(D_array)
    D_off = D_array - D_min
    F = -1/beta * np.log(np.sum(np.exp(-beta*D_off))/len(D_array))
    # F = -np.log(np.sum(np.exp(-beta*D_off))) + np.log(len(D_array)) + D_min * beta
    return F

def gibbs(D_array, beta):
    D_min = np.min(D_array)
    D_off = D_array - D_min
    exp_bD = np.exp(-beta * D_off)
    sum_exp_bD = np.sum(exp_bD)
    P = exp_bD/sum_exp_bD
    return P

# %%
np.random.seed(10)
D_array = np.sort(np.random.uniform(10,100,10))
beta = 0.0001
P = gibbs(D_array, beta)
slopeP = (P[1:] - P[0:-1])/(D_array[1:]-D_array[0:-1])
plt.figure(figsize=(6,2))
plt.plot(D_array, P, marker='.')
plt.grid()

plt.figure(figsize=(6,2))
plt.plot(D_array[0:-1], slopeP, marker='.')
plt.grid()
plt.show()

# %%
d1 = 10
d2 = 30
d3 = 40
d4 = 50
b0 = 1e-5
l0 = 1/b0 * np.log(4)
l1 = -1/b0 * np.log(np.exp(-b0*d1) + np.exp(-b0*d2) + np.exp(-b0*d3) + np.exp(-b0*d4)) + l0
l2 = -1/b0 * np.log(4)
l3 = l2 + d1 - 1/b0 * np.log((1 + np.exp(-b0*(d2-d1)) + np.exp(-b0*(d3-d1)) + np.exp(-b0*(d4-d1)))/4) + l0
l4 = l2 + d1 - 1/b0 * np.log((1 + np.exp(-b0*d1) + np.exp(-b0*1.5*d1) + np.exp(-b0*4*d1))/4) + l0
print(f'l0:{l0:.3f}\nl1:{l1:.3f}\nl2:{l2:.3f}\nl3:{l3:.3f}\nl4:{l4:.3f}\nl2-l1:{l2+l0-l1:.3f}\nl3-l1:{l3-l1:.3f}\nl4-l1:{l4-l1:.3f}')
# Out:
# l0:138629.436
# l1:32.499
# l2:-138629.436
# l3:32.499
# l4:26.249
# l2-l1:-32.499
# l3-l1:0.000
# l4-l1:-6.250

# %% [markdown]
# ### Create dataset

# %%
# function to generate logsum dataset
def logsum_dataset(n_curves, b_min, b_max, b_grow, D_min_range, D_max_range, D_max_scale, len_Darray_range, approx_log_sum_flr, io_scale):
    b_array = createBetaArray(b_min, b_max, b_grow)
    n_beta_per_curve = len(b_array)
    n_data = n_curves * n_beta_per_curve
    In = torch.zeros((n_data, 3), dtype=torch.float32)
    Out = torch.zeros((n_data,1), dtype=torch.float32)
    len_D_ARR = []

    cnt = 0
    for c in range(n_curves):
        
        len_Darray = int(np.random.uniform(len_Darray_range[0], len_Darray_range[1]))
        D_min = np.random.uniform(D_min_range[0], D_min_range[1])
        D_max = D_min + np.random.uniform(D_max_range[0], D_max_range[1])
        D_array = np.random.uniform(D_min, D_max, len_Darray)
        if approx_log_sum_flr:
            D_array_dum = np.linspace(D_min, D_max_scale, len_Darray)
            F_min = logSumExp(D_array_dum, b_min)
            F_min1 = logSumExp(D_array, b_min)
            print(f"F_min approx: {F_min:.3e}")
            print(f"F_min true: {F_min1:.3e}")
            print(f"D_min approx:{D_array_dum}")
            print(f"D_min true:{np.sort(D_array)}")
        else:
            F_min = logSumExp(D_array, b_min)
            print(f"F_min true: {F_min:.3e}")
        F_min = io_scale * F_min
        F_max = io_scale * np.min(D_array)

        for b in b_array:
            Fb = io_scale * logSumExp(D_array, b)
            In[cnt,:] = torch.tensor([F_min, F_max, b])
            Out[cnt,:] = torch.tensor([Fb])
            len_D_ARR.append(len_Darray)
            cnt += 1

    return In, Out, len_D_ARR

# %%
# beta limits
b_min = 1e-4
b_max = 1e5
b_grow = 1.1
b_array = createBetaArray(b_min, b_max, b_grow)
print(f'len b_array:\t{b_array.shape}')

# torch input and output arrays
n_curves = 1
len_Darray_range = [10,10]
D_min_range = [0.001, 1] # minimum value of D_array is picked at random from this range
D_max_range = [1, 10] # maximum value of D_array is picked at random from the range dmin + D_max_range
D_max_scale = np.max(np.array(D_min_range) + np.array(D_max_range))
IO_scale = 1

In, Out, len_D_ARR = logsum_dataset(n_curves, b_min, b_max, b_grow, D_min_range, D_max_range, D_max_scale, len_Darray_range, approx_log_sum_flr=True, io_scale=IO_scale)
print(f'In:\t{In.size()}\nOut:\t{Out.size()}\nlen_D_ARR\tsize:{len(len_D_ARR)}\tmin:{np.min(len_D_ARR)}\tmax:{np.max(len_D_ARR)}\tmean:{np.mean(len_D_ARR)}')
# Out:
# len b_array:	(219,)
# F_min approx: 5.120e+00
# F_min true: 3.342e+00
# D_min approx:[ 0.75793239  1.8959399   3.03394741  4.17195492  5.30996244  6.44796995
#   7.58597746  8.72398497  9.86199249 11.        ]
# D_min true:[0.9184095  2.13316651 2.30794929 4.08677197 4.90707369 5.13088865
#  5.2952114  5.54436967 5.60540932 6.67863285]
# In:	torch.Size([219, 3])
# Out:	torch.Size([219, 1])
# len_D_ARR	size:219	min:10	max:10	mean:10.0

# %% [markdown]
# ### Visualize Data

# %%
def visualizeData(In, Out, n_end):

    plt.figure(figsize=(12,8))

    plt.subplot(2,2,1)
    plt.plot(In[:n_end,0], label='F_min')
    plt.legend()
    plt.grid()

    plt.subplot(2,2,2)
    plt.plot(In[:n_end,1], label='F_max')
    plt.legend()
    plt.grid()

    plt.subplot(2,2,3)
    plt.plot(In[:n_end,2], label='beta')
    plt.legend()
    plt.grid()

    plt.subplot(2,2,4)
    plt.plot(In[:n_end,0], label='F_min', linestyle='dashed', linewidth=2)
    plt.plot(In[:n_end,1], label='F_max', linestyle='dashed', linewidth=2)
    plt.plot(Out[:n_end], label='F_beta')
    plt.legend()
    plt.grid()

    plt.show()

visualizeData(In, Out, n_end=2000)

# %% [markdown]
# ### Create neural net for training

# %%
importlib.reload(LSE_net)

# create DNN
n_inputs = In.size()[1]
n_outputs = Out.size()[1]
layers = [20, 20, 10]
NN_logSum = LSE_net.dnn(n_inputs, n_outputs, layers)
print(f'DNN model:\n{NN_logSum}')

# create training, and testing dataset
n_samples = In.size()[0]
frac_train = 0.7
n_train = int(frac_train * n_samples)
indices = torch.arange(n_samples)
train_indices = indices[:n_train]
test_indices = indices[n_train:]
In_train = In[train_indices]
Out_train = Out[train_indices]
In_test = In[test_indices]
Out_test = Out[test_indices]
# Out:
# DNN model:
# dnn(
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=20, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=20, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )

# %%
In[0]
# Out:
# tensor([6.6010e-01, 7.1440e-01, 1.0000e-04])

# %%
NN_logSum(In).detach().numpy()
# Out:
# array([[-7.0579268e-02],
#        [-7.0586033e-02],
#        [-7.0593499e-02],
#        ...,
#        [-1.4153204e+04],
#        [-1.5568459e+04],
#        [-1.7125242e+04]], dtype=float32)

# %%
visualizeData(In_train, Out_train, n_end=2000)
visualizeData(In_test, Out_test, n_end=2000)

# %% [markdown]
# ### train the network

# %%
# dnn configuration
optimizer_name = 'adam'
lr_scheduler = 'ReduceLROnPlateau'
lr0 = 0.0005
epochs = 200
batch_size = 70
loss_coeffs = [1.0, 0.0]
loss_fn, optimizer, scheduler = LSE_net.config_nn(NN_logSum, optimizer_name, lr_scheduler, lr0)
loss = loss_fn(NN_logSum(In_train[0]), Out_train[0]).detach().item()
training_loss, learning_rate, stopping_epoch = LSE_net.train_nn1(
    NN_logSum, In_train, Out_train, loss_fn,
    optimizer, scheduler, loss_coeffs=loss_coeffs,
    epochs=epochs, batch_size=batch_size, shuffledata=True, allowPrint=True)
# Out:
# ---------------------------------
# training data size = 3066
# training batch size = 70
# n_epochs = 200
# n_batches = 44
# loss weights = [1.0, 0.0]
# ---------------------------------
#
# batch_split
# 0 69
# 70 139
# 140 209
# 210 279
# 280 349
# 350 419
# 420 489
# 490 559
# 560 629
# 630 699
# 700 769
# 770 839
# 840 909
# 910 979
# 980 1049
# 1050 1119
# 1120 1189
# 1190 1259
# 1260 1329
# 1330 1399
# 1400 1469
# 1470 1539
# 1540 1609
# 1610 1679
# 1680 1749
# 1750 1819
# 1820 1889
# 1890 1959
# 1960 2029
# 2030 2099
# 2100 2169
# 2170 2239
# 2240 2309
# 2310 2379
# 2380 2449
# 2450 2519
# 2520 2589
# 2590 2659
# 2660 2729
# 2730 2799
# 2800 2869
# 2870 2939
# 2940 3009
# 3010 3065
#
#
#
# ---------------------------------
# epoch: 0/200, 	 loss: 2599957.882 	 rel:1.000e+03, 	 time: 0.04
# epoch: 1/200, 	 loss: 2599957.882 	 rel:1.000e+03, 	 time: 0.04
# epoch: 2/200, 	 loss: 316294.335 	 rel:1.217e+02, 	 time: 0.03
# epoch: 3/200, 	 loss: 55777.255 	 rel:2.145e+01, 	 time: 0.03
# epoch: 4/200, 	 loss: 1003.794 	 rel:3.861e-01, 	 time: 0.03
# epoch: 5/200, 	 loss: 10.483 	 rel:4.032e-03, 	 time: 0.03
# epoch: 6/200, 	 loss: 0.739 	 rel:2.841e-04, 	 time: 0.03
# epoch: 7/200, 	 loss: 0.375 	 rel:1.442e-04, 	 time: 0.04
# epoch: 8/200, 	 loss: 0.225 	 rel:8.659e-05, 	 time: 0.03
# epoch: 9/200, 	 loss: 0.147 	 rel:5.636e-05, 	 time: 0.04
# epoch: 10/200, 	 loss: 0.102 	 rel:3.933e-05, 	 time: 0.03
# epoch: 11/200, 	 loss: 0.081 	 rel:3.128e-05, 	 time: 0.03
# epoch: 12/200, 	 loss: 0.067 	 rel:2.573e-05, 	 time: 0.03
# epoch: 13/200, 	 loss: 0.058 	 rel:2.240e-05, 	 time: 0.04
# epoch: 14/200, 	 loss: 0.053 	 rel:2.023e-05, 	 time: 0.04
# ---------------------------------

# %%
# trained_lse_info = {
#     'model_state_dict': NN_logSum.state_dict(), 
#     'n_inputs':n_inputs,
#     'n_outputs':n_outputs,
#     'layers':layers,
#     'b_arr':b_array, 
#     'len_Darray':len_Darray, 
#     'D_min_range':D_min_range,
#     'D_max_range':D_max_range,
#     'io_scale':IO_scale,
#     'n_samples':n_samples,
#     'frac_train':frac_train,
#     'optimizer_name':optimizer,
#     'optimize_state_dict':optimizer.state_dict(),
#     'lr_scheduler':lr_scheduler,
#     'lr0':lr0,
#     'loss_fn':loss_fn,
#     'epochs':epochs,
#     'batch_size':batch_size,
#     'training_loss':training_loss,
#     'learning_rate':learning_rate,
# }

# %% [markdown]
# ### Save the trained model

# %%
# # str(datetime.datetime.today()).split()
# current_time = datetime.datetime.now()
# yyyy = str(current_time.year)
# mm = str(current_time.month)
# dd = str(current_time.day)
# hh = str(current_time.hour)
# mt = str(current_time.minute)
# sec = str(current_time.second)
# current_datetime = yyyy + '_' + mm + '_' + dd + '__' + hh + '_' + mt + '_' + sec 
# print(current_datetime)
# Out:
# 2025_4_17__15_56_48

# %%
# filename = 'logSumExp_models/lse_' + current_datetime + '.pth'

# torch.save(trained_lse_info, filename)

# %% [markdown]
# ### plot training loss and learning rate

# %%
plt.figure(figsize=(10,2))
plt.subplot(1,2,1)
plt.plot(training_loss)
plt.title('training_loss')
plt.grid()
plt.subplot(1,2,2)
plt.plot(learning_rate)
plt.title('learning_rate')
plt.grid()

plt.show()

# %% [markdown]
# ### Evaluate the network on a validation dataset

# %%
b_min_v = b_array[0]
b_max_v = b_array[-1]
b_grow_v = 1.1
b_array_v = createBetaArray(b_min_v, b_max_v, b_grow_v)
n_curves_v = 5
D_min_range_v = [0.0001,1]
D_max_range_v = [1,2]
len_Darray_range_v = len_Darray_range
In_val, Out_val, len_D_ARR_v = logsum_dataset(n_curves=n_curves_v, 
                    b_min=b_min_v, b_max=b_max_v, b_grow=b_grow_v, D_min_range=D_min_range_v, 
                    D_max_range=D_max_range_v, len_Darray_range=len_Darray_range_v, 
                    approx_log_sum_flr=False, io_scale=IO_scale)
pred_val = NN_logSum(In_val).detach()

st = 0
Out_val_np = (Out_val.numpy().flatten()/IO_scale)[st:] #- (1 / np.tile(b_array_v, n_curves_v) * np.log(len_D_ARR_v))[st:] + (In_val[:,1].numpy().flatten()/IO_scale)[st:]
pred_val_np = (pred_val.numpy().flatten()/IO_scale)[st:] #- (1 / np.tile(b_array_v, n_curves_v) * np.log(len_D_ARR_v))[st:] + (In_val[:,1].numpy().flatten()/IO_scale)[st:]

plt.figure(figsize=(12,4))
plt.subplot(2,1,1)
plt.plot(Out_val_np, label='target', color='violet', linestyle='dashed', linewidth=3)
plt.plot(pred_val_np, label='prediction', color='black')
plt.grid()
plt.xticks()
plt.legend()

plt.subplot(2,1,2)
error_val = np.abs(pred_val_np - Out_val_np)
# plt.subplot(1,2,2)
plt.plot(error_val, label='error', color='red')
plt.legend()
plt.grid()

plt.show()

# %%
Out_val_np.shape
# Out:
# (1120,)

# %%
b_array_v.shape
# Out:
# (280,)

# %%
np.tile(b_array_v, n_curves_v).shape
# Out:
# (1120,)
