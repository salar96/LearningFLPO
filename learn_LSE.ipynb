# %%
import numpy as np
import matplotlib.pyplot as plt
import LSE_net
import torch
import importlib
import pickle
import datetime

# %%
def myLog(x, base):
    return np.log(x)/np.log(base)

def createBetaArray(min, max, grow):
    beta = min
    beta_array = [beta]
    while beta <= max:
        beta = beta*grow
        beta_array.append(beta)
    beta_array = np.array(beta_array)
    return beta_array

def logSumExp(D_array, beta):
    D_min = np.min(D_array)
    D_off = D_array - D_min
    F = -1/beta * np.log(np.sum(np.exp(-beta*D_off))) + D_min + 1/beta * np.log(len(D_array))
    # F = -np.log(np.sum(np.exp(-beta*D_off))) + np.log(len(D_array)) + D_min * beta
    return F

# %%
np.random.seed(10)
D_array = np.random.uniform(10,100,20)
print(D_array.min())
beta0 = 1
logSumExp(D_array, beta0)
# Out:
# 10.355343969512301
# 13.151488974924014

# %%
d1 = 10
d2 = 30
d3 = 40
d4 = 50
b0 = 1e-5
l0 = 1/b0 * np.log(4)
l1 = -1/b0 * np.log(np.exp(-b0*d1) + np.exp(-b0*d2) + np.exp(-b0*d3) + np.exp(-b0*d4)) + l0
l2 = -1/b0 * np.log(4)
l3 = l2 + d1 - 1/b0 * np.log((1 + np.exp(-b0*(d2-d1)) + np.exp(-b0*(d3-d1)) + np.exp(-b0*(d4-d1)))/4) + l0
l4 = l2 + d1 - 1/b0 * np.log((1 + np.exp(-b0*d1) + np.exp(-b0*1.5*d1) + np.exp(-b0*4*d1))/4) + l0
print(f'l0:{l0:.3f}\nl1:{l1:.3f}\nl2:{l2:.3f}\nl3:{l3:.3f}\nl4:{l4:.3f}\nl2-l1:{l2+l0-l1:.3f}\nl3-l1:{l3-l1:.3f}\nl4-l1:{l4-l1:.3f}')
# Out:
# l0:138629.436
# l1:32.499
# l2:-138629.436
# l3:32.499
# l4:26.249
# l2-l1:-32.499
# l3-l1:0.000
# l4-l1:-6.250

# %% [markdown]
# ### Create dataset

# %%
# function to generate logsum dataset
def logsum_dataset(n_curves, b_min, b_max, b_grow, D_min_range, D_max_range, len_Darray, approx_log_sum_flr, io_scale):
    b_array = createBetaArray(b_min, b_max, b_grow)
    n_beta_per_curve = len(b_array)
    n_data = n_curves * n_beta_per_curve
    In = torch.zeros((n_data, 3), dtype=torch.float32)
    Out = torch.zeros((n_data,1), dtype=torch.float32)

    cnt = 0
    for c in range(n_curves):
        
        D_min = np.random.uniform(D_min_range[0], D_min_range[1])
        D_max = D_min + np.random.uniform(D_max_range[0], D_max_range[1])
        D_array = np.random.uniform(D_min, D_max, len_Darray)
        if approx_log_sum_flr:
            D_array_dum = np.arange(1,len_Darray+1)*2 + D_min
            F_min = logSumExp(D_array_dum, b_min)
        else:
            F_min = logSumExp(D_array, b_min)
        F_min = io_scale * F_min
        F_max = io_scale * np.min(D_array)

        for b in b_array:
            Fb = io_scale * logSumExp(D_array, b)
            In[cnt,:] = torch.tensor([F_min, F_max, b])
            Out[cnt,:] = torch.tensor([Fb])
            cnt += 1

    return In, Out

# %%
# beta limits
b_min = 1e-5
b_max = 1e3
b_grow = 1.1
b_array = createBetaArray(b_min, b_max, b_grow)
print(f'len b_array: {b_array.shape}')

# torch input and output arrays
n_curves = 200
len_Darray = 200
D_min_range = [10, 1000] # minimum value of D_array is picked at random from this range
D_max_range = [100, 1000] # maximum value of D_array is picked at random from the range dmin + D_max_range
IO_scale = 0.005

In, Out = logsum_dataset(n_curves, b_min, b_max, b_grow, D_min_range, D_max_range, len_Darray, approx_log_sum_flr=False, io_scale=IO_scale)
print(f'In: {In.size()}\tOut: {Out.size()}')
# Out:
# len b_array: (195,)
# In: torch.Size([39000, 3])	Out: torch.Size([39000, 1])

# %% [markdown]
# ### Visualize Data

# %%
def visualizeData(In, Out, n_end):

    plt.figure(figsize=(12,8))

    plt.subplot(2,2,1)
    plt.plot(In[:n_end,0], label='F_min')
    plt.legend()
    plt.grid()

    plt.subplot(2,2,2)
    plt.plot(In[:n_end,1], label='F_max')
    plt.legend()
    plt.grid()

    plt.subplot(2,2,3)
    plt.plot(In[:n_end,2], label='beta')
    plt.legend()
    plt.grid()

    plt.subplot(2,2,4)
    plt.plot(In[:n_end,0], label='F_min', linestyle='dashed', linewidth=2)
    plt.plot(In[:n_end,1], label='F_max', linestyle='dashed', linewidth=2)
    plt.plot(Out[:n_end], label='F_beta')
    plt.legend()
    plt.grid()

    plt.show()

visualizeData(In, Out, n_end=2000)

# %% [markdown]
# ### Create neural net for training

# %%
importlib.reload(LSE_net)

# create DNN
n_inputs = In.size()[1]
n_outputs = Out.size()[1]
layers = [20, 20, 10]
NN_logSum = LSE_net.dnn(n_inputs, n_outputs, layers)
print(f'DNN model:\n{NN_logSum}')

# create training, and testing dataset
n_samples = In.size()[0]
frac_train = 0.7
n_train = int(frac_train * n_samples)
indices = torch.arange(n_samples)
train_indices = indices[:n_train]
test_indices = indices[n_train:]
In_train = In[train_indices]
Out_train = Out[train_indices]
In_test = In[test_indices]
Out_test = Out[test_indices]
# Out:
# DNN model:
# dnn(
#   (layers): ModuleList(
#     (0): Linear(in_features=3, out_features=20, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=20, out_features=20, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=20, out_features=10, bias=True)
#     (5): ReLU()
#     (6): Linear(in_features=10, out_features=1, bias=True)
#   )
# )

# %%
In[0]
# Out:
# tensor([6.3074e+00, 4.5503e+00, 1.0000e-05])

# %%
NN_logSum(In).detach().numpy()
# Out:
# array([[ -0.54566216],
#        [ -0.5456622 ],
#        [ -0.54566216],
#        ...,
#        [-14.588141  ],
#        [-16.044552  ],
#        [-17.6466    ]], dtype=float32)

# %%
visualizeData(In_train, Out_train, n_end=2000)
visualizeData(In_test, Out_test, n_end=2000)

# %% [markdown]
# ### train the network

# %%
# dnn configuration
optimizer_name = 'adam'
lr_scheduler = 'ReduceLROnPlateau'
lr0 = 0.0005
epochs = 100
batch_size = 70
loss_coeffs = [1.0, 0.0]
loss_fn, optimizer, scheduler = LSE_net.config_nn(NN_logSum, optimizer_name, lr_scheduler, lr0)
loss = loss_fn(NN_logSum(In_train[0]), Out_train[0]).detach().item()
training_loss, learning_rate, stopping_epoch = LSE_net.train_nn1(
    NN_logSum, In_train, Out_train, loss_fn,
    optimizer, scheduler, loss_coeffs=loss_coeffs,
    epochs=epochs, batch_size=batch_size, allowPrint=True)
# Out:
# ---------------------------------
# training data size = 27300
# training batch size = 70
# n_epochs = 100
# n_batches = 390
# loss weights = [1.0, 0.0]
# ---------------------------------
#
# batch_split
# 0 69
# 70 139
# 140 209
# 210 279
# 280 349
# 350 419
# 420 489
# 490 559
# 560 629
# 630 699
# 700 769
# 770 839
# 840 909
# 910 979
# 980 1049
# 1050 1119
# 1120 1189
# 1190 1259
# 1260 1329
# 1330 1399
# 1400 1469
# 1470 1539
# 1540 1609
# 1610 1679
# 1680 1749
# 1750 1819
# 1820 1889
# 1890 1959
# 1960 2029
# 2030 2099
# 2100 2169
# 2170 2239
# 2240 2309
# 2310 2379
# 2380 2449
# 2450 2519
# 2520 2589
# 2590 2659
# 2660 2729
# 2730 2799
# 2800 2869
# 2870 2939
# 2940 3009
# 3010 3079
# 3080 3149
# 3150 3219
# 3220 3289
# 3290 3359
# 3360 3429
# 3430 3499
# 3500 3569
# 3570 3639
# 3640 3709
# 3710 3779
# 3780 3849
# 3850 3919
# 3920 3989
# 3990 4059
# 4060 4129
# 4130 4199
# 4200 4269
# 4270 4339
# 4340 4409
# 4410 4479
# 4480 4549
# 4550 4619
# 4620 4689
# 4690 4759
# 4760 4829
# 4830 4899
# 4900 4969
# 4970 5039
# 5040 5109
# 5110 5179
# 5180 5249
# 5250 5319
# 5320 5389
# 5390 5459
# 5460 5529
# 5530 5599
# 5600 5669
# 5670 5739
# 5740 5809
# 5810 5879
# 5880 5949
# 5950 6019
# 6020 6089
# 6090 6159
# 6160 6229
# 6230 6299
# 6300 6369
# 6370 6439
# 6440 6509
# 6510 6579
# 6580 6649
# 6650 6719
# 6720 6789
# 6790 6859
# 6860 6929
# 6930 6999
# 7000 7069
# 7070 7139
# 7140 7209
# 7210 7279
# 7280 7349
# 7350 7419
# 7420 7489
# 7490 7559
# 7560 7629
# 7630 7699
# 7700 7769
# 7770 7839
# 7840 7909
# 7910 7979
# 7980 8049
# 8050 8119
# 8120 8189
# 8190 8259
# 8260 8329
# 8330 8399
# 8400 8469
# 8470 8539
# 8540 8609
# 8610 8679
# 8680 8749
# 8750 8819
# 8820 8889
# 8890 8959
# 8960 9029
# 9030 9099
# 9100 9169
# 9170 9239
# 9240 9309
# 9310 9379
# 9380 9449
# 9450 9519
# 9520 9589
# 9590 9659
# 9660 9729
# 9730 9799
# 9800 9869
# 9870 9939
# 9940 10009
# 10010 10079
# 10080 10149
# 10150 10219
# 10220 10289
# 10290 10359
# 10360 10429
# 10430 10499
# 10500 10569
# 10570 10639
# 10640 10709
# 10710 10779
# 10780 10849
# 10850 10919
# 10920 10989
# 10990 11059
# 11060 11129
# 11130 11199
# 11200 11269
# 11270 11339
# 11340 11409
# 11410 11479
# 11480 11549
# 11550 11619
# 11620 11689
# 11690 11759
# 11760 11829
# 11830 11899
# 11900 11969
# 11970 12039
# 12040 12109
# 12110 12179
# 12180 12249
# 12250 12319
# 12320 12389
# 12390 12459
# 12460 12529
# 12530 12599
# 12600 12669
# 12670 12739
# 12740 12809
# 12810 12879
# 12880 12949
# 12950 13019
# 13020 13089
# 13090 13159
# 13160 13229
# 13230 13299
# 13300 13369
# 13370 13439
# 13440 13509
# 13510 13579
# 13580 13649
# 13650 13719
# 13720 13789
# 13790 13859
# 13860 13929
# 13930 13999
# 14000 14069
# 14070 14139
# 14140 14209
# 14210 14279
# 14280 14349
# 14350 14419
# 14420 14489
# 14490 14559
# 14560 14629
# 14630 14699
# 14700 14769
# 14770 14839
# 14840 14909
# 14910 14979
# 14980 15049
# 15050 15119
# 15120 15189
# 15190 15259
# 15260 15329
# 15330 15399
# 15400 15469
# 15470 15539
# 15540 15609
# 15610 15679
# 15680 15749
# 15750 15819
# 15820 15889
# 15890 15959
# 15960 16029
# 16030 16099
# 16100 16169
# 16170 16239
# 16240 16309
# 16310 16379
# 16380 16449
# 16450 16519
# 16520 16589
# 16590 16659
# 16660 16729
# 16730 16799
# 16800 16869
# 16870 16939
# 16940 17009
# 17010 17079
# 17080 17149
# 17150 17219
# 17220 17289
# 17290 17359
# 17360 17429
# 17430 17499
# 17500 17569
# 17570 17639
# 17640 17709
# 17710 17779
# 17780 17849
# 17850 17919
# 17920 17989
# 17990 18059
# 18060 18129
# 18130 18199
# 18200 18269
# 18270 18339
# 18340 18409
# 18410 18479
# 18480 18549
# 18550 18619
# 18620 18689
# 18690 18759
# 18760 18829
# 18830 18899
# 18900 18969
# 18970 19039
# 19040 19109
# 19110 19179
# 19180 19249
# 19250 19319
# 19320 19389
# 19390 19459
# 19460 19529
# 19530 19599
# 19600 19669
# 19670 19739
# 19740 19809
# 19810 19879
# 19880 19949
# 19950 20019
# 20020 20089
# 20090 20159
# 20160 20229
# 20230 20299
# 20300 20369
# 20370 20439
# 20440 20509
# 20510 20579
# 20580 20649
# 20650 20719
# 20720 20789
# 20790 20859
# 20860 20929
# 20930 20999
# 21000 21069
# 21070 21139
# 21140 21209
# 21210 21279
# 21280 21349
# 21350 21419
# 21420 21489
# 21490 21559
# 21560 21629
# 21630 21699
# 21700 21769
# 21770 21839
# 21840 21909
# 21910 21979
# 21980 22049
# 22050 22119
# 22120 22189
# 22190 22259
# 22260 22329
# 22330 22399
# 22400 22469
# 22470 22539
# 22540 22609
# 22610 22679
# 22680 22749
# 22750 22819
# 22820 22889
# 22890 22959
# 22960 23029
# 23030 23099
# 23100 23169
# 23170 23239
# 23240 23309
# 23310 23379
# 23380 23449
# 23450 23519
# 23520 23589
# 23590 23659
# 23660 23729
# 23730 23799
# 23800 23869
# 23870 23939
# 23940 24009
# 24010 24079
# 24080 24149
# 24150 24219
# 24220 24289
# 24290 24359
# 24360 24429
# 24430 24499
# 24500 24569
# 24570 24639
# 24640 24709
# 24710 24779
# 24780 24849
# 24850 24919
# 24920 24989
# 24990 25059
# 25060 25129
# 25130 25199
# 25200 25269
# 25270 25339
# 25340 25409
# 25410 25479
# 25480 25549
# 25550 25619
# 25620 25689
# 25690 25759
# 25760 25829
# 25830 25899
# 25900 25969
# 25970 26039
# 26040 26109
# 26110 26179
# 26180 26249
# 26250 26319
# 26320 26389
# 26390 26459
# 26460 26529
# 26530 26599
# 26600 26669
# 26670 26739
# 26740 26809
# 26810 26879
# 26880 26949
# 26950 27019
# 27020 27089
# 27090 27159
# 27160 27229
# 27230 27299
#
#
#
# ---------------------------------
# epoch: 0/100, 	 loss: 2132.114 	 rel:1000.0, 	 time: 0.64
# epoch: 1/100, 	 loss: 2132.114 	 rel:1000.0, 	 time: 0.64
# epoch: 2/100, 	 loss: 134.444 	 rel:63.1, 	 time: 0.63
# epoch: 3/100, 	 loss: 91.037 	 rel:42.7, 	 time: 0.60
# epoch: 4/100, 	 loss: 82.156 	 rel:38.5, 	 time: 0.59
# epoch: 5/100, 	 loss: 76.630 	 rel:35.9, 	 time: 0.59
# epoch: 6/100, 	 loss: 70.719 	 rel:33.2, 	 time: 0.59
# epoch: 7/100, 	 loss: 68.476 	 rel:32.1, 	 time: 0.59
# epoch: 8/100, 	 loss: 59.950 	 rel:28.1, 	 time: 0.60
# epoch: 9/100, 	 loss: 54.610 	 rel:25.6, 	 time: 0.67
# epoch: 10/100, 	 loss: 50.970 	 rel:23.9, 	 time: 0.60
# epoch: 11/100, 	 loss: 44.190 	 rel:20.7, 	 time: 0.85
# epoch: 12/100, 	 loss: 40.817 	 rel:19.1, 	 time: 0.90
# epoch: 13/100, 	 loss: 49.380 	 rel:23.2, 	 time: 0.95
# epoch: 14/100, 	 loss: 31.715 	 rel:14.9, 	 time: 0.93
# epoch: 15/100, 	 loss: 27.790 	 rel:13.0, 	 time: 1.35
# epoch: 16/100, 	 loss: 23.198 	 rel:10.9, 	 time: 0.90
# epoch: 17/100, 	 loss: 22.150 	 rel:10.4, 	 time: 0.86
# epoch: 18/100, 	 loss: 15.980 	 rel:7.5, 	 time: 0.90
# epoch: 19/100, 	 loss: 14.031 	 rel:6.6, 	 time: 0.89
# epoch: 20/100, 	 loss: 13.603 	 rel:6.4, 	 time: 0.90
# epoch: 21/100, 	 loss: 10.911 	 rel:5.1, 	 time: 2.37
# epoch: 22/100, 	 loss: 11.897 	 rel:5.6, 	 time: 1.83
# epoch: 23/100, 	 loss: 63.370 	 rel:29.7, 	 time: 0.93
# epoch: 24/100, 	 loss: 8.750 	 rel:4.1, 	 time: 1.01
# epoch: 25/100, 	 loss: 7.552 	 rel:3.5, 	 time: 1.05
# epoch: 26/100, 	 loss: 6.627 	 rel:3.1, 	 time: 0.83
# epoch: 27/100, 	 loss: 5.819 	 rel:2.7, 	 time: 0.96
# epoch: 28/100, 	 loss: 5.115 	 rel:2.4, 	 time: 1.22
# epoch: 29/100, 	 loss: 4.415 	 rel:2.1, 	 time: 2.07
# epoch: 30/100, 	 loss: 3.811 	 rel:1.8, 	 time: 1.33
# epoch: 31/100, 	 loss: 3.371 	 rel:1.6, 	 time: 1.15
# epoch: 32/100, 	 loss: 4.534 	 rel:2.1, 	 time: 1.18
# epoch: 33/100, 	 loss: 2.504 	 rel:1.2, 	 time: 1.34
# epoch: 34/100, 	 loss: 2.323 	 rel:1.1, 	 time: 0.93
# epoch: 35/100, 	 loss: 5.373 	 rel:2.5, 	 time: 1.19
# epoch: 36/100, 	 loss: 1.640 	 rel:0.8, 	 time: 1.24
# epoch: 37/100, 	 loss: 1.397 	 rel:0.7, 	 time: 1.43
# epoch: 38/100, 	 loss: 1.785 	 rel:0.8, 	 time: 0.94
# epoch: 39/100, 	 loss: 1.798 	 rel:0.8, 	 time: 0.89
# epoch: 40/100, 	 loss: 1.335 	 rel:0.6, 	 time: 1.08
# epoch: 41/100, 	 loss: 2.490 	 rel:1.2, 	 time: 1.22
# epoch: 42/100, 	 loss: 0.816 	 rel:0.4, 	 time: 0.85
# epoch: 43/100, 	 loss: 1.952 	 rel:0.9, 	 time: 0.96
# epoch: 44/100, 	 loss: 0.755 	 rel:0.4, 	 time: 0.85
# epoch: 45/100, 	 loss: 3.429 	 rel:1.6, 	 time: 0.87
# epoch: 46/100, 	 loss: 0.661 	 rel:0.3, 	 time: 0.85
# epoch: 47/100, 	 loss: 0.625 	 rel:0.3, 	 time: 0.82
# epoch: 48/100, 	 loss: 1.599 	 rel:0.7, 	 time: 0.82
# epoch: 49/100, 	 loss: 0.595 	 rel:0.3, 	 time: 0.82
# epoch: 50/100, 	 loss: 2.945 	 rel:1.4, 	 time: 0.84
# epoch: 51/100, 	 loss: 0.528 	 rel:0.2, 	 time: 0.85
# epoch: 52/100, 	 loss: 0.539 	 rel:0.3, 	 time: 0.91
# epoch: 53/100, 	 loss: 2.781 	 rel:1.3, 	 time: 1.00
# epoch: 54/100, 	 loss: 0.479 	 rel:0.2, 	 time: 0.87
# epoch: 55/100, 	 loss: 0.487 	 rel:0.2, 	 time: 0.86
# epoch: 56/100, 	 loss: 2.015 	 rel:0.9, 	 time: 0.83
# epoch: 57/100, 	 loss: 0.447 	 rel:0.2, 	 time: 0.83
# epoch: 58/100, 	 loss: 0.908 	 rel:0.4, 	 time: 0.82
# epoch: 59/100, 	 loss: 0.804 	 rel:0.4, 	 time: 0.82
# epoch: 60/100, 	 loss: 0.779 	 rel:0.4, 	 time: 0.82
# epoch: 61/100, 	 loss: 0.874 	 rel:0.4, 	 time: 0.82
# epoch: 62/100, 	 loss: 0.688 	 rel:0.3, 	 time: 0.81
# epoch: 63/100, 	 loss: 1.593 	 rel:0.7, 	 time: 0.87
# epoch: 64/100, 	 loss: 0.408 	 rel:0.2, 	 time: 0.85
# epoch: 65/100, 	 loss: 0.805 	 rel:0.4, 	 time: 0.82
# epoch: 66/100, 	 loss: 0.731 	 rel:0.3, 	 time: 0.82
# epoch: 67/100, 	 loss: 1.021 	 rel:0.5, 	 time: 0.87
# epoch: 68/100, 	 loss: 0.355 	 rel:0.2, 	 time: 0.93
# epoch: 69/100, 	 loss: 2.563 	 rel:1.2, 	 time: 0.82
# epoch: 70/100, 	 loss: 0.412 	 rel:0.2, 	 time: 0.98
# epoch: 71/100, 	 loss: 0.391 	 rel:0.2, 	 time: 0.82
# epoch: 72/100, 	 loss: 1.072 	 rel:0.5, 	 time: 0.82
# epoch: 73/100, 	 loss: 0.409 	 rel:0.2, 	 time: 0.82
# epoch: 74/100, 	 loss: 1.062 	 rel:0.5, 	 time: 0.83
# epoch: 75/100, 	 loss: 0.355 	 rel:0.2, 	 time: 0.82
# epoch: 76/100, 	 loss: 1.049 	 rel:0.5, 	 time: 0.82
# epoch: 77/100, 	 loss: 0.312 	 rel:0.1, 	 time: 0.82
# epoch: 78/100, 	 loss: 1.089 	 rel:0.5, 	 time: 0.82
# epoch: 79/100, 	 loss: 0.288 	 rel:0.1, 	 time: 0.82
# epoch: 80/100, 	 loss: 0.524 	 rel:0.2, 	 time: 0.82
# epoch: 81/100, 	 loss: 1.508 	 rel:0.7, 	 time: 0.82
# epoch: 82/100, 	 loss: 0.575 	 rel:0.3, 	 time: 0.82
# epoch: 83/100, 	 loss: 0.366 	 rel:0.2, 	 time: 0.81
# epoch: 84/100, 	 loss: 2.021 	 rel:0.9, 	 time: 0.84
# epoch: 85/100, 	 loss: 0.297 	 rel:0.1, 	 time: 0.83
# epoch: 86/100, 	 loss: 0.308 	 rel:0.1, 	 time: 0.82
# epoch: 87/100, 	 loss: 0.671 	 rel:0.3, 	 time: 0.82
# epoch: 88/100, 	 loss: 0.535 	 rel:0.3, 	 time: 0.82
# epoch: 89/100, 	 loss: 0.706 	 rel:0.3, 	 time: 0.82
# epoch: 90/100, 	 loss: 0.315 	 rel:0.1, 	 time: 0.81
# epoch: 91/100, 	 loss: 18.493 	 rel:8.7, 	 time: 0.82
# epoch: 92/100, 	 loss: 0.460 	 rel:0.2, 	 time: 0.82
# epoch: 93/100, 	 loss: 0.343 	 rel:0.2, 	 time: 0.83
# epoch: 94/100, 	 loss: 0.310 	 rel:0.1, 	 time: 0.91
# epoch: 95/100, 	 loss: 0.287 	 rel:0.1, 	 time: 0.82
# epoch: 96/100, 	 loss: 0.277 	 rel:0.1, 	 time: 0.82
# epoch: 97/100, 	 loss: 0.285 	 rel:0.1, 	 time: 0.82
# epoch: 98/100, 	 loss: 0.379 	 rel:0.2, 	 time: 0.84
# epoch: 99/100, 	 loss: 0.328 	 rel:0.2, 	 time: 0.82
# epoch: 100/100, 	 loss: 3.700 	 rel:1.7, 	 time: 0.81
# Maximum Iterations Reached
# ---------------------------------

# %%
trained_dnn_info = {
    'model_state_dict': NN_logSum.state_dict(), 
    'n_inputs':n_inputs,
    'n_outputs':n_outputs,
    'layers':layers,
    'b_arr':b_array, 
    'len_Darray':len_Darray, 
    'D_min_range':D_min_range,
    'D_max_range':D_max_range,
    'io_scale':IO_scale,
    'n_samples':n_samples,
    'frac_train':frac_train,
    'optimizer_name':optimizer,
    'optimize_state_dict':optimizer.state_dict(),
    'lr_scheduler':lr_scheduler,
    'lr0':lr0,
    'loss_fn':loss_fn,
    'epochs':epochs,
    'batch_size':batch_size,
    'training_loss':training_loss,
    'learning_rate':learning_rate,
}

# %% [markdown]
# ### Save the trained model

# %%
# str(datetime.datetime.today()).split()
current_time = datetime.datetime.now()
yyyy = str(current_time.year)[2:]
mm = str(current_time.month)
dd = str(current_time.day)
hh = str(current_time.hour)
mt = str(current_time.minute)
sec = str(current_time.second)
current_datetime = yyyy + mm + dd + '_' + hh + mt + sec 
print(current_datetime)
# Out:
# 25415_153930

# %%
filename = 'logSumExp_models/dnn_' + current_datetime + '.pth'

torch.save(trained_dnn_info, filename)

# %% [markdown]
# ### plot training loss and learning rate

# %%
plt.figure(figsize=(10,2))
plt.subplot(1,2,1)
plt.plot(training_loss)
plt.title('training_loss')
plt.grid()
plt.subplot(1,2,2)
plt.plot(learning_rate)
plt.title('learning_rate')
plt.grid()

plt.show()

# %% [markdown]
# ### Evaluate the network on a validation dataset

# %%
b_min_v = b_array[0]
b_max_v = b_array[-1]
b_grow_v = 1.2
b_array_v = createBetaArray(b_min_v, b_max_v, b_grow_v)
n_curves_v = 2
D_min_range_v = [1000,2000]
D_max_range_v = [400,1000]
len_Darray_v = len_Darray
In_val, Out_val = logsum_dataset(n_curves=n_curves_v, 
                    b_min=b_min_v, b_max=b_max_v, b_grow=b_grow_v, D_min_range=D_min_range_v, 
                    D_max_range=D_max_range_v, len_Darray=len_Darray_v, 
                    approx_log_sum_flr=True, io_scale=IO_scale)
pred_val = NN_logSum(In_val).detach()

st = 0
Out_val_np = (Out_val.numpy().flatten()/IO_scale)[st:] - (1 / np.tile(b_array_v, n_curves_v) * np.log(len_Darray_v))[st:]
pred_val_np = (pred_val.numpy().flatten()/IO_scale)[st:] - (1 / np.tile(b_array_v, n_curves_v) * np.log(len_Darray_v))[st:]

plt.figure(figsize=(12,4))
plt.subplot(2,1,1)
plt.plot(Out_val_np, label='target', color='violet', linestyle='dashed', linewidth=3)
plt.plot(pred_val_np, label='prediction', color='black')
plt.grid()
plt.xticks()
plt.legend()

plt.subplot(2,1,2)
error_val = np.abs(pred_val_np - Out_val_np)
# plt.subplot(1,2,2)
plt.plot(error_val, label='error', color='red')
plt.legend()
plt.grid()

plt.show()

# %%
Out_val_np.shape
# Out:
# (1120,)

# %%
b_array_v.shape
# Out:
# (280,)

# %%
np.tile(b_array_v, n_curves_v).shape
# Out:
# (1120,)
